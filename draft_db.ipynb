# %% [markdown]
# <a href="https://colab.research.google.com/github/zhouhanc/superset-information-tracer/blob/main/draft_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# !pip install informationtracer
# !pip install pysentimiento

# %% [markdown]
# # Import

# %%
import os

from informationtracer import informationtracer
import requests
import mysql.connector

import pandas as pd
import numpy as np
import random

import pytz
from pytz import timezone
from datetime import datetime
from datetime import date
from datetime import datetime, timedelta

from pysentimiento.preprocessing import preprocess_tweet
from pysentimiento import create_analyzer


import itertools

import re
import string
from nltk.stem.snowball import SnowballStemmer
import nltk
from gensim import corpora, models
from wordcloud import WordCloud

# %% [markdown]
# # Create database and table

# %%
with open(os.path.expanduser('db_info.txt'), 'r') as f:
    lines = f.readlines()

localhost = lines[0].strip()
username = lines[1].strip()
pw = lines[2].strip()


#connect to database
mydb = mysql.connector.connect(
  host=localhost,
  user=username,
  password=pw
)


mycursor = mydb.cursor()
# create a databse called "dashboard"
#mycursor.execute("CREATE DATABASE dashboard")

# %%
# select database to modify
mycursor.execute("use dashboard")

# delete table
# mycursor.execute("drop table if exists infotracer")
# mycursor.execute("drop table if exists sentiment")
# mycursor.execute("drop table if exists wordcloud")
# mycursor.execute("drop table if exists network")
# mycursor.execute("drop table if exists helper")

# create table
# mycursor.execute("create table infotracer (candidate_name varchar(255), text MediumTEXT, username varchar(255), num_interaction int, datetime timestamp, platform varchar(255) )")
# mycursor.execute("create table sentiment (text MediumTEXT, processed_text MediumTEXT, positive float, neutral float, negative float, label varchar(255),candidate_name varchar(255), platform varchar(255), username varchar(255), num_interaction int, datetime timestamp )")
# mycursor.execute("create table wordcloud (word varchar(255), weight float, candidate_name varchar(255),platform varchar(255))")
# mycursor.execute("create table network (source varchar(255), target varchar(255), weight float, source_cat varchar(255), target_cat varchar(255), source_datetime timestamp, target_datetime timestamp, candidate_name varchar(255))")
# mycursor.execute("create table helper (datetime timestamp,candidate_name varchar(255),label varchar(255),platform varchar(255))")
# mydb.commit()

# %% [markdown]
# delete data

# %%
# !!!!!!!!!!!!!!!!!!!!!!!!always remember to commit!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# mycursor.execute("DELETE FROM infotracer WHERE datetime >= '2023-04-18 18:00:00' AND datetime <= '2023-04-25 18:00:00'")
# mycursor.execute("DELETE FROM sentiment WHERE datetime >= '2023-04-18 18:00:00' AND datetime <= '2023-04-25 18:00:00'")
# mycursor.execute("DELETE FROM network")
# 18:00 is mexico time, when collect still use 00:00 to 23:59
# mydb.commit()

# %% [markdown]
# #ELT helper table

# %%
def generate_helper_table(start_date,end_date,update_db=True):
  
##############################################################################
##  This function generates a helper table that is used to join with other table to fill in time gaps.
##  Records are inserted to table within function.
##############################################################################

  # Define platforms and labels
  platforms = ['facebook','twitter','instagram','youtube','youtube comment']
  labels = ['POS','NEU','NEG']
  candidate_name=['Manolo Jiménez Salinas','Armando Guadiana Tijerina','Ricardo Mejia Berdeja','Lenin Perez Rivera']
  # Generate date range
  date_range = pd.date_range(start=start_date, end=end_date)

  # Generate combinations of platform and label for each date
  date_platform_label = list(itertools.product(date_range, platforms, labels,candidate_name))

  # Create DataFrame
  helper_df = pd.DataFrame(date_platform_label, columns=["datetime", "platform", "label",'candidate_name'])


  if update_db==True:
    # Insert to db
    helper_data = helper_df.apply(tuple, axis=1).tolist()
    # change order of column to fit df
    query="insert into helper (datetime,platform,label, candidate_name) Values(%s,%s,%s,%s);" 
    mycursor.executemany(query,helper_data)
    mydb.commit()

  return

# %% [markdown]
# # ETL for infotracer table

# %%
def convert_time(column):

##############################################################################
##  This function takes the datetime column of any dataframe 
##  and convert utc time to mexico time.
##  This function is part of another function. DO NOT run directly.
##############################################################################

  column=column.apply(lambda x: pytz.utc.localize(x))
  #utc to mexico time
  mexico_tz = timezone('America/Mexico_City')
  convert_timestamp = lambda x: x.astimezone(mexico_tz).replace(tzinfo=None)
  column = column.apply(convert_timestamp)
  return column

# %%
def generate_infotracer_table(start_date,end_date,update_db=True):

########################################################################################
##  This function query data using information tracer, store in df, convert time and insert
##  data into information tracer table. It returns a df of qury result. This result will be used for sentiment analysis.
##  This function is part of another function. DO NOT run directly.
########################################################################################

  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # query with information tracer api
  df=[]

  for candidate, query in query_dict.items():
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date)
    url = "https://informationtracer.com/api/v1/result?token={}&id_hash256={}".format(your_token, id_hash256)
    results = requests.get(url).json() #will get json for all data of keyword, results is a dictionary

    for pf in ['facebook','twitter','instagram','youtube']:
      platform_data=pd.DataFrame(results['posts'][pf], columns=['d','i','n','t'])
      platform_data['platform']=pf
      platform_data['candidate_name']=candidate
      platform_data['t']=pd.to_datetime(platform_data['t'])
      df.append(platform_data)

  df=pd.concat(df)
  df=df.rename(columns={'d':'text','i':'num_interaction','n':'username','t':'datetime'})

  # convert timezone
  df['datetime'] = convert_time(df['datetime'])
  df=df.drop_duplicates()

  print('#################################################')
  print('the shape of infotracer table is:',df.shape)
  print('#################################################')

  if update_db==True:
    # insert to db
    infotracer_data = df.apply(tuple, axis=1).tolist()
    query="insert into infotracer (text,num_interaction,username,datetime,platform,candidate_name) Values(%s,%s,%s,%s,%s,%s);"
    mycursor.executemany(query,infotracer_data)

    mydb.commit()
    # return query result
  return df

# %%
# result416=generate_infotracer_table(start_date='2023-04-16',end_date='2023-04-17',update_db=False)

# %% [markdown]
# # ETL data for sentiment table

# %% [markdown]
# ## youtube comment functions

# %%
##############################################################################
##  NOTE: register youtube API key!
## 
##  Follow instruction here: 
##  https://developers.google.com/youtube/registering_an_application
##
##  One key is enough, more keys can speed up the data collection process
#############################################################################

# read a dictionary of names and values of youtube api key 
API_KEY= {}

with open(os.path.expanduser('youtube_tokens.txt'), 'r') as f:
    for line in f:
        key, value = line.strip().split(',')
        API_KEY[key] = value

API_KEY = list(API_KEY.values())

def search_replies(comment_id):
    headers = {
        'Accept': 'application/json',
    }    

    params = (
        ('part', 'snippet,id'),
        ('parentId', comment_id),
        ('key', random.choice(API_KEY)),
        ('maxResults', '100')        
    )
    
    results = []
    response = requests.get('https://www.googleapis.com/youtube/v3/comments', headers=headers, params=params)
    
    print("Youtube response code --> ", response.status_code)
    if int(response.status_code) > 300:
        print(response.text)
        print('Youtube API v3/videos returns non 200 status code, something is very wrong')
        return results

    results += [item for item in response.json()['items']]
#     print(results)
    nextPageToken = response.json().get('nextPageToken', None)
    
    while nextPageToken:
        print(nextPageToken)
        params = (
            ('part', 'snippet,id'),
            ('parentId', comment_id),
            ('key', random.choice(API_KEY)),
            ('maxResults', '100'),
            ('pageToken', nextPageToken)
        )
        
        response = requests.get('https://www.googleapis.com/youtube/v3/comments', headers=headers, params=params)
        print("Youtube response code --> ", response.status_code)
        if int(response.status_code) > 300:
            print(response.text)
            print('Youtube API v3/videos returns non 200 status code, something is very wrong')
            break
    
        results += [item for item in response.json()['items']]
        nextPageToken = response.json().get('nextPageToken', None)
        
    return results




def search_comments(video_id):        
    headers = {
        'Accept': 'application/json',
    }    

    params = (
        ('part', 'snippet,replies'),
        ('videoId', video_id),
        ('key', random.choice(API_KEY)),
        ('maxResults', '100')        
    )
    
    results = []
    response = requests.get('https://www.googleapis.com/youtube/v3/commentThreads', headers=headers, params=params)
    print("Youtube response code --> ", response.status_code)
    if int(response.status_code) > 300:
        print(response.text)
        print('Youtube API v3/videos returns non 200 status code, something is very wrong')
        return results

    results += [item for item in response.json()['items']]
    nextPageToken = response.json().get('nextPageToken', None)
    
    while nextPageToken:
        print(nextPageToken)
        params = (
            ('part', 'snippet,replies'),
            ('videoId', video_id),
            ('key', random.choice(API_KEY)),
            ('maxResults', '100'),
            ('pageToken', nextPageToken)
        )
        
        response = requests.get('https://www.googleapis.com/youtube/v3/commentThreads', headers=headers, params=params)
        print("Youtube response code --> ", response.status_code)
        if int(response.status_code) > 300:
            print(response.text)
            print('Youtube API v3/videos returns non 200 status code, something is very wrong')
            break
    
        results += [item for item in response.json()['items']]
        nextPageToken = response.json().get('nextPageToken', None)
    
    for i in results:
        if i['snippet']['totalReplyCount'] > 5:
            print('hydrating more comments...')
            i['replies']['comments'] = search_replies(i['id'])
            print(len(i['replies']['comments']))

    # save results    
    return results

# %%
def convert_time_ytb(column):
##############################################################################
##  This function takes the datetime column of any dataframe 
##  and convert utc time to mexico time. For ytb comment only.
##  This function is part of another function. DO NOT run directly.
##############################################################################

  #utc to mexico time
  mexico_tz = timezone('America/Mexico_City')
  convert_timestamp = lambda x: x.astimezone(mexico_tz).replace(tzinfo=None)
  column = column.apply(convert_timestamp)
  return column

# %% [markdown]
# ## youtube query

# %%
def query_youtube_comment(start_date,end_date):
##############################################################################
##  This function use information tracer result to query for youtube comment, 
##  and convert utc time to mexico time.
##  This function is part of another function. DO NOT run directly.
##############################################################################
  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # get video id from information tracer source data
  videoId_dic={}
  for candidate, query in query_dict.items():
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date,skip_result=True)
    url="https://informationtracer.com/loadsource?source={}&id_hash256={}&token={}".format('youtube', id_hash256, your_token)
    results=requests.get(url).json()
    videoId_dic[candidate] = [data['id']['videoId'] for data in results] 
  
  # query comments using youtube api
  ytbcomment_df=[]
  for candidate, videoId_list in videoId_dic.items():
    comment=[]
    username=[]
    likeCount=[]
    date=[]
    for vid in videoId_list:
      if vid!=[]:
        result=search_comments(vid)
        for i in np.arange(0,len(result),1):
          comment.append(result[i]['snippet']['topLevelComment']['snippet']['textDisplay'])
          username.append(result[i]['snippet']['topLevelComment']['snippet']['authorDisplayName'])
          likeCount.append(result[i]['snippet']['topLevelComment']['snippet']['likeCount'])
          date.append(result[i]['snippet']['topLevelComment']['snippet']['publishedAt'])
      ytbcomment= pd.DataFrame({'text': comment, 'num_interaction': likeCount, 
                      'username': username,'datetime': date})
      ytbcomment['platform']='youtube comment'
      ytbcomment['candidate_name']=candidate
      ytbcomment['datetime']=pd.to_datetime(ytbcomment['datetime'])
      ytbcomment_df.append(ytbcomment)
  ytbcomment_df=pd.concat(ytbcomment_df)
  

  # convert timezone
  if ytbcomment_df.empty==False:
    ytbcomment_df['datetime'] = convert_time_ytb(ytbcomment_df['datetime'])
    ytbcomment_df=ytbcomment_df.drop_duplicates()

  print('#################################################')
  print('the shape of youtube comment is:',ytbcomment_df.shape)
  print('#################################################')
  # return query result
  return ytbcomment_df

# %% [markdown]
# ## text process functions

# %%
# remove \n and ...
def remove_n(df):
  df['text'] = df['text'].str.replace(r'\n|\n.', '', regex=True)
  df['text'] = df['text'].str.replace(r'\.{2,}', '.', regex=True)
  return df
  
# parse
def parse(df):
  print('#################################################')
  print('the shape of merged df is:',df.shape)
  print('start parsing')
  print('#################################################')
  df=remove_n(df)
  df=df.drop_duplicates()
  # new_df = pd.DataFrame(columns=df.columns)
  parsed_df=[]
  # iterate over each row in the original dataframe
  for index, row in df.iterrows():
    print('parsing row', index)
    # split the "text" column value into a list of sentences
    sentences = row['text'].split('. ')  # assuming sentences are separated by ". "
    new_df=pd.DataFrame({
            'text': sentences,
            'num_interaction': row['num_interaction'],
            'username':row['username'],
            'datetime': row['datetime'],
            'platform': row['platform'],
            'candidate_name': row['candidate_name']            
    })
    parsed_df.append(new_df)

  parsed_df=pd.concat(parsed_df)
  return parsed_df

# %%
# Define a function to restore spanish accents
def replace_special_chars(text):
  text = re.sub(r'\\u([\da-fA-F]{4})', lambda m: chr(int(m.group(1), 16)), text)
  # Remove punctuation
  text = text.translate(str.maketrans('', '', string.punctuation))
  text = ''.join([i for i in text if not i.isdigit()])
  # # Create a SnowballStemmer for Spanish
  # stemmer = SnowballStemmer('spanish')
  # # Apply stemming
  # words = text.split()
  # stemmed_words = [stemmer.stem(word) for word in words]
  # return ' '.join(stemmed_words)
  return text

def text_process(df):
  # restore accent
  df['text'] = df['text'].apply(replace_special_chars)
  # process tweet is a func from pysentimiento
  df['processed_text'] = df['text'].apply(preprocess_tweet)

  # other steps

  return df

# %% [markdown]
# ## sentiment analysis function

# %%
# do sentiment analysis in batches
def sent_analyze(df):
  batch=512
  analyzer = create_analyzer(task="sentiment", lang="es", batch_size=batch)

  text=df['processed_text'].tolist() #list of texts
  label=[]
  pos_prob=[]
  neu_prob=[]
  neg_prob=[]
  for i in range(0, len(text), batch):
    analyze_result=analyzer.predict(text[i:i+batch])

    label+=[r.output for r in analyze_result]
    pos_prob+=[r.probas['POS'] for r in analyze_result]
    neu_prob+=[r.probas['NEU'] for r in analyze_result]
    neg_prob+=[r.probas['NEG'] for r in analyze_result]
    print("Batch {} done".format(int(i/512)))

  df['label']=label
  df['positive']=pos_prob
  df['neutral']=neu_prob
  df['negative']=neg_prob
  return df

# %%
def generate_infotracer_and_sentiment_table(start_date,end_date,ytb_end_date,update_db=True):

###########################################################################
## This function generates both infotracer and sentiment table.
## It calls information tracer and ytb comment function within it,
## merge result, process text and conduct sentiment analysis.
###########################################################################

  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # get information tracer query result (also insert to db)
  df=generate_infotracer_table(start_date=start_date,end_date=end_date,update_db=update_db)

  #get youtube comment query result
  ytbcomment_df=query_youtube_comment(start_date=start_date,end_date=ytb_end_date)

  # merge results
  # text for sentiment table: everything in df + used youtube raw data to extract comment
  sentiment_df=pd.concat([ytbcomment_df,df])
  sentiment_df=sentiment_df.reset_index(drop=True)

  #parse post into sentences
  sentiment=parse(sentiment_df)

  #################################
  ## text processing
  #################################
  sentiment=text_process(sentiment)

  # sentiment calculation

  full_sentiment=sent_analyze(sentiment)
  if update_db==True:
    # commit full sentiment to sentiment table in db
    sent_data = full_sentiment.apply(tuple, axis=1).tolist()
    query="insert into sentiment (text,num_interaction,username,datetime,platform,candidate_name,processed_text,label, positive, neutral, negative) Values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);" 
    mycursor.executemany(query,sent_data)

    mydb.commit()

  return

# %% [markdown]
# # ETL data for wordcloud

# %%
def clean_text(sentence):
  # all lower-case
  sentence = sentence.lower()
  # remove punctuations 
  sentence = re.sub(r"[,.¡¿\"@#$%^&*(){}?/;:<>+=-]", "", sentence)
  # remove numbers
  sentence = re.sub(r'\d+', '', sentence)
  # remove leading/trailing whitespace
  sentence = sentence.strip()
  
  return sentence

# %%
def generate_wordcloud_table():
  #query for data in last 14 days
  wc_query= "SELECT processed_text, platform, candidate_name, datetime FROM sentiment WHERE datetime >= DATE_SUB(NOW(), INTERVAL 14 DAY) "
  word_cloud_df= pd.read_sql_query(wc_query, mydb)
  
  #process text
  word_cloud_df['processed_text']=word_cloud_df['processed_text'].apply(lambda x: clean_text(x))


  # stop words
  
  with open(os.path.expanduser('spanish.txt'), 'r') as f:
    spanish_stopwords = [line.strip() for line in f]
  stop_words = set(spanish_stopwords)
  stop_words.add('emoji') 
  stop_words.add('http')
  stop_words.add('youtube')
  stop_words.add('twitter')
  stop_words.add('instagram')
  stop_words.add('facebook')

  # generate wordcloud df
  wc=[]
  for platform in word_cloud_df['platform'].unique():
    for candidate in word_cloud_df['candidate_name'].unique():
      all_text = ' '.join(word_cloud_df[(word_cloud_df['platform']==platform)&(word_cloud_df['candidate_name']==candidate)]['processed_text'])
      if all_text=='':
        all_text='NADA'
        print(platform, candidate, all_text)
      wordcloud = WordCloud(stopwords=stop_words).generate(all_text)
      # Get list of words in wordcloud
      word_list = list(wordcloud.words_.keys())
      word_weights = list(wordcloud.words_.values())
      sub_wc=pd.DataFrame({'word':word_list, 'frequency':word_weights,'platform': platform,'candidate_name':candidate})
      wc.append(sub_wc)

  wc=pd.concat(wc)
  print('shape of wordcloud is',wc.shape)

  # empty the table
  print('empty the table')
  mycursor.execute(f'DELETE FROM wordcloud')
  mydb.commit()

  # insert to db last 14 days data
  print('start inserting')
  wc_data = wc.apply(tuple, axis=1).tolist()
  query="insert into wordcloud (word,weight, platform, candidate_name) Values(%s,%s,%s,%s);" 
  mycursor.executemany(query,wc_data)
  print('done')

  mydb.commit()

  return

# %% [markdown]
# # ETL data for network

# %%
def generate_network_table(start_date,end_date,update_db=True):
  
  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}

  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  for candidate, query in query_dict.items():
    ## extract data
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date)
    url = "https://informationtracer.com/cross_platform/{}/interaction_network_{}.json".format(id_hash256[:3], id_hash256)

    network_json = requests.get(url).json()

    ## construct df
    node_id_to_category = {}
    node_id_to_name={}
    node_id_to_datetime={}
    node_id_to_platform={}

    ## iterate all nodes to save node type
    for node in network_json['nodes']:
      node_id_to_category[node['id']] = node['type']
      node_id_to_name[node['id']]=node['name']
      node_id_to_datetime[node['id']]=node['timestamp']
      node_id_to_platform[node['id']]=node['platform']

    ## iterate all links
    source=[]
    target=[]
    weight=[]
    source_cat=[]
    target_cat=[]
    source_datetime=[]
    target_datetime=[]

    for link in network_json['links']:
      source_id = link['source']
      target_id = link['target']
      source_datetime.append(node_id_to_datetime[source_id])
      target_datetime.append(node_id_to_datetime[target_id])

      source_cat.append(node_id_to_category[source_id])
      target_cat.append(node_id_to_category[target_id])

      # to distinguish user with same name on different platform
      if node_id_to_category[source_id]=='user':
        source.append((node_id_to_name[source_id]+' '+node_id_to_platform[source_id]))
      else: 
        source.append(node_id_to_name[source_id])
      
      if node_id_to_category[target_id]=='user':
        target.append((node_id_to_name[target_id]+' '+node_id_to_platform[target_id]))
      else:
        target.append(node_id_to_name[target_id])
      
      weight.append(link['weight'])


    nw_df = pd.DataFrame({
        'source': source,
        'target': target,
        'weight': weight,
        'source_cat': source_cat,
        'target_cat': target_cat,
        'source_datetime': source_datetime,
        'target_datetime': target_datetime
    })
    nw_df['source_datetime']=pd.to_datetime(nw_df['source_datetime'])
    nw_df['target_datetime']=pd.to_datetime(nw_df['target_datetime'])
    nw_df['source_datetime']=convert_time(nw_df['source_datetime'])
    nw_df['target_datetime']=convert_time(nw_df['target_datetime'])

    nw_df['candidate_name']=candidate
    if update_db==True:
      ##### insert into mysql table source, target, weight, source_category, target_category
      nw_data=nw_df.apply(tuple, axis=1).tolist()
      query="insert into network (source, target, weight, source_cat, target_cat, source_datetime, target_datetime, candidate_name) Values(%s,%s,%s,%s,%s,%s,%s,%s);"
      mycursor.executemany(query,nw_data)

      mydb.commit()

  return

# %% [markdown]
# # Historical

# %% [markdown]
# **different from databse_buildup.py !!!!!!!!!!!!!!!!!!**
# <br>
# **add query_dict parameter**

# %%
# if start date=0415, end date=0416, it means from 0415 00:00 to 0416 23:59!!!
# 0415 00：00-0416-23：59 << start 0415, end 0416
# 0416 00：00-0416 23：59 << start 0416, end 0416

# %%
# # infotracer and sentiment: add historical data
generate_infotracer_and_sentiment_table(start_date="2023-04-24",end_date="2023-04-25",ytb_end_date="2023-04-25",update_db=True)

# # network: add historical data
# print('network table starts')
# generate_network_table(start_date="2023-04-19",end_date="2023-04-24",update_db=True)
# print('network table done')

# # helper: add historical data
# generate_helper_table(start_date="2023-01-01",end_date="2023-04-08")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#                         't': '2023-04-25T02:57:32'},
#                        {'d': 'Mejor si,tanto el ojos de Sapo de '
#                              '@mario_delgado,el greñudo apestoso de '
#                              '@DiegodelBosqueV y el viejo bofo de @aguadiana '
#                              'deben entender que esta imposición fue el regalo '
#                              'perfecto para el Pri, garantizar su continuidad, '
#                              'mas no contaban con el Tigre @RicardoMeb\n'
#                              '#FueraElPriDeCoahuila',
#                         'i': 10,
#                         'id': 1569150398489071618,
#                         'l': 'https://twitter.com/sarapero1972/status/1650686286020190208',
#                         'n': 'sarapero1972',
#                         't': '2023-04-25T02:20:53'},
#                        {'d': '@mario_delgado @PartidoMorenaMx @aguadiana Para '
#                              'que te haces wey @mario_delgado ,sabes muy bien '
#                              'que el bueno es @RicardoMeb 🐯💪',
#                         'i': 10,
#                         'id': 130517616,
#                         'l': 'https://twitter.com/punisherserna/status/1650668910428180480',
#                         'n': 'punisherserna',
#                         't': '2023-04-25T01:11:50'},
#                        {'d': '@AlfredoAlvarezz @RicardoMeb @RicardoMonrealA '
#                              '@delfinagomeza Ricardo Mejía del PT le ha '
#                              'devuelto la esperanza a los Coahuilenses para '
#                              'luchar de pie y no de rodillas con un cacique '
#                              'impuestos. Muy simplón su análisis. Vaya a '
#                              'coahuila como lo hemos hecho otros y compruébelo '
#                              'por sí mismo .',
#                         'i': 19,
#                         'id': 247844816,
#                         'l': 'https://twitter.com/Miriam_Junne/status/1650602421129715720',
#                         'n': 'Miriam_Junne',
#                         't': '2023-04-24T20:47:38'},
#                        {'d': '@Polemista4T @coahuilensepol @AlfredoAlvarezz '
#                              '@RicardoMeb @RicardoMonrealA @delfinagomeza '
#                              '@mario_delgado @yoeNy_33 @4nnaVN_ @taller2006 '
#                              '@Baldo04555156 @saltillotwit @NenaVelasco32 '
#                              '#GuadianaDeclina',
#                         'i': 9,
#                         'id': 2806067203,
#                         'l': 'https://twitter.com/FilipoOcadiz/status/1650589952432799744',
#                         'n': 'FilipoOcadiz',
#                         't': '2023-04-24T19:58:05'},
#                        {'d': '@Polemista4T @taller2006 @Biologictime @yoeNy_33 '
#                              '@SoyLyn05 @Baldo04555156 @saltillotwit '
#                              '@CamaritaPirata @DragonVladimir @EddLite2018 '
#                              '@RicardoMeb Diría una morra imprescindible por '
#                              'ahi:\n'
#                              '"¡Izki N0 3s d3 tw1t3ar a Hu3v0!" 🙄😒',
#                         'i': 8,
#                         'id': 1537661812505825281,
#                         'l': 'https://twitter.com/coahuilensepol/status/1650517095766016004',
#                         'n': 'coahuilensepol',
#                         't': '2023-04-24T15:08:35'},
#                        {'d': '@RicardoMeb @lopezobrador_ No seas oportunista',
#                         'i': 4,
#                         'id': 222986180,
#                         'l': 'https://twitter.com/juancaortizz/status/1650386654698373121',
#                         'n': 'juancaortizz',
#                         't': '2023-04-24T06:30:15'},
#                        {'d': '@RicardoMeb @soy_cristina6 @lopezobrador_ '
#                              'Traidor hipócrita',
#                         'i': 5,
#                         'id': 1478629628,
#                         'l': 'https://twitter.com/aurelio_luis/status/1650384796017721347',
#                         'n': 'aurelio_luis',
#                         't': '2023-04-24T06:22:52'},
#                        {'d': '@mafalda0909 @PepeAstorgaR @RicardoMeb Mañana '
#                              'Reunión del Sector Salud del IMSS con Ricardo '
#                              'Mejía. https://t.co/Ch3BA7MlT3',
#                         'i': 6,
#                         'id': 262718662,
#                         'l': 'https://twitter.com/saltillotwit/status/1650378880266452997',
#                         'n': 'saltillotwit',
#                         't': '2023-04-24T05:59:22'},
#                        {'d': '@tlatoani696 @RicardoMeb @lopezobrador_ Lo de '
#                              '“traidor” se los enseñó #MarioTranzas y uds lo '
#                              'repiten como pericos aunque no sepan ni de lo '
#                              'que hablan.\n'
#                              'Así síguele, mientras en #Coahuila luchamos '
#                              'contra imposiciones de la nomenclatura que en '
#                              'Morena perdió el rumbo .\n'
#                              '\n'
#                              '#RicardoMejíaGOBERNADOR \n'
#                              '#DeclinaGuadaña https://t.co/UTiNa2cQaq',
#                         'i': 9,
#                         'id': 249561098,
#                         'l': 'https://twitter.com/mafalda0909/status/1650364241277272065',
#                         'n': 'mafalda0909',
#                         't': '2023-04-24T05:01:12'},
#                        {'d': '@Luis_Montero36 @RicardoMeb @yoeNy_33 @4nnaVN_ '
#                              '@Baldo04555156 @saltillotwit @taller2006 '
#                              '@SoyLyn05 “Como las chachas” Con ese comentario '
#                              'solo demuestras tu clasismo de mierda. La neta '
#                              'qué alegría que gente como tú no apoye a Mejía.\n'
#                              '\n'
#                              'Ahora entiendo por qué apoyas al delincuente '
#                              'neoliberal Guadiana. Te identificas con él. '
#                              'https://t.co/HFLC88W3yE',
#                         'i': 10,
#                         'id': 609438592,
#                         'l': 'https://twitter.com/Polemista4T/status/1650363185159979008',
#                         'n': 'Polemista4T',
#                         't': '2023-04-24T04:57:00'},
#                        {'d': '@emedranos Pues en #Coahuila andan poniendo '
#                              'mantas por todas las colonias que han recibido '
#                              'despensas raquíticas y tarjetas; solo que no les '
#                              'llegó a los Mpios. el cemento, pintura Lic. '
#                              '@RicardoMeb porque nosotros los #Coahuilenses y '
#                              'las #BenditasRedesSociales los descubrimos a '
#                              'tiempo.❤️🇲🇽❤️',
#                         'i': 6,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650293996516966400',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-24T00:22:04'},
#                        {'d': '@monerohernandez @emedranos Antes me caías bien, '
#                              'pero ahora que te obsesionas por #Morena '
#                              'manipulado por un corrupto como @mario_delgado '
#                              'ya no me hacen gracia tus cartones; prefiero los '
#                              'de #ToñoHelguera QEPD. Defender al Pdte. '
#                              '@lopezobrador_ es una cosa y al tipo ése otra. '
#                              '@RicardoMeb #Coahuila #Gobernador',
#                         'i': 6,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650293145538801667',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-24T00:18:41'},
#                        {'d': '#ULTIMAHORA #DiaDelMigranteCoahuilense Propuesta '
#                              'del próximo Gobernador de #Coahuila Ricardo '
#                              'Mejía Berdeja #Saltillo #Torreon',
#                         'i': 4,
#                         'id': 552210507,
#                         'l': 'https://twitter.com/Saguilar99/status/1651008178841157632',
#                         'n': 'Saguilar99',
#                         't': '2023-04-25T23:39:58'},
#                        {'d': 'ARMANDO GUADIANA no es un OPOSITOR REAL al '
#                              'MOREIRATO en COAHUILA: Mejía ... '
#                              'https://t.co/sPlPu7fFj1 a través de @YouTube '
#                              '@RicardoMeb @HernanGomezB nos escuchó a miles en '
#                              '#Coahuila; el @PTnacionalMX 🇲🇽que lo acogió al '
#                              'igual que el Pdte. @lopezobrador_ somos #PT los '
#                              '#Coahuilenses🇲🇽',
#                         'i': 4,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650985954705051649',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-25T22:11:40'},
#                        {'d': '@coahuilensepol @aguadiana @mario_delgado Tanto '
#                              'que criticaban al @PRI_Nacional y hacen lo mismo '
#                              'con quien no piensa igual que ellos.. @aguadiana '
#                              '@mario_delgado @PartidoMorenaMx @CitlaHM . Ni '
#                              'modo son los frutos de la imposición del '
#                              'candidato, para que no lo vuelvan a hacer. Solo '
#                              'les queda declinar por @RicardoMeb',
#                         'i': 6,
#                         'id': 1297753407218999296,
#                         'l': 'https://twitter.com/YukzulLira/status/1650918714055729169',
#                         'n': 'YukzulLira',
#                         't': '2023-04-25T17:44:28'},
#                        {'d': '@FilipoOcadiz @laverdadconsaul @mario_delgado '
#                              '@RicardoMeb Tienes razón, pero se tiene que '
#                              'hacer.',
#                         'i': 4,
#                         'id': 1222738770769993728,
#                         'l': 'https://twitter.com/vissaeusmorenae/status/1650901007876997129',
#                         'n': 'vissaeusmorenae',
#                         't': '2023-04-25T16:34:07'},
#                        {'d': '@vissaeusmorenae @laverdadconsaul @mario_delgado '
#                              '@RicardoMeb En esas andamos, en exigir, pero '
#                              'luego sucede que lo haces y les molesta.',
#                         'i': 4,
#                         'id': 2806067203,
#                         'l': 'https://twitter.com/FilipoOcadiz/status/1650900571962986496',
#                         'n': 'FilipoOcadiz',
#                         't': '2023-04-25T16:32:23'},
#                        {'d': '@laverdadconsaul @mario_delgado @RicardoMeb No, '
#                              'digo que Berdeja fue el que mandó a la chngada a '
#                              'MORENA. La señora fue a hacer su reclamo en ese '
#                              'foro, su problema fue sacar la foto de ese wey. '
#                              'Ese fue su error.',
#                         'i': 4,
#                         'id': 1222738770769993728,
#                         'l': 'https://twitter.com/vissaeusmorenae/status/1650888545543020544',
#                         'n': 'vissaeusmorenae',
#                         't': '2023-04-25T15:44:35'},
#                        {'d': '@luisghernan @PartidoMorenaMx @mario_delgado '
#                              '@aguadiana @RicardoMeb Aquí, ningún actor tiene '
#                              'disculpa TODOS son unos ambiciosos vulgares... y '
#                              'este acto orquestado por las filas del señor '
#                              'Ricardo Mejía, vergonzoso. Que hagan su campaña '
#                              'en santa paz; ahí está el candidato, el partido '
#                              "y está en la contienda no? Si es el bueno, pa' "
#                              'qué estos actos?🤦',
#                         'i': 11,
#                         'id': 1013995728912384002,
#                         'l': 'https://twitter.com/Hermes7209/status/1650887500758491136',
#                         'n': 'Hermes7209',
#                         't': '2023-04-25T15:40:26'},
#                        {'d': '🗞 Ricardo Mejia llega a sectores olvidados de '
#                              'Saltillo.\n'
#                              '\n'
#                              '@RicardoMeb candidato a la gubernatura de '
#                              'Coahuila por el Partido del Trabajo se '
#                              'compromete con mejorar infraestructura '
#                              'hospitalaria y mejorares condiciones de los '
#                              'trabajadores de la salud.📑 '
#                              'https://t.co/x5ouxltSOu https://t.co/mVycKOAsa2',
#                         'i': 5,
#                         'id': 220236304,
#                         'l': 'https://twitter.com/RutaElectoralmx/status/1650868257987887104',
#                         'n': 'RutaElectoralmx',
#                         't': '2023-04-25T14:23:59'},
#                        {'d': '@cardonamex @mario_delgado @RicardoMeb '
#                              '@aguadiana Soy Coahuilense, soy de oposicion a '
#                              'Morena, son unas basuras humanas....\n'
#                              'Pero no mmen, a poco le van a dejar el micro a '
#                              'medio mundo, y que te tomen el estrado para '
#                              'shingarte?\n'
#                              'Parfavaaaarr',
#                         'i': 5,
#                         'id': 57796243,
#                         'l': 'https://twitter.com/trevinonavejar/status/1650859588709924864',
#                         'n': 'trevinonavejar',
#                         't': '2023-04-25T13:49:32'},
#                        {'d': '@DaniArfi @RicardoMeb No aceptó los resultados, '
#                              'de hacerlo, habría trabajado en la campaña y '
#                              'quizás habría la posibilidad de ganarle al '
#                              'PRIAN.',
#                         'i': 11,
#                         'id': 62664348,
#                         'l': 'https://twitter.com/ZuritaCarpio/status/1650858368989556737',
#                         'n': 'ZuritaCarpio',
#                         't': '2023-04-25T13:44:41'},
#                        {'d': '@saltillotwit @RicardoMeb '
#                              'https://t.co/kkz19LQltY',
#                         'i': 4,
#                         'id': 1259207429415411716,
#                         'l': 'https://twitter.com/Alextrat069/status/1650846654575042560',
#                         'n': 'Alextrat069',
#                         't': '2023-04-25T12:58:08'},
#                        {'d': '@Camemual @aguadiana @mario_delgado @RicardoMeb '
#                              '@PartidoMorenaMx Después una persona quería ver '
#                              'si estaba segura pero no la dejaron '
#                              'https://t.co/LK6EQFwfNi',
#                         'i': 6,
#                         'id': 117205631,
#                         'l': 'https://twitter.com/Kikelabastida/status/1650779172397109248',
#                         'n': 'Kikelabastida',
#                         't': '2023-04-25T08:29:59'},
#                        {'d': '@aguadiana Tú eres el elegido de Mario Delgado, '
#                              '@RicardoMeb es el elegido del pueblo, aunque les '
#                              'duela.',
#                         'i': 4,
#                         'id': 1250651662684958721,
#                         'l': 'https://twitter.com/EffiePalacios/status/1650762568267603969',
#                         'n': 'EffiePalacios',
#                         't': '2023-04-25T07:24:00'},
#                        {'d': '@DiegodelBosqueV @aguadiana @mario_delgado '
#                              '@RicardoMeb @PartidoMorenaMx Que haya salido '
#                              'caminando, no significa que no la hayan '
#                              'golpeado. Casi puros hombres en el escenario y '
#                              'nadie logró poner orden entre las morenistas.',
#                         'i': 22,
#                         'id': 183253341,
#                         'l': 'https://twitter.com/Camemual/status/1650746379042451458',
#                         'n': 'Camemual',
#                         't': '2023-04-25T06:19:40'},
#                        {'d': '@Camemual @aguadiana @mario_delgado @RicardoMeb '
#                              '@PartidoMorenaMx No fueron 2, fueron como 6, '
#                              'entre unos y otros entre ellos hombres, además '
#                              'la mantuvieron 20 minutos tras bambalinas, nos '
#                              'negaron el acceso para saber como estaba',
#                         'i': 10,
#                         'id': 1537661812505825281,
#                         'l': 'https://twitter.com/coahuilensepol/status/1650742651275075586',
#                         'n': 'coahuilensepol',
#                         't': '2023-04-25T06:04:52'},
#                        {'d': '@liliaaguilarmx @RicardoMeb @aguadiana '
#                              '@mario_delgado El Tigre Coahuilense ya despertó '
#                              'https://t.co/UXqwBKe46s',
#                         'i': 6,
#                         'id': 609438592,
#                         'l': 'https://twitter.com/Polemista4T/status/1650737209874546688',
#                         'n': 'Polemista4T',
#                         't': '2023-04-25T05:43:14'},
#                        {'d': '@RicardoMeb Con estas demoledoras palabras usted '
#                              'acaba de ganarse mi voto. Me gustó su trabajo al '
#                              'lado de nuestro Presi y de la Secretaria Rosa '
#                              'Isela Rdz.  Me gusta su fuerza y su valentía '
#                              'pero sobre todo su amor por Coahuila. Siga '
#                              'adelante. Le mando un abrazo desde Kyle, Texas.',
#                         'i': 14,
#                         'id': 582231434,
#                         'l': 'https://twitter.com/AliteyU/status/1650711476682801155',
#                         'n': 'AliteyU',
#                         't': '2023-04-25T04:00:59'},
#                        {'d': '@RicardoMeb',
#                         'i': 4,
#                         'id': 262718662,
#                         'l': 'https://twitter.com/saltillotwit/status/1650694735378481153',
#                         'n': 'saltillotwit',
#                         't': '2023-04-25T02:54:27'},
#                        {'d': '@RicardoMeb @Pablo_CesarL Cómo sea, tu no tienes '
#                              'palabra,\n'
#                              'Firmaste un convenio de acuerdo en que '
#                              'respetarías la encuesta y al ganador, no lo '
#                              'hiciste, con tampoco tuviste el valor de ir y '
#                              'renunciar en persona con el presidente,\n'
#                              'No tienes palabra, no respetas los acuerdos.👎🐀',
#                         'i': 10,
#                         'id': 1183096089567813635,
#                         'l': 'https://twitter.com/ReynaldoMagal/status/1650687108003110912',
#                         'n': 'ReynaldoMagal',
#                         't': '2023-04-25T02:24:09'},
#                        {'d': '#VIDEO I Una mujer subió al templete mientras '
#                              '@mario_delgado se encontraba dando un mensaje en '
#                              'un evento de campaña de @aguadiana; cuando la '
#                              'situación parecía controlada, la manifestante '
#                              'sacó una lona de @RicardoMeb, la cual le fue '
#                              'arrebatada. https://t.co/HNo1zPbSSE',
#                         'i': 5,
#                         'id': 137474821,
#                         'l': 'https://twitter.com/politicomx/status/1650682790902661122',
#                         'n': 'politicomx',
#                         't': '2023-04-25T02:07:00'},
#                        {'d': '@mafalda0909 @saltillotwit @AragonEquity '
#                              '@RicardoMeb @aguadiana Al contrario MORENA debe '
#                              'recular y darle el apoyó al verdadero Cambió que '
#                              'es RICARDO MEJIA BERDEJA.......Vamos por el PT '
#                              'https://t.co/c0CoIryNHv',
#                         'i': 4,
#                         'id': 1526565195937681408,
#                         'l': 'https://twitter.com/SergioA68157036/status/1650682305202077698',
#                         'n': 'SergioA68157036',
#                         't': '2023-04-25T02:05:04'},
#                        {'d': '@AragonEquity @RicardoMeb @aguadiana Yo le '
#                              'recomiendo elegir al más calificado ☝🏻 y es RMB '
#                              '! El Senador @aguadiana apenas se sostiene en '
#                              'pie, y ni hablar d su incapacidad Mental y '
#                              'verbal q es aun peor! Porfavor lo q ud pide es q '
#                              'traicionemos a ntro Amado Coahuila y su gente '
#                              'buena. Ya tenemos Tigre , sr. ⏳⚖️🐅❤️🇲🇽',
#                         'i': 4,
#                         'id': 197234131,
#                         'l': 'https://twitter.com/melidiazmoll/status/1650679326830997505',
#                         'n': 'melidiazmoll',
#                         't': '2023-04-25T01:53:14'},
#                        {'d': '@laverdadconsaul @RicardoMeb Nouuu! La Enorme '
#                              'deuda está en otros bancos ! Consulta la web👀',
#                         'i': 4,
#                         'id': 197234131,
#                         'l': 'https://twitter.com/melidiazmoll/status/1650671007043035136',
#                         'n': 'melidiazmoll',
#                         't': '2023-04-25T01:20:10'},
#                        {'d': '@MarcosDelado @RicardoMeb @manolojim Buenas '
#                              'vibras de parte de toda la ideología de '
#                              'izquierda a nivel nacional, son nuestra '
#                              'evidencia de que no es la encuesta la mejor '
#                              'forma de nombrar nuestros candidatos y que se '
#                              'deben ya formar los comités municipales en '
#                              'MORENA Por que no existen en el país @RicardoMeb '
#                              'VIVA LA 4T',
#                         'i': 5,
#                         'id': 1195790388067520513,
#                         'l': 'https://twitter.com/White_Rabbit_MR/status/1650650401161486337',
#                         'n': 'White_Rabbit_MR',
#                         't': '2023-04-24T23:58:17'},
#                        {'d': '@RicardoMeb @Polemista4T @AlfredoAlvarezz '
#                              '@RicardoMonrealA @delfinagomeza @mario_delgado '
#                              '@yoeNy_33 @4nnaVN_ @taller2006 @saltillotwit '
#                              '@NenaVelasco32 Así o más pagadas? Mi estimado '
#                              'Ricardo https://t.co/wJZsgD2dks',
#                         'i': 6,
#                         'id': 1378845380960419845,
#                         'l': 'https://twitter.com/Baldo04555156/status/1650634867162357760',
#                         'n': 'Baldo04555156',
#                         't': '2023-04-24T22:56:34'},
#                        {'d': '@coahuilensepol @Saguilar99 @AlfredoAlvarezz '
#                              '@RicardoMeb @RicardoMonrealA @delfinagomeza Los '
#                              'chapulínes',
#                         'i': 5,
#                         'id': 1584363768842047488,
#                         'l': 'https://twitter.com/MarcosDelado/status/1650617113508290562',
#                         'n': 'MarcosDelado',
#                         't': '2023-04-24T21:46:01'},
#                        {'d': '@RicardoMeb @Polemista4T @AlfredoAlvarezz '
#                              '@RicardoMonrealA @delfinagomeza @mario_delgado '
#                              '@yoeNy_33 @4nnaVN_ @taller2006 @Baldo04555156 '
#                              '@saltillotwit @NenaVelasco32 No entienden que '
#                              'quienes están con usted,  NUNCA votarían por un '
#                              'cacique explotador y despojador  de campesinos '
#                              'que es amigo del Peñanieto que incubaron los '
#                              'Moreira.\n'
#                              '\n'
#                              'En usted encontraron una opción de por quién '
#                              'votar que antes no tenían.',
#                         'i': 7,
#                         'id': 92668129,
#                         'l': 'https://twitter.com/patinegrete/status/1650609543867695104',
#                         'n': 'patinegrete',
#                         't': '2023-04-24T21:15:56'},
#                        {'d': '@PollsMX_ @manolojim @aguadiana @RicardoMeb '
#                              '@PRICoahuila @shamir_fdz @Veronica_mtz '
#                              '@SalazarLuisFer @BenjaminRoblesM @danysantoyo_ '
#                              'Fake News. https://t.co/KKemZLLTtc',
#                         'i': 3,
#                         'id': 609438592,
#                         'l': 'https://twitter.com/Polemista4T/status/1650595116166291457',
#                         'n': 'Polemista4T',
#                         't': '2023-04-24T20:18:36'},
#                        {'d': 'No queremos que solo en campaña se prometa '
#                              'atender a la niñez de #Coahuila Se necesita un '
#                              'escrutinio severo a pasadas administraciones '
#                              '#Priístas por casos de adopción con personas que '
#                              'no cumplían los requisitos que exige la #Ley '
#                              'Lic. @RicardoMeb y hoy se encuentran en el '
#                              'olvido. https://t.co/q2RoPvHJNh',
#                         'i': 3,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650576080787619841',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-24T19:02:58'},
#                        {'d': '@coahuilensepol @taller2006 @Biologictime '
#                              '@yoeNy_33 @SoyLyn05 @Baldo04555156 @saltillotwit '
#                              '@CamaritaPirata @DragonVladimir @EddLite2018 '
#                              '@RicardoMeb Tu paisana ya da pena ajena, '
#                              'maromeando todo el tiempo para lavarle la cara a '
#                              'la dirigencia de morena.',
#                         'i': 7,
#                         'id': 609438592,
#                         'l': 'https://twitter.com/Polemista4T/status/1650540148176871425',
#                         'n': 'Polemista4T',
#                         't': '2023-04-24T16:40:11'},
#                        {'d': '@mafalda0909 @PepeAstorgaR @RicardoMeb '
#                              'https://t.co/yrhoz2p3dD',
#                         'i': 2,
#                         'id': 262718662,
#                         'l': 'https://twitter.com/saltillotwit/status/1650382075428478976',
#                         'n': 'saltillotwit',
#                         't': '2023-04-24T06:12:04'},
#                        {'d': '@Polemista4T @mario_delgado @4nnaVN_ '
#                              '@Baldo04555156 @Biologictime @DragonVladimir '
#                              '@taller2006 @yoeNy_33 @saltillotwit @BebedeIuz '
#                              '@NenaVelasco32 @SarinMx Armando Guadiana '
#                              '@aguadiana nomás no levanta y va en caída libre… '
#                              'Ricardo Mejía Berdeja @RicardoMeb Ganará la '
#                              'elección a #Gobernador en nuestro estado '
#                              '#Coahuila',
#                         'i': 9,
#                         'id': 456975716,
#                         'l': 'https://twitter.com/jorgewb27/status/1650375845083578368',
#                         'n': 'jorgewb27',
#                         't': '2023-04-24T05:47:18'},
#                        {'d': '#Saltillo #Coahuila #Monclova #Torreon #Acuña '
#                              '#PiedrasNegras #Mexico \u2066@RicardoMeb\u2069 \n'
#                              '\n'
#                              '(PRECAUCIÓN CONTIENE PALABRAS QUE PUEDEN SER '
#                              'SENSIBLES PARA ALGUNAS PERSONAS) '
#                              'https://t.co/1cHaQDtMiq',
#                         'i': 8,
#                         'id': 262718662,
#                         'l': 'https://twitter.com/saltillotwit/status/1650373964827377664',
#                         'n': 'saltillotwit',
#                         't': '2023-04-24T05:39:50'},
#                        {'d': '@RicardoMeb @lopezobrador_ Traidor!!',
#                         'i': 4,
#                         'id': 1263612323668701185,
#                         'l': 'https://twitter.com/Alicia84659038/status/1650370911651127297',
#                         'n': 'Alicia84659038',
#                         't': '2023-04-24T05:27:42'},
#                        {'d': '@PepeAstorgaR @RicardoMeb Como micos amaestrados '
#                              'llegan a escupir su frustración gritando lo que '
#                              'ni entienden.\n'
#                              'El único traidor es #MarioTranzas y andas de '
#                              '“quedabien” para que  te siga beneficiando.\n'
#                              'Síguele en tu piano, no se te olvide: los '
#                              'coahuilenses decidimos en COAHUILA \n'
#                              '\n'
#                              '#RicardoMejíaGOBERNADOR',
#                         'i': 6,
#                         'id': 249561098,
#                         'l': 'https://twitter.com/mafalda0909/status/1650362526922678272',
#                         'n': 'mafalda0909',
#                         't': '2023-04-24T04:54:23'},
#                        {'d': 'Ahí te hablan @mario_delgado y más vale que '
#                              'apoye #Guadiana al Lic. @RicardoMeb pues es una '
#                              'burla para el pueblo #Coahuilense qué hayas '
#                              'puesto a un bufón corrupto. Qué poca seriedad '
#                              'tienes; pero recuerda: #CoahuilaSufre y el '
#                              '@PTnacionalMX éste 4 de junio brillará por todo '
#                              'el Edo.',
#                         'i': 6,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650344007531130883',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-24T03:40:47'},
#                        {'d': '#ElOctágono I Al ver mi talante crítico y que la '
#                              'gente sintió que por fin había alguien que los '
#                              'defendía, fue la propia gente la que me fue '
#                              'pidiendo que participara, explica @RicardoMeb su '
#                              'candidatura alterna a la 4T en Coahuila▶ '
#                              'https://t.co/5HlNklKWh0 https://t.co/d0KNGgYCzx',
#                         'i': 17,
#                         'id': 164337327,
#                         'l': 'https://twitter.com/laoctavadigital/status/1650334496326049795',
#                         'n': 'laoctavadigital',
#                         't': '2023-04-24T03:03:00'},
#                        {'d': '#ElOctágono I Más allá de las bromas del señor '
#                              '@aguadiana, la verdad él no es un opositor real. '
#                              'El estado requería un opositor que cuestione a '
#                              'los exgobernadores y al moreirato, dijo '
#                              '@RicardoMeb▶ https://t.co/5HlNklLu6y '
#                              'https://t.co/Pg5vrFPYgg',
#                         'i': 15,
#                         'id': 164337327,
#                         'l': 'https://twitter.com/laoctavadigital/status/1650330217607737345',
#                         'n': 'laoctavadigital',
#                         't': '2023-04-24T02:46:00'},
#                        {'d': '@RicardoMeb @manolojim @rubenmoreiravdz Para '
#                              'sacar a los tranzas del PRI se necesitan unir '
#                              'morena y PT y UDC... también MC',
#                         'i': 3,
#                         'id': 738180090,
#                         'l': 'https://twitter.com/carlosx66/status/1650325912204763138',
#                         'n': 'carlosx66',
#                         't': '2023-04-24T02:28:53'},
#                        {'d': '@NenaVelasco32 @catrina_nortena @Polemista4T '
#                              '@saltillotwit @AntonioChairesC @RicardoMeb '
#                              '@rikiricardof No sirve de nada denunciar a '
#                              '@twitterdeguro, NUNCA atienden una queja, ¿ '
#                              'serán instrucciones de @elonmusk ? \n'
#                              '\n'
#                              'El formulario para denunciar es un trabalenguas '
#                              'y cuando terminas recibes un correo diciendo que '
#                              'tu queja no procede .\n'
#                              '\n'
#                              '¡Hay q soportar a la gente podrida y cobarde!',
#                         'i': 5,
#                         'id': 249561098,
#                         'l': 'https://twitter.com/mafalda0909/status/1650307373624336384',
#                         'n': 'mafalda0909',
#                         't': '2023-04-24T01:15:13'},
#                        {'d': '@DiegodelBosqueV @Camemual @aguadiana '
#                              '@mario_delgado @RicardoMeb @PartidoMorenaMx Que '
#                              'respuesta tan pndeja...  🤦🏻\u200d♂️',
#                         'i': 5,
#                         'id': 77143996,
#                         'l': 'https://twitter.com/victorhy/status/1651011792770834432',
#                         'n': 'victorhy',
#                         't': '2023-04-25T23:54:20'},
#                        {'d': '@Camemual @aguadiana @mario_delgado @RicardoMeb '
#                              '@PartidoMorenaMx Jajaja si fuese en tiempos '
#                              'dónde no se podía registrar la situación en '
#                              'video la hubiesen linchado desaparecido quemado '
#                              'descuartizado',
#                         'i': 3,
#                         'id': 364703816,
#                         'l': 'https://twitter.com/tinsit0/status/1651007096693968901',
#                         'n': 'tinsit0',
#                         't': '2023-04-25T23:35:40'},
#                        {'d': '@Polemista4T @RicardoMeb @4nnaVN_ @yoeNy_33 '
#                              '@taller2006 @BebedeIuz @Baldo04555156 '
#                              '@saltillotwit @RicardoMeb 🇲🇽#Gobernador🇲🇽 de '
#                              '#Coahuila🇲🇽 @PTnacionalMX 🇲🇽💯 '
#                              'https://t.co/bHZVF89iR9',
#                         'i': 3,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650988310087749633',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-25T22:21:01'},
#                        {'d': '@cardonamex @mario_delgado @RicardoMeb '
#                              '@aguadiana Q bonita familia @PartidoMorenaMx  '
#                              '#MorenaCuevaDeDelincuentes #MorenaNidoDeRatas',
#                         'i': 1,
#                         'id': 197513609,
#                         'l': 'https://twitter.com/Eduardo_Garduno/status/1650983504253943815',
#                         'n': 'Eduardo_Garduno',
#                         't': '2023-04-25T22:01:55'},
#                        {'d': '#Entrevista\n'
#                              'Ricardo Mejía Berdeja (@RicardoMeb) #candidato a '
#                              '#gobernador de #Coahuila por el '
#                              '#PartidoDelTrabajo:\n'
#                              '“Vamos a crear una nueva #PolicíaEstatal; '
#                              'condenamos la #violencia contra #animales y '
#                              'vamos a crear un centro de atención #animal. '
#                              'Promoveremos #cultura de protección… '
#                              'https://t.co/slxOOpMd34',
#                         'i': 1,
#                         'id': 2996136309,
#                         'l': 'https://twitter.com/AdriDelgadoRuiz/status/1650975581826064388',
#                         'n': 'AdriDelgadoRuiz',
#                         't': '2023-04-25T21:30:27'},
#                        {'d': 'Este hombre está igual que #JosephGoebbels quien '
#                              'era conocido por su profundo #antisemitismo Lic. '
#                              '@RicardoMeb en este caso #AntiObradorismo y que '
#                              'a base de repetir mentiras estilo #Moreira y '
#                              '#ElGobiernoDeLaGente embaucó a la sociedad '
#                              'alemana quien padecía una recesión cruda 🧵1/2',
#                         'i': 2,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650967882556112903',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-25T20:59:51'},
#                        {'d': '@luisghernan @PartidoMorenaMx @mario_delgado '
#                              '@aguadiana @RicardoMeb La señora llego agresiva '
#                              'a provocar nunca le faltaron al respeto\n'
#                              'No mamen.',
#                         'i': 2,
#                         'id': 3166758466,
#                         'l': 'https://twitter.com/luisfer70931331/status/1650960158980206603',
#                         'n': 'luisfer70931331',
#                         't': '2023-04-25T20:29:09'},
#                        {'d': '@lvlexico #NoMásPRIAN 👇\n'
#                              '#Coahuila con @RicardoMeb\n'
#                              '@PTnacionalMX 🇲🇽⚖️🇲🇽 https://t.co/GdInwEihyi',
#                         'i': 3,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650957241019781121',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-25T20:17:34'},
#                        {'d': '@cardonamex @mario_delgado @RicardoMeb '
#                              '@aguadiana Pleito entre chairos, entre tribus '
#                              'pues. Y asi será hasta 2024.',
#                         'i': 2,
#                         'id': 268499809,
#                         'l': 'https://twitter.com/marolo6001/status/1650954381850705921',
#                         'n': 'marolo6001',
#                         't': '2023-04-25T20:06:12'},
#                        {'d': '@taller2006 @saltillotwit @mario_delgado junto '
#                              'con @RicardoMonrealA se estrellarán contra la '
#                              'fuerza de los #Coahuilenses al no aceptar más '
#                              '#imposiciones. Los #Moreira y todos los que les '
#                              'suplieron y siguieron, nos tienen sin esperanza '
#                              'alguna. @RicardoMeb nos la ha devuelto como el '
#                              'Pdte. @lopezobrador_ 🇲🇽',
#                         'i': 4,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650952665914802176',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-25T19:59:23'},
#                        {'d': '@noefgarza @luisghernan @PartidoMorenaMx '
#                              '@mario_delgado @aguadiana @RicardoMeb '
#                              '@DiegodelBosqueV Han hecho a un lado a los '
#                              'militantes de MORENA',
#                         'i': 2,
#                         'id': 1008442797790191616,
#                         'l': 'https://twitter.com/HablareLaVerdad/status/1650948580956598272',
#                         'n': 'HablareLaVerdad',
#                         't': '2023-04-25T19:43:09'},
#                        {'d': '@cardonamex @mario_delgado @RicardoMeb '
#                              '@aguadiana Ni ellos mismo ya se cren en las '
#                              'mentiras., ya entre ellos ni se cren las '
#                              'mentiras., ya estan viendo la clase se corruptos '
#                              'mafiosos que son., y ahora usan a guaruras '
#                              'armados a  amedrentar y callar ala gente.  Esa '
#                              'es la manera que si no estas con ellos ., asi te '
#                              'tratan',
#                         'i': 2,
#                         'id': 309093007,
#                         'l': 'https://twitter.com/TheRussoG/status/1650946087903977472',
#                         'n': 'TheRussoG',
#                         't': '2023-04-25T19:33:15'},
#                        {'d': '@Polemista4T @RicardoMeb @4nnaVN_ @yoeNy_33 '
#                              '@taller2006 @BebedeIuz @Baldo04555156 '
#                              '@saltillotwit @NenaVelasco32 @mario_delgado '
#                              'debería declinar @aguadiana a favor de '
#                              '@RicardoMeb y unirse a favor del mov #4T',
#                         'i': 3,
#                         'id': 100844676,
#                         'l': 'https://twitter.com/AlbertoSosaN/status/1650944237968523264',
#                         'n': 'AlbertoSosaN',
#                         't': '2023-04-25T19:25:54'},
#                        {'d': 'Que tiene que hacer la Sra en un mitin de '
#                              '@aguadiana ??\n'
#                              '\n'
#                              'Su preferencia es por @RicardoMeb y está bien, '
#                              'que vaya y convenza a la ciudadanía a votar por '
#                              'el, #ConductaReprobable',
#                         'i': 1,
#                         'id': 1058462699040980993,
#                         'l': 'https://twitter.com/MiedoImplantado/status/1650923703830712320',
#                         'n': 'MiedoImplantado',
#                         't': '2023-04-25T18:04:18'},
#                        {'d': '@cardonamex @mario_delgado @RicardoMeb '
#                              '@aguadiana https://t.co/bRsCNsMP0n',
#                         'i': 2,
#                         'id': 2620789539,
#                         'l': 'https://twitter.com/Guadalu41297779/status/1650920666235916289',
#                         'n': 'Guadalu41297779',
#                         't': '2023-04-25T17:52:14'},
#                        {'d': '@cardonamex @mario_delgado @RicardoMeb '
#                              '@aguadiana https://t.co/w9wcCUuAnM',
#                         'i': 2,
#                         'id': 2620789539,
#                         'l': 'https://twitter.com/Guadalu41297779/status/1650919862997319682',
#                         'n': 'Guadalu41297779',
#                         't': '2023-04-25T17:49:02'},
#                        {'d': '@YukzulLira @aguadiana @mario_delgado '
#                              '@PRI_Nacional @PartidoMorenaMx @CitlaHM '
#                              '@RicardoMeb Durante todo el evento Paloma '
#                              'Candidata Dto 1, Jacobo Candidato dto 2, Del '
#                              'Bosque, Guadiana y Mario Delgado solo se '
#                              'colgaron de los resultados del Gob Federal, cero '
#                              'propuestas y puro decir con "Ya saben quien" '
#                              'parecían qué les daría salpullido decir Andrés '
#                              'Manuel 🙄',
#                         'i': 4,
#                         'id': 1537661812505825281,
#                         'l': 'https://twitter.com/coahuilensepol/status/1650919678829801473',
#                         'n': 'coahuilensepol',
#                         't': '2023-04-25T17:48:18'},
#                        {'d': '@luisghernan @PartidoMorenaMx @mario_delgado '
#                              '@aguadiana @RicardoMeb La tipa parece panista',
#                         'i': 2,
#                         'id': 1179567457293492225,
#                         'l': 'https://twitter.com/PilardelaMaza1/status/1650908617682436104',
#                         'n': 'PilardelaMaza1',
#                         't': '2023-04-25T17:04:21'},
#                        {'d': '@Juanyol66Juany @luisghernan @PartidoMorenaMx '
#                              '@mario_delgado @aguadiana @RicardoMeb Exacto... '
#                              'Berdejo se vendió al juego de la derecha.',
#                         'i': 3,
#                         'id': 979886366069682177,
#                         'l': 'https://twitter.com/MirraSara1/status/1650902967753621519',
#                         'n': 'MirraSara1',
#                         't': '2023-04-25T16:41:54'},
#                        {'d': '@gcastroibarra @AnaPOrdorica @PartidoMorenaQ '
#                              '@marisolgase @CitlaHM @mario_delgado @calbert57 '
#                              '@PartidoMorenaMx @Yoltzin78 @FAFierroP '
#                              '@SocialDmocrata_ Es el resultado como el de Ags. '
#                              'y no lo quieren reconocer. Aún están a tiempo. '
#                              'Todo indicaba qué la favorita era la candidata '
#                              'de @PartidoMorenaMx llega @mario_delgado y gana '
#                              'la #Panista 👈\n'
#                              'En #Coahuila impone a #Guadiana y sabía el '
#                              'favorito era @RicardoMeb @delfinagomeza ¡Ojo! 👀',
#                         'i': 2,
#                         'id': 1442231135287742469,
#                         'l': 'https://twitter.com/NenaVelasco32/status/1650900574978686980',
#                         'n': 'NenaVelasco32',
#                         't': '2023-04-25T16:32:23'},
#                        {'d': '@luisghernan @PartidoMorenaMx @mario_delgado '
#                              '@aguadiana @RicardoMeb Pero que necesidad, '
#                              'imposiciones llevan a esto.',
#                         'i': 1,
#                         'id': 305088047,
#                         'l': 'https://twitter.com/Gorgonio_70/status/1650900538853306369',
#                         'n': 'Gorgonio_70',
#                         't': '2023-04-25T16:32:15'},
#                        {'d': '@Miriam_Junne @mario_delgado @PartidoMorenaMx '
#                              '@aguadiana Totalmente de acuerdo!! El Lic. '
#                              '@RicardoMeb está imparable y el #CaciqueGuadaña '
#                              '🤡 lo sabe, está desesperado...',
#                         'i': 2,
#                         'id': 72603559,
#                         'l': 'https://twitter.com/G_0deVil/status/1650899266804563969',
#                         'n': 'G_0deVil',
#                         't': '2023-04-25T16:27:12'},
#                        {'d': '@Hermes7209 @FilipoOcadiz @laverdadconsaul '
#                              '@mario_delgado @RicardoMeb Exacto 👊',
#                         'i': 3,
#                         'id': 1222738770769993728,
#                         'l': 'https://twitter.com/vissaeusmorenae/status/1650899152400957440',
#                         'n': 'vissaeusmorenae',
# ...
# parsing row 1327
# parsing row 1328
# parsing row 1329
# parsing row 1330
# parsing row 1331
# parsing row 1332
# parsing row 1333
# parsing row 1334
# parsing row 1335
# parsing row 1336
# parsing row 1337
# parsing row 1338
# parsing row 1339
# parsing row 1340
# parsing row 1341
# parsing row 1342
# parsing row 1343
# parsing row 1344
# parsing row 1345
# parsing row 1346
# parsing row 1347
# parsing row 1348
# parsing row 1349
# parsing row 1350
# parsing row 1351
# parsing row 1352
# parsing row 1353
# parsing row 1354
# parsing row 1355
# parsing row 1356
# parsing row 1357
# parsing row 1358
# parsing row 1359
# parsing row 1360
# parsing row 1361
# parsing row 1362
# parsing row 1363
# parsing row 1364
# parsing row 1365
# parsing row 1366
# parsing row 1367
# parsing row 1368
# parsing row 1369
# parsing row 1370
# parsing row 1371
# parsing row 1372
# parsing row 1373
# parsing row 1374
# parsing row 1375
# parsing row 1376
# parsing row 1377
# parsing row 1378
# parsing row 1379
# parsing row 1380
# parsing row 1381
# parsing row 1382
# parsing row 1383
# parsing row 1384
# parsing row 1385
# parsing row 1386
# parsing row 1387
# parsing row 1388
# parsing row 1389
# parsing row 1390
# parsing row 1391
# parsing row 1392
# parsing row 1393
# parsing row 1394
# parsing row 1395
# parsing row 1396
# parsing row 1397
# parsing row 1398
# parsing row 1399
# parsing row 1400
# parsing row 1401
# parsing row 1402
# parsing row 1403
# parsing row 1404
# parsing row 1405
# parsing row 1406
# parsing row 1407
# parsing row 1408
# parsing row 1409
# parsing row 1410
# parsing row 1411
# parsing row 1412
# parsing row 1413
# parsing row 1414
# parsing row 1415
# parsing row 1416
# parsing row 1417
# parsing row 1418
# parsing row 1419
# parsing row 1420
# parsing row 1421
# parsing row 1422
# parsing row 1423
# parsing row 1424
# parsing row 1425
# parsing row 1426
# parsing row 1427
# parsing row 1428
# parsing row 1429
# parsing row 1430
# parsing row 1431
# parsing row 1432
# parsing row 1433
# parsing row 1434
# parsing row 1435
# parsing row 1436
# parsing row 1437
# parsing row 1438
# parsing row 1439
# parsing row 1440
# parsing row 1441
# parsing row 1442
# parsing row 1443
# parsing row 1444
# parsing row 1445
# parsing row 1446
# parsing row 1447
# parsing row 1448
# parsing row 1449
# parsing row 1450
# parsing row 1451
# parsing row 1452
# parsing row 1453
# parsing row 1454
# parsing row 1455
# parsing row 1456
# parsing row 1457
# parsing row 1458
# parsing row 1459
# parsing row 1460
# parsing row 1461
# parsing row 1462
# parsing row 1463
# parsing row 1464
# parsing row 1465
# parsing row 1466
# parsing row 1467
# parsing row 1468
# parsing row 1469
# parsing row 1470
# parsing row 1471
# parsing row 1472
# parsing row 1473
# parsing row 1474
# parsing row 1475
# parsing row 1476
# parsing row 1477
# parsing row 1478
# parsing row 1479
# parsing row 1480
# parsing row 1481
# parsing row 1482
# parsing row 1483
# parsing row 1484
# parsing row 1485
# parsing row 1486
# parsing row 1487
# parsing row 1488
# parsing row 1489
# parsing row 1490
# parsing row 1491
# parsing row 1492
# parsing row 1493
# parsing row 1494
# parsing row 1495
# parsing row 1496
# parsing row 1497
# parsing row 1498
# parsing row 1499
# parsing row 1500
# parsing row 1501
# parsing row 1502
# parsing row 1503
# parsing row 1504
# parsing row 1505
# parsing row 1506
# parsing row 1507
# parsing row 1508
# parsing row 1509
# parsing row 1510
# parsing row 1511
# parsing row 1512
# parsing row 1513
# parsing row 1514
# parsing row 1515
# parsing row 1516
# parsing row 1517
# parsing row 1518
# parsing row 1519
# parsing row 1520
# parsing row 1521
# parsing row 1522
# parsing row 1523
# parsing row 1524
# parsing row 1525
# parsing row 1526
# parsing row 1527
# parsing row 1528
# parsing row 1529
# parsing row 1530
# parsing row 1531
# parsing row 1532
# parsing row 1533
# parsing row 1534
# parsing row 1535
# parsing row 1536
# parsing row 1537
# parsing row 1538
# parsing row 1539
# parsing row 1540
# parsing row 1541
# parsing row 1542
# parsing row 1543
# parsing row 1544
# parsing row 1545
# parsing row 1546
# parsing row 1547
# parsing row 1548
# parsing row 1549
# parsing row 1550
# parsing row 1551
# parsing row 1552
# parsing row 1553
# parsing row 1554
# parsing row 1555
# parsing row 1556
# parsing row 1557
# parsing row 1558
# parsing row 1559
# parsing row 1560
# parsing row 1561
# parsing row 1562
# parsing row 1563
# parsing row 1564
# parsing row 1565
# parsing row 1566
# parsing row 1567
# parsing row 1568
# parsing row 1569
# parsing row 1570
# parsing row 1571
# parsing row 1572
# parsing row 1573
# parsing row 1574
# parsing row 1575
# parsing row 1576
# parsing row 1577
# parsing row 1578
# parsing row 1579
# parsing row 1580
# parsing row 1581
# parsing row 1582
# parsing row 1583
# parsing row 1584
# parsing row 1585
# parsing row 1586
# parsing row 1587
# parsing row 1588
# parsing row 1589
# parsing row 1590
# parsing row 1591
# parsing row 1592
# parsing row 1593
# parsing row 1594
# parsing row 1595
# parsing row 1596
# parsing row 1597
# parsing row 1598
# parsing row 1599
# parsing row 1600
# parsing row 1601
# parsing row 1602
# parsing row 1603
# parsing row 1604
# parsing row 1605
# parsing row 1606
# parsing row 1607
# parsing row 1608
# parsing row 1609
# parsing row 1610
# parsing row 1611
# parsing row 1612
# parsing row 1613
# parsing row 1614
# parsing row 1615
# parsing row 1616
# parsing row 1617
# parsing row 1618
# parsing row 1619
# parsing row 1620
# parsing row 1621
# parsing row 1622
# parsing row 1623
# parsing row 1624
# parsing row 1625
# parsing row 1626
# parsing row 1627
# parsing row 1628
# parsing row 1629
# parsing row 1630
# parsing row 1631
# parsing row 1632
# parsing row 1633
# parsing row 1634
# parsing row 1635
# parsing row 1636
# parsing row 1637
# parsing row 1638
# parsing row 1639
# parsing row 1640
# parsing row 1641
# parsing row 1642
# parsing row 1643
# parsing row 1644
# parsing row 1645
# parsing row 1646
# parsing row 1647
# parsing row 1648
# parsing row 1649
# parsing row 1650
# parsing row 1651
# parsing row 1652
# parsing row 1653
# parsing row 1654
# parsing row 1655
# parsing row 1656
# parsing row 1657
# parsing row 1658
# parsing row 1659
# parsing row 1660
# parsing row 1661
# parsing row 1662
# parsing row 1663
# parsing row 1664
# parsing row 1665
# parsing row 1666
# parsing row 1667
# parsing row 1668
# parsing row 1669
# parsing row 1670
# parsing row 1671
# parsing row 1672
# parsing row 1673
# parsing row 1674
# parsing row 1675
# parsing row 1676
# parsing row 1677
# parsing row 1678
# parsing row 1679
# parsing row 1680
# parsing row 1681
# parsing row 1682
# parsing row 1683
# parsing row 1684
# parsing row 1685
# parsing row 1686
# parsing row 1687
# parsing row 1688
# parsing row 1689
# parsing row 1690
# parsing row 1691
# parsing row 1692
# parsing row 1693
# parsing row 1694
# parsing row 1695
# parsing row 1696
# parsing row 1697
# parsing row 1698
# parsing row 1699
# parsing row 1700
# parsing row 1701
# parsing row 1702
# parsing row 1703
# parsing row 1704
# parsing row 1705
# parsing row 1706
# parsing row 1707
# parsing row 1708
# parsing row 1709
# parsing row 1710
# parsing row 1711
# parsing row 1712
# parsing row 1713
# parsing row 1714
# parsing row 1715
# parsing row 1716
# parsing row 1717
# parsing row 1718
# parsing row 1719
# parsing row 1720
# parsing row 1721
# parsing row 1722
# parsing row 1723
# parsing row 1724
# parsing row 1725
# parsing row 1726
# parsing row 1727
# parsing row 1728
# parsing row 1729
# parsing row 1730
# parsing row 1731
# parsing row 1732
# parsing row 1733
# parsing row 1734
# parsing row 1735
# parsing row 1736
# parsing row 1737
# parsing row 1738
# parsing row 1739
# parsing row 1740
# parsing row 1741
# parsing row 1742
# parsing row 1743
# parsing row 1744
# parsing row 1745
# parsing row 1746
# parsing row 1747
# parsing row 1748
# parsing row 1749
# parsing row 1750
# parsing row 1751
# parsing row 1752
# parsing row 1753
# parsing row 1754
# parsing row 1755
# parsing row 1756
# parsing row 1757
# parsing row 1758
# parsing row 1759
# parsing row 1760
# parsing row 1761
# parsing row 1762
# parsing row 1763
# parsing row 1764
# parsing row 1765
# parsing row 1766
# parsing row 1767
# parsing row 1768
# parsing row 1769
# parsing row 1770
# parsing row 1771
# parsing row 1772
# parsing row 1773
# parsing row 1774
# parsing row 1775
# parsing row 1776
# parsing row 1777
# parsing row 1778
# parsing row 1779
# parsing row 1780
# parsing row 1781
# parsing row 1782
# parsing row 1783
# parsing row 1784
# parsing row 1785
# parsing row 1786
# parsing row 1787
# parsing row 1788
# parsing row 1789
# parsing row 1790
# parsing row 1791
# parsing row 1792
# parsing row 1793
# parsing row 1794
# parsing row 1795
# parsing row 1796
# parsing row 1797
# parsing row 1798
# parsing row 1799
# parsing row 1800
# parsing row 1801
# parsing row 1802
# parsing row 1803
# parsing row 1804
# parsing row 1805
# parsing row 1806
# parsing row 1807
# parsing row 1808
# parsing row 1809
# parsing row 1810
# parsing row 1811
# parsing row 1812
# parsing row 1813
# parsing row 1814
# parsing row 1815
# parsing row 1816
# parsing row 1817
# parsing row 1818
# parsing row 1819
# parsing row 1820
# parsing row 1821
# parsing row 1822
# parsing row 1823
# parsing row 1824
# parsing row 1825
# parsing row 1826
# parsing row 1827
# parsing row 1828
# parsing row 1829
# parsing row 1830
# parsing row 1831
# parsing row 1832
# parsing row 1833
# parsing row 1834
# parsing row 1835
# parsing row 1836
# parsing row 1837
# parsing row 1838
# parsing row 1839
# parsing row 1840
# parsing row 1841
# parsing row 1842
# parsing row 1843
# parsing row 1844
# parsing row 1845
# parsing row 1846
# parsing row 1847
# parsing row 1848
# parsing row 1849
# parsing row 1850
# parsing row 1851
# parsing row 1852
# parsing row 1853
# parsing row 1854
# parsing row 1855
# parsing row 1856
# parsing row 1857
# parsing row 1858
# parsing row 1859
# parsing row 1860
# parsing row 1861
# parsing row 1862
# parsing row 1863
# parsing row 1864
# parsing row 1865
# parsing row 1866
# parsing row 1867
# parsing row 1868
# parsing row 1869
# parsing row 1870
# parsing row 1871
# parsing row 1872
# parsing row 1873
# parsing row 1874
# parsing row 1875
# parsing row 1876
# parsing row 1877
# parsing row 1878
# parsing row 1879
# parsing row 1880
# parsing row 1881
# parsing row 1882
# parsing row 1883
# parsing row 1884
# parsing row 1885
# parsing row 1886
# parsing row 1887
# parsing row 1888
# parsing row 1889
# parsing row 1890
# parsing row 1891
# parsing row 1892
# parsing row 1893
# parsing row 1894
# parsing row 1895
# parsing row 1896
# parsing row 1897
# parsing row 1898
# parsing row 1899
# parsing row 1900
# parsing row 1901
# parsing row 1902
# parsing row 1903
# parsing row 1904
# parsing row 1905
# parsing row 1906
# parsing row 1907
# parsing row 1908
# parsing row 1909
# parsing row 1910
# parsing row 1911
# parsing row 1912
# parsing row 1913
# parsing row 1914
# parsing row 1915
# parsing row 1916
# parsing row 1917
# parsing row 1918
# parsing row 1919
# parsing row 1920
# parsing row 1921
# parsing row 1922
# parsing row 1923
# parsing row 1924
# parsing row 1925
# parsing row 1926
# parsing row 1927
# parsing row 1928
# parsing row 1929
# parsing row 1930
# parsing row 1931
# parsing row 1932
# parsing row 1933
# parsing row 1934
# parsing row 1935
# parsing row 1936
# parsing row 1937
# parsing row 1938
# parsing row 1939
# parsing row 1940
# parsing row 1941
# parsing row 1942
# parsing row 1943
# parsing row 1944
# parsing row 1945
# parsing row 1946
# parsing row 1947
# parsing row 1948
# parsing row 1949
# parsing row 1950
# parsing row 1951
# parsing row 1952
# parsing row 1953
# parsing row 1954
# parsing row 1955
# parsing row 1956
# parsing row 1957
# parsing row 1958
# parsing row 1959
# parsing row 1960
# parsing row 1961
# parsing row 1962
# parsing row 1963
# parsing row 1964
# parsing row 1965
# parsing row 1966
# parsing row 1967
# parsing row 1968
# parsing row 1969
# parsing row 1970
# parsing row 1971
# parsing row 1972
# parsing row 1973
# parsing row 1974
# parsing row 1975
# parsing row 1976
# parsing row 1977
# parsing row 1978
# parsing row 1979
# parsing row 1980
# parsing row 1981
# parsing row 1982
# parsing row 1983
# parsing row 1984
# parsing row 1985
# parsing row 1986
# parsing row 1987
# parsing row 1988
# parsing row 1989
# parsing row 1990
# parsing row 1991
# parsing row 1992
# parsing row 1993
# parsing row 1994
# parsing row 1995
# parsing row 1996
# parsing row 1997
# parsing row 1998
# parsing row 1999
# parsing row 2000
# parsing row 2001
# parsing row 2002
# parsing row 2003
# parsing row 2004
# parsing row 2005
# parsing row 2006
# parsing row 2007
# parsing row 2008
# parsing row 2009
# parsing row 2010
# parsing row 2011
# parsing row 2012
# parsing row 2013
# parsing row 2014
# parsing row 2015
# parsing row 2016
# parsing row 2017
# parsing row 2018
# parsing row 2019
# parsing row 2020
# parsing row 2021
# parsing row 2022
# parsing row 2023
# parsing row 2024
# parsing row 2025
# parsing row 2026
# parsing row 2027
# parsing row 2028
# parsing row 2029
# parsing row 2030
# parsing row 2031
# parsing row 2032
# parsing row 2033
# parsing row 2034
# parsing row 2035
# parsing row 2036
# parsing row 2037
# parsing row 2038
# parsing row 2039
# parsing row 2040
# parsing row 2041
# parsing row 2042
# parsing row 2043
# parsing row 2044
# parsing row 2045
# parsing row 2046
# parsing row 2047
# parsing row 2048
# parsing row 2049
# parsing row 2050
# parsing row 2051
# parsing row 2052
# parsing row 2053
# parsing row 2054
# parsing row 2055
# parsing row 2056
# parsing row 2057
# parsing row 2058
# parsing row 2059
# parsing row 2060
# parsing row 2061
# parsing row 2062
# parsing row 2063
# parsing row 2064
# parsing row 2065
# parsing row 2066
# parsing row 2067
# parsing row 2068
# parsing row 2069
# parsing row 2070
# parsing row 2071
# parsing row 2072
# parsing row 2073
# parsing row 2074
# parsing row 2075
# parsing row 2076
# parsing row 2077
# parsing row 2078
# parsing row 2079
# parsing row 2080
# parsing row 2081
# parsing row 2082
# parsing row 2083
# parsing row 2084
# parsing row 2085
# parsing row 2086
# parsing row 2087
# parsing row 2088
# parsing row 2089
# parsing row 2090
# parsing row 2091
# parsing row 2092
# parsing row 2093
# parsing row 2094
# parsing row 2095
# parsing row 2096
# parsing row 2097
# parsing row 2098
# parsing row 2099
# parsing row 2100
# parsing row 2101
# parsing row 2102
# parsing row 2103
# parsing row 2104
# parsing row 2105
# parsing row 2106
# parsing row 2107
# parsing row 2108
# parsing row 2109
# parsing row 2110
# parsing row 2111
# parsing row 2112
# parsing row 2113
# parsing row 2114
# parsing row 2115
# parsing row 2116
# parsing row 2117
# parsing row 2118
# parsing row 2119
# parsing row 2120
# parsing row 2121
# parsing row 2122
# parsing row 2123
# parsing row 2124
# parsing row 2125
# parsing row 2126
# parsing row 2127
# parsing row 2128
# parsing row 2129
# parsing row 2130
# parsing row 2131
# parsing row 2132
# parsing row 2133
# parsing row 2134
# parsing row 2135
# parsing row 2136
# parsing row 2137
# parsing row 2138
# parsing row 2139
# parsing row 2140
# parsing row 2141
# parsing row 2142
# parsing row 2143
# parsing row 2144
# parsing row 2145
# parsing row 2146
# parsing row 2147
# parsing row 2148
# parsing row 2149
# parsing row 2150
# parsing row 2151
# parsing row 2152
# parsing row 2153
# parsing row 2154
# parsing row 2155
# parsing row 2156
# parsing row 2157
# parsing row 2158
# parsing row 2159
# parsing row 2160
# parsing row 2161
# parsing row 2162
# parsing row 2163
# parsing row 2164
# parsing row 2165
# parsing row 2166
# parsing row 2167
# parsing row 2168
# parsing row 2169
# parsing row 2170
# parsing row 2171
# parsing row 2172
# parsing row 2173
# parsing row 2174
# parsing row 2175
# parsing row 2176
# parsing row 2177
# parsing row 2178
# parsing row 2179
# parsing row 2180
# parsing row 2181
# parsing row 2182
# parsing row 2183
# parsing row 2184
# parsing row 2185
# parsing row 2186
# parsing row 2187
# parsing row 2188
# parsing row 2189
# parsing row 2190
# parsing row 2191
# parsing row 2192
# parsing row 2193
# parsing row 2194
# parsing row 2195
# parsing row 2196
# parsing row 2197
# parsing row 2198
# parsing row 2199
# parsing row 2200
# parsing row 2201
# parsing row 2202
# parsing row 2203
# parsing row 2204
# parsing row 2205
# parsing row 2206
# parsing row 2207
# parsing row 2208
# parsing row 2209
# parsing row 2210
# parsing row 2211
# parsing row 2212
# parsing row 2213
# Downloading (…)lve/main/config.json:   0%|          | 0.00/925 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/435M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]
# Batch 0 done
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]
# Batch 1 done
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]
# Batch 2 done
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]
# Batch 3 done
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]
# Batch 4 done
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]
# Batch 5 done
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]
# Batch 6 done
# Map:   0%|          | 0/199 [00:00<?, ? examples/s]
# Batch 7 done

# %%
# # infotracer and sentiment: add historical data
generate_infotracer_and_sentiment_table(start_date="2023-04-25",end_date="2023-04-25",ytb_end_date="2023-04-25",update_db=True)

# # network: add historical data
mycursor.execute("DELETE FROM network")
mydb.commit()
print('network table starts')
generate_network_table(start_date="2023-01-01",end_date="2023-04-25",update_db=True)
print('network table done')

# %% [markdown]
# # Daily update

# %%
query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}

# %%
print('##############################')
print('Update starts')

# helper: daily update
# print('helper table starts')
# today = datetime.now(pytz.timezone('America/Mexico_City')).date()
# tomorrow=datetime.now(pytz.timezone('America/Mexico_City')).date() + timedelta(days=1)
# generate_helper_table(start_date=tomorrow, end_date=tomorrow, update_db=True)
# print('helper table done')


# infotracer and sentiment: daily update
print('infotracer and sentiment table start')
# today = datetime.now(pytz.timezone('America/Mexico_City')).date().strftime('%Y-%m-%d')
# tomorrow=(datetime.now(pytz.timezone('America/Mexico_City')).date() + timedelta(days=1)).strftime('%Y-%m-%d')
today='2023-04-16'
tomorrow='2023-04-17'
generate_infotracer_and_sentiment_table(start_date=today, end_date=tomorrow, ytb_end_date=tomorrow,update_db=True)
print('infotracer and sentiment table done')

# wordcloud: daily update
print('wordcloud table starts')
generate_wordcloud_table()
print('wordcloud table done')

# network: daily update
print('network table starts')
generate_network_table(start_date=today, end_date=tomorrow,update_db=True)
print('network table done')

print('Update ends')
print('##############################')

# %%
####################################
##  refresh old data
####################################
'''
This code removes data from 48 hours ago and recollects it because the data 
becomes more stable after that time period. This ensures that we are working 
with the most reliable data possible.
''' 

print('##############################')
print('start refresh')
two_days_ago=(datetime.now(pytz.timezone('America/Mexico_City')).date() - timedelta(days=2)).strftime('%Y-%m-%d')
three_days_ago=(datetime.now(pytz.timezone('America/Mexico_City')).date() - timedelta(days=3)).strftime('%Y-%m-%d')

# delete
# data in db is mexico timezone
infotracer_query="DELETE FROM infotracer WHERE datetime >= '"+three_days_ago+" 18:00:00' AND datetime <= '"+two_days_ago+" 18:00:00'"
sentiment_query="DELETE FROM sentiment WHERE datetime >= '"+three_days_ago+" 18:00:00' AND datetime <= '"+two_days_ago+" 18:00:00'"

mycursor.execute(infotracer_query)
mycursor.execute(sentiment_query)

mydb.commit()
print('old data deleted')

# recollect
print('start recollect')
generate_infotracer_and_sentiment_table(start_date=two_days_ago, end_date=two_days_ago, ytb_end_date=two_days_ago,update_db=True)
print('recollect end')

print('refresh ends')
print('##############################')
