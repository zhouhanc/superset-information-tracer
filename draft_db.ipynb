# %% [markdown]
# <a href="https://colab.research.google.com/github/zhouhanc/superset-information-tracer/blob/main/draft_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# !pip install informationtracer
# !pip install pysentimiento

# %% [markdown]
# # Import

# %%
import os

from informationtracer import informationtracer
import requests
import mysql.connector

import pandas as pd
import numpy as np
import random

import pytz
from pytz import timezone
from datetime import datetime
from datetime import date
from datetime import datetime, timedelta

from pysentimiento.preprocessing import preprocess_tweet
from pysentimiento import create_analyzer


import itertools

import re
import string
from nltk.stem.snowball import SnowballStemmer
import nltk
from gensim import corpora, models
from wordcloud import WordCloud

# %% [markdown]
# # Create database and table

# %%
with open(os.path.expanduser('db_info.txt'), 'r') as f:
    lines = f.readlines()

localhost = lines[0].strip()
username = lines[1].strip()
pw = lines[2].strip()


#connect to database
mydb = mysql.connector.connect(
  host=localhost,
  user=username,
  password=pw
)


mycursor = mydb.cursor()
# create a databse called "dashboard"
#mycursor.execute("CREATE DATABASE dashboard")

# %%
# select database to modify
mycursor.execute("use dashboard")

# delete table
# mycursor.execute("drop table if exists infotracer")
# mycursor.execute("drop table if exists sentiment")
# mycursor.execute("drop table if exists wordcloud")
# mycursor.execute("drop table if exists network")
# mycursor.execute("drop table if exists helper")

# create table
# mycursor.execute("create table infotracer (candidate_name varchar(255), text MediumTEXT, username varchar(255), num_interaction int, datetime timestamp, platform varchar(255) )")
# mycursor.execute("create table sentiment (text MediumTEXT, processed_text MediumTEXT, positive float, neutral float, negative float, label varchar(255),candidate_name varchar(255), platform varchar(255), username varchar(255), num_interaction int, datetime timestamp )")
# mycursor.execute("create table wordcloud (word varchar(255), weight float, candidate_name varchar(255),platform varchar(255))")
# mycursor.execute("create table network (source varchar(255), target varchar(255), weight float, source_cat varchar(255), target_cat varchar(255), source_datetime timestamp, target_datetime timestamp, candidate_name varchar(255))")
# mycursor.execute("create table helper (datetime timestamp,candidate_name varchar(255),label varchar(255),platform varchar(255))")

# %% [markdown]
# delete data

# %%
# mycursor.execute("DELETE FROM infotracer WHERE datetime >= '2023-04-18 18:00:00' AND datetime <= '2023-04-25 18:00:00'")
# mycursor.execute("DELETE FROM sentiment WHERE datetime >= '2023-04-18 18:00:00' AND datetime <= '2023-04-25 18:00:00'")
# mycursor.execute("DELETE FROM network")
# 18:00 is mexico time, when collect still use 00:00 to 23:59
# mydb.commit()

# %% [markdown]
# #ELT helper table

# %%
def generate_helper_table(start_date,end_date,update_db=True):
  
##############################################################################
##  This function generates a helper table that is used to join with other table to fill in time gaps.
##  Records are inserted to table within function.
##############################################################################

  # Define platforms and labels
  platforms = ['facebook','twitter','instagram','youtube','youtube comment']
  labels = ['POS','NEU','NEG']
  candidate_name=['Manolo Jiménez Salinas','Armando Guadiana Tijerina','Ricardo Mejia Berdeja','Lenin Perez Rivera']
  # Generate date range
  date_range = pd.date_range(start=start_date, end=end_date)

  # Generate combinations of platform and label for each date
  date_platform_label = list(itertools.product(date_range, platforms, labels,candidate_name))

  # Create DataFrame
  helper_df = pd.DataFrame(date_platform_label, columns=["datetime", "platform", "label",'candidate_name'])


  if update_db==True:
    # Insert to db
    helper_data = helper_df.apply(tuple, axis=1).tolist()
    # change order of column to fit df
    query="insert into helper (datetime,platform,label, candidate_name) Values(%s,%s,%s,%s);" 
    mycursor.executemany(query,helper_data)
    mydb.commit()

  return

# %% [markdown]
# # ETL for infotracer table

# %%
def convert_time(column):

##############################################################################
##  This function takes the datetime column of any dataframe 
##  and convert utc time to mexico time.
##  This function is part of another function. DO NOT run directly.
##############################################################################

  column=column.apply(lambda x: pytz.utc.localize(x))
  #utc to mexico time
  mexico_tz = timezone('America/Mexico_City')
  convert_timestamp = lambda x: x.astimezone(mexico_tz).replace(tzinfo=None)
  column = column.apply(convert_timestamp)
  return column

# %%
def generate_infotracer_table(start_date,end_date,update_db=True):

########################################################################################
##  This function query data using information tracer, store in df, convert time and insert
##  data into information tracer table. It returns a df of qury result. This result will be used for sentiment analysis.
##  This function is part of another function. DO NOT run directly.
########################################################################################

  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # query with information tracer api
  df=[]

  for candidate, query in query_dict.items():
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date)
    url = "https://informationtracer.com/api/v1/result?token={}&id_hash256={}".format(your_token, id_hash256)
    results = requests.get(url).json() #will get json for all data of keyword, results is a dictionary

    for pf in ['facebook','twitter','instagram','youtube']:
      platform_data=pd.DataFrame(results['posts'][pf], columns=['d','i','n','t'])
      platform_data['platform']=pf
      platform_data['candidate_name']=candidate
      platform_data['t']=pd.to_datetime(platform_data['t'])
      df.append(platform_data)

  df=pd.concat(df)
  df=df.rename(columns={'d':'text','i':'num_interaction','n':'username','t':'datetime'})

  # convert timezone
  df['datetime'] = convert_time(df['datetime'])
  df=df.drop_duplicates()

  print('#################################################')
  print('the shape of infotracer table is:',df.shape)
  print('#################################################')

  if update_db==True:
    # insert to db
    infotracer_data = df.apply(tuple, axis=1).tolist()
    query="insert into infotracer (text,num_interaction,username,datetime,platform,candidate_name) Values(%s,%s,%s,%s,%s,%s);"
    mycursor.executemany(query,infotracer_data)

    mydb.commit()
    # return query result
  return df

# %%
# result416=generate_infotracer_table(start_date='2023-04-16',end_date='2023-04-17',update_db=False)

# %% [markdown]
# # ETL data for sentiment table

# %% [markdown]
# ## youtube comment functions

# %%
##############################################################################
##  NOTE: register youtube API key!
## 
##  Follow instruction here: 
##  https://developers.google.com/youtube/registering_an_application
##
##  One key is enough, more keys can speed up the data collection process
#############################################################################

# read a dictionary of names and values of youtube api key 
API_KEY= {}

with open(os.path.expanduser('youtube_tokens.txt'), 'r') as f:
    for line in f:
        key, value = line.strip().split(',')
        API_KEY[key] = value

API_KEY = list(API_KEY.values())

def search_replies(comment_id):
    headers = {
        'Accept': 'application/json',
    }    

    params = (
        ('part', 'snippet,id'),
        ('parentId', comment_id),
        ('key', random.choice(API_KEY)),
        ('maxResults', '100')        
    )
    
    results = []
    response = requests.get('https://www.googleapis.com/youtube/v3/comments', headers=headers, params=params)
    
    print("Youtube response code --> ", response.status_code)
    if int(response.status_code) > 300:
        print(response.text)
        print('Youtube API v3/videos returns non 200 status code, something is very wrong')
        return results

    results += [item for item in response.json()['items']]
#     print(results)
    nextPageToken = response.json().get('nextPageToken', None)
    
    while nextPageToken:
        print(nextPageToken)
        params = (
            ('part', 'snippet,id'),
            ('parentId', comment_id),
            ('key', random.choice(API_KEY)),
            ('maxResults', '100'),
            ('pageToken', nextPageToken)
        )
        
        response = requests.get('https://www.googleapis.com/youtube/v3/comments', headers=headers, params=params)
        print("Youtube response code --> ", response.status_code)
        if int(response.status_code) > 300:
            print(response.text)
            print('Youtube API v3/videos returns non 200 status code, something is very wrong')
            break
    
        results += [item for item in response.json()['items']]
        nextPageToken = response.json().get('nextPageToken', None)
        
    return results




def search_comments(video_id):        
    headers = {
        'Accept': 'application/json',
    }    

    params = (
        ('part', 'snippet,replies'),
        ('videoId', video_id),
        ('key', random.choice(API_KEY)),
        ('maxResults', '100')        
    )
    
    results = []
    response = requests.get('https://www.googleapis.com/youtube/v3/commentThreads', headers=headers, params=params)
    print("Youtube response code --> ", response.status_code)
    if int(response.status_code) > 300:
        print(response.text)
        print('Youtube API v3/videos returns non 200 status code, something is very wrong')
        return results

    results += [item for item in response.json()['items']]
    nextPageToken = response.json().get('nextPageToken', None)
    
    while nextPageToken:
        print(nextPageToken)
        params = (
            ('part', 'snippet,replies'),
            ('videoId', video_id),
            ('key', random.choice(API_KEY)),
            ('maxResults', '100'),
            ('pageToken', nextPageToken)
        )
        
        response = requests.get('https://www.googleapis.com/youtube/v3/commentThreads', headers=headers, params=params)
        print("Youtube response code --> ", response.status_code)
        if int(response.status_code) > 300:
            print(response.text)
            print('Youtube API v3/videos returns non 200 status code, something is very wrong')
            break
    
        results += [item for item in response.json()['items']]
        nextPageToken = response.json().get('nextPageToken', None)
    
    for i in results:
        if i['snippet']['totalReplyCount'] > 5:
            print('hydrating more comments...')
            i['replies']['comments'] = search_replies(i['id'])
            print(len(i['replies']['comments']))

    # save results    
    return results

# %%
def convert_time_ytb(column):
##############################################################################
##  This function takes the datetime column of any dataframe 
##  and convert utc time to mexico time. For ytb comment only.
##  This function is part of another function. DO NOT run directly.
##############################################################################

  #utc to mexico time
  mexico_tz = timezone('America/Mexico_City')
  convert_timestamp = lambda x: x.astimezone(mexico_tz).replace(tzinfo=None)
  column = column.apply(convert_timestamp)
  return column

# %% [markdown]
# ## youtube query

# %%
def query_youtube_comment(start_date,end_date):
##############################################################################
##  This function use information tracer result to query for youtube comment, 
##  and convert utc time to mexico time.
##  This function is part of another function. DO NOT run directly.
##############################################################################
  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # get video id from information tracer source data
  videoId_dic={}
  for candidate, query in query_dict.items():
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date,skip_result=True)
    url="https://informationtracer.com/loadsource?source={}&id_hash256={}&token={}".format('youtube', id_hash256, your_token)
    results=requests.get(url).json()
    videoId_dic[candidate] = [data['id']['videoId'] for data in results] 
  
  # query comments using youtube api
  ytbcomment_df=[]
  for candidate, videoId_list in videoId_dic.items():
    comment=[]
    username=[]
    likeCount=[]
    date=[]
    for vid in videoId_list:
      if vid!=[]:
        result=search_comments(vid)
        for i in np.arange(0,len(result),1):
          comment.append(result[i]['snippet']['topLevelComment']['snippet']['textDisplay'])
          username.append(result[i]['snippet']['topLevelComment']['snippet']['authorDisplayName'])
          likeCount.append(result[i]['snippet']['topLevelComment']['snippet']['likeCount'])
          date.append(result[i]['snippet']['topLevelComment']['snippet']['publishedAt'])
      ytbcomment= pd.DataFrame({'text': comment, 'num_interaction': likeCount, 
                      'username': username,'datetime': date})
      ytbcomment['platform']='youtube comment'
      ytbcomment['candidate_name']=candidate
      ytbcomment['datetime']=pd.to_datetime(ytbcomment['datetime'])
      ytbcomment_df.append(ytbcomment)
  ytbcomment_df=pd.concat(ytbcomment_df)
  

  # convert timezone
  if ytbcomment_df.empty==False:
    ytbcomment_df['datetime'] = convert_time_ytb(ytbcomment_df['datetime'])
    ytbcomment_df=ytbcomment_df.drop_duplicates()

  print('#################################################')
  print('the shape of youtube comment is:',ytbcomment_df.shape)
  print('#################################################')
  # return query result
  return ytbcomment_df

# %% [markdown]
# ## text process functions

# %%
# remove \n and ...
def remove_n(df):
  df['text'] = df['text'].str.replace(r'\n|\n.', '', regex=True)
  df['text'] = df['text'].str.replace(r'\.{2,}', '.', regex=True)
  return df
  
# parse
def parse(df):
  print('#################################################')
  print('the shape of merged df is:',df.shape)
  print('start parsing')
  print('#################################################')
  df=remove_n(df)
  df=df.drop_duplicates()
  # new_df = pd.DataFrame(columns=df.columns)
  parsed_df=[]
  # iterate over each row in the original dataframe
  for index, row in df.iterrows():
    print('parsing row', index)
    # split the "text" column value into a list of sentences
    sentences = row['text'].split('. ')  # assuming sentences are separated by ". "
    new_df=pd.DataFrame({
            'text': sentences,
            'num_interaction': row['num_interaction'],
            'username':row['username'],
            'datetime': row['datetime'],
            'platform': row['platform'],
            'candidate_name': row['candidate_name']            
    })
    parsed_df.append(new_df)

  parsed_df=pd.concat(parsed_df)
  return parsed_df

# %%
# Define a function to restore spanish accents
def replace_special_chars(text):
  text = re.sub(r'\\u([\da-fA-F]{4})', lambda m: chr(int(m.group(1), 16)), text)
  # Remove punctuation
  text = text.translate(str.maketrans('', '', string.punctuation))
  text = ''.join([i for i in text if not i.isdigit()])
  # # Create a SnowballStemmer for Spanish
  # stemmer = SnowballStemmer('spanish')
  # # Apply stemming
  # words = text.split()
  # stemmed_words = [stemmer.stem(word) for word in words]
  # return ' '.join(stemmed_words)
  return text

def text_process(df):
  # restore accent
  df['text'] = df['text'].apply(replace_special_chars)
  # process tweet is a func from pysentimiento
  df['processed_text'] = df['text'].apply(preprocess_tweet)

  # other steps

  return df

# %% [markdown]
# ## sentiment analysis function

# %%
# do sentiment analysis in batches
def sent_analyze(df):
  batch=512
  analyzer = create_analyzer(task="sentiment", lang="es", batch_size=batch)

  text=df['processed_text'].tolist() #list of texts
  label=[]
  pos_prob=[]
  neu_prob=[]
  neg_prob=[]
  for i in range(0, len(text), batch):
    analyze_result=analyzer.predict(text[i:i+batch])

    label+=[r.output for r in analyze_result]
    pos_prob+=[r.probas['POS'] for r in analyze_result]
    neu_prob+=[r.probas['NEU'] for r in analyze_result]
    neg_prob+=[r.probas['NEG'] for r in analyze_result]
    print("Batch {} done".format(int(i/512)))

  df['label']=label
  df['positive']=pos_prob
  df['neutral']=neu_prob
  df['negative']=neg_prob
  return df

# %%
def generate_infotracer_and_sentiment_table(start_date,end_date,ytb_end_date,update_db=True):

###########################################################################
## This function generates both infotracer and sentiment table.
## It calls information tracer and ytb comment function within it,
## merge result, process text and conduct sentiment analysis.
###########################################################################

  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # get information tracer query result (also insert to db)
  df=generate_infotracer_table(start_date=start_date,end_date=end_date,update_db=update_db)

  #get youtube comment query result
  ytbcomment_df=query_youtube_comment(start_date=start_date,end_date=ytb_end_date)

  # merge results
  # text for sentiment table: everything in df + used youtube raw data to extract comment
  sentiment_df=pd.concat([ytbcomment_df,df])
  sentiment_df=sentiment_df.reset_index(drop=True)

  #parse post into sentences
  sentiment=parse(sentiment_df)

  #################################
  ## text processing
  #################################
  sentiment=text_process(sentiment)

  # sentiment calculation

  full_sentiment=sent_analyze(sentiment)
  if update_db==True:
    # commit full sentiment to sentiment table in db
    sent_data = full_sentiment.apply(tuple, axis=1).tolist()
    query="insert into sentiment (text,num_interaction,username,datetime,platform,candidate_name,processed_text,label, positive, neutral, negative) Values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);" 
    mycursor.executemany(query,sent_data)

    mydb.commit()

  return

# %% [markdown]
# # ETL data for wordcloud

# %%
def clean_text(sentence):
  # all lower-case
  sentence = sentence.lower()
  # remove punctuations 
  sentence = re.sub(r"[,.¡¿\"@#$%^&*(){}?/;:<>+=-]", "", sentence)
  # remove numbers
  sentence = re.sub(r'\d+', '', sentence)
  # remove leading/trailing whitespace
  sentence = sentence.strip()
  
  return sentence

# %%
def generate_wordcloud_table():
  #query for data in last 14 days
  wc_query= "SELECT processed_text, platform, candidate_name, datetime FROM sentiment WHERE datetime >= DATE_SUB(NOW(), INTERVAL 14 DAY) "
  word_cloud_df= pd.read_sql_query(wc_query, mydb)
  
  #process text
  word_cloud_df['processed_text']=word_cloud_df['processed_text'].apply(lambda x: clean_text(x))


  # stop words
  
  with open(os.path.expanduser('spanish.txt'), 'r') as f:
    spanish_stopwords = [line.strip() for line in f]
  stop_words = set(spanish_stopwords)
  stop_words.add('emoji') 
  stop_words.add('http')
  stop_words.add('youtube')
  stop_words.add('twitter')
  stop_words.add('instagram')
  stop_words.add('facebook')

  # generate wordcloud df
  wc=[]
  for platform in word_cloud_df['platform'].unique():
    for candidate in word_cloud_df['candidate_name'].unique():
      all_text = ' '.join(word_cloud_df[(word_cloud_df['platform']==platform)&(word_cloud_df['candidate_name']==candidate)]['processed_text'])
      if all_text=='':
        all_text='NADA'
        print(platform, candidate, all_text)
      wordcloud = WordCloud(stopwords=stop_words).generate(all_text)
      # Get list of words in wordcloud
      word_list = list(wordcloud.words_.keys())
      word_weights = list(wordcloud.words_.values())
      sub_wc=pd.DataFrame({'word':word_list, 'frequency':word_weights,'platform': platform,'candidate_name':candidate})
      wc.append(sub_wc)

  wc=pd.concat(wc)
  print('shape of wordcloud is',wc.shape)

  # empty the table
  print('empty the table')
  mycursor.execute(f'DELETE FROM wordcloud')
  mydb.commit()

  # insert to db last 14 days data
  print('start inserting')
  wc_data = wc.apply(tuple, axis=1).tolist()
  query="insert into wordcloud (word,weight, platform, candidate_name) Values(%s,%s,%s,%s);" 
  mycursor.executemany(query,wc_data)
  print('done')

  mydb.commit()

  return

# %% [markdown]
# # ETL data for network

# %%
def generate_network_table(start_date,end_date,update_db=True):
  
  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}

  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  for candidate, query in query_dict.items():
    ## extract data
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date)
    url = "https://informationtracer.com/cross_platform/{}/interaction_network_{}.json".format(id_hash256[:3], id_hash256)

    network_json = requests.get(url).json()

    ## construct df
    node_id_to_category = {}
    node_id_to_name={}
    node_id_to_datetime={}
    node_id_to_platform={}

    ## iterate all nodes to save node type
    for node in network_json['nodes']:
      node_id_to_category[node['id']] = node['type']
      node_id_to_name[node['id']]=node['name']
      node_id_to_datetime[node['id']]=node['timestamp']
      node_id_to_platform[node['id']]=node['platform']

    ## iterate all links
    source=[]
    target=[]
    weight=[]
    source_cat=[]
    target_cat=[]
    source_datetime=[]
    target_datetime=[]

    for link in network_json['links']:
      source_id = link['source']
      target_id = link['target']
      source_datetime.append(node_id_to_datetime[source_id])
      target_datetime.append(node_id_to_datetime[target_id])

      source_cat.append(node_id_to_category[source_id])
      target_cat.append(node_id_to_category[target_id])

      # to distinguish user with same name on different platform
      if node_id_to_category[source_id]=='user':
        source.append((node_id_to_name[source_id]+' '+node_id_to_platform[source_id]))
      else: 
        source.append(node_id_to_name[source_id])
      
      if node_id_to_category[target_id]=='user':
        target.append((node_id_to_name[target_id]+' '+node_id_to_platform[target_id]))
      else:
        target.append(node_id_to_name[target_id])
      
      weight.append(link['weight'])


    nw_df = pd.DataFrame({
        'source': source,
        'target': target,
        'weight': weight,
        'source_cat': source_cat,
        'target_cat': target_cat,
        'source_datetime': source_datetime,
        'target_datetime': target_datetime
    })
    nw_df['source_datetime']=pd.to_datetime(nw_df['source_datetime'])
    nw_df['target_datetime']=pd.to_datetime(nw_df['target_datetime'])
    nw_df['source_datetime']=convert_time(nw_df['source_datetime'])
    nw_df['target_datetime']=convert_time(nw_df['target_datetime'])

    nw_df['candidate_name']=candidate
    if update_db==True:
      ##### insert into mysql table source, target, weight, source_category, target_category
      nw_data=nw_df.apply(tuple, axis=1).tolist()
      query="insert into network (source, target, weight, source_cat, target_cat, source_datetime, target_datetime, candidate_name) Values(%s,%s,%s,%s,%s,%s,%s,%s);"
      mycursor.executemany(query,nw_data)

      mydb.commit()

  return

# %% [markdown]
# # Historical

# %%
# if start date=0415, end date=0416, it means from 0415 00:00 to 0416 23:59!!!
# 0415 00：00-0416-23：59 << start 0415, end 0416
# 0416 00：00-0416 23：59 << start 0416, end 0416

# %%
# # # infotracer and sentiment: add historical data
# generate_infotracer_and_sentiment_table(start_date="2023-04-19",end_date="2023-04-24",ytb_end_date="2023-04-24",update_db=True)

# # # network: add historical data
# print('network table starts')
# generate_network_table(start_date="2023-04-19",end_date="2023-04-24",update_db=True)
# print('network table done')

# # # helper: add historical data
# # generate_helper_table(start_date="2023-01-01",end_date="2023-04-08")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# parsing row 1593
# parsing row 1594
# parsing row 1595
# parsing row 1596
# parsing row 1597
# parsing row 1598
# parsing row 1599
# parsing row 1600
# parsing row 1601
# parsing row 1602
# parsing row 1603
# parsing row 1604
# parsing row 1605
# parsing row 1606
# parsing row 1607
# parsing row 1608
# parsing row 1609
# parsing row 1610
# parsing row 1611
# parsing row 1612
# parsing row 1613
# parsing row 1614
# parsing row 1615
# parsing row 1616
# parsing row 1617
# parsing row 1618
# parsing row 1619
# parsing row 1620
# parsing row 1621
# parsing row 1622
# parsing row 1623
# parsing row 1624
# parsing row 1625
# parsing row 1626
# parsing row 1627
# parsing row 1628
# parsing row 1629
# parsing row 1630
# parsing row 1631
# parsing row 1632
# parsing row 1633
# parsing row 1634
# parsing row 1635
# parsing row 1636
# parsing row 1637
# parsing row 1638
# parsing row 1639
# parsing row 1640
# parsing row 1641
# parsing row 1642
# parsing row 1643
# parsing row 1644
# parsing row 1645
# parsing row 1646
# parsing row 1647
# parsing row 1648
# parsing row 1649
# parsing row 1650
# parsing row 1651
# parsing row 1652
# parsing row 1653
# parsing row 1654
# parsing row 1655
# parsing row 1656
# parsing row 1657
# parsing row 1658
# parsing row 1659
# parsing row 1660
# parsing row 1661
# parsing row 1662
# parsing row 1663
# parsing row 1664
# parsing row 1665
# parsing row 1666
# parsing row 1667
# parsing row 1668
# parsing row 1669
# parsing row 1670
# parsing row 1671
# parsing row 1672
# parsing row 1673
# parsing row 1674
# parsing row 1675
# parsing row 1676
# parsing row 1677
# parsing row 1678
# parsing row 1679
# parsing row 1680
# parsing row 1681
# parsing row 1682
# parsing row 1683
# parsing row 1684
# parsing row 1685
# parsing row 1686
# parsing row 1687
# parsing row 1688
# parsing row 1689
# parsing row 1690
# parsing row 1691
# parsing row 1692
# parsing row 1693
# parsing row 1694
# parsing row 1695
# parsing row 1696
# parsing row 1697
# parsing row 1698
# parsing row 1699
# parsing row 1700
# parsing row 1701
# parsing row 1702
# parsing row 1703
# parsing row 1704
# parsing row 1705
# parsing row 1706
# parsing row 1707
# parsing row 1708
# parsing row 1709
# parsing row 1710
# parsing row 1711
# parsing row 1712
# parsing row 1713
# parsing row 1714
# parsing row 1715
# parsing row 1716
# parsing row 1717
# parsing row 1718
# parsing row 1719
# parsing row 1720
# parsing row 1721
# parsing row 1722
# parsing row 1723
# parsing row 1724
# parsing row 1725
# parsing row 1726
# parsing row 1727
# parsing row 1728
# parsing row 1729
# parsing row 1730
# parsing row 1731
# parsing row 1732
# parsing row 1733
# parsing row 1734
# parsing row 1735
# parsing row 1736
# parsing row 1737
# parsing row 1738
# parsing row 1739
# parsing row 1740
# parsing row 1741
# parsing row 1742
# parsing row 1743
# parsing row 1744
# parsing row 1745
# parsing row 1746
# parsing row 1747
# parsing row 1748
# parsing row 1749
# parsing row 1750
# parsing row 1751
# parsing row 1752
# parsing row 1753
# parsing row 1754
# parsing row 1755
# parsing row 1756
# parsing row 1757
# parsing row 1758
# parsing row 1759
# parsing row 1760
# parsing row 1761
# parsing row 1762
# parsing row 1763
# parsing row 1764
# parsing row 1765
# parsing row 1766
# parsing row 1767
# parsing row 1768
# parsing row 1769
# parsing row 1770
# parsing row 1771
# parsing row 1772
# parsing row 1773
# parsing row 1774
# parsing row 1775
# parsing row 1776
# parsing row 1777
# parsing row 1778
# parsing row 1779
# parsing row 1780
# parsing row 1781
# parsing row 1782
# parsing row 1783
# parsing row 1784
# parsing row 1785
# parsing row 1786
# parsing row 1787
# parsing row 1788
# parsing row 1789
# parsing row 1790
# parsing row 1791
# parsing row 1792
# parsing row 1793
# parsing row 1794
# parsing row 1795
# parsing row 1796
# parsing row 1797
# parsing row 1798
# parsing row 1799
# parsing row 1800
# parsing row 1801
# parsing row 1802
# parsing row 1803
# parsing row 1804
# parsing row 1805
# parsing row 1806
# parsing row 1807
# parsing row 1808
# parsing row 1809
# parsing row 1810
# parsing row 1811
# parsing row 1812
# parsing row 1813
# parsing row 1814
# parsing row 1815
# parsing row 1816
# parsing row 1817
# parsing row 1818
# parsing row 1819
# parsing row 1820
# parsing row 1821
# parsing row 1822
# parsing row 1823
# parsing row 1824
# parsing row 1825
# parsing row 1826
# parsing row 1827
# parsing row 1828
# parsing row 1829
# parsing row 1830
# parsing row 1831
# parsing row 1832
# parsing row 1833
# parsing row 1834
# parsing row 1835
# parsing row 1836
# parsing row 1837
# parsing row 1838
# parsing row 1839
# parsing row 1840
# parsing row 1841
# parsing row 1842
# parsing row 1843
# parsing row 1844
# parsing row 1845
# parsing row 1846
# parsing row 1847
# parsing row 1848
# parsing row 1849
# parsing row 1850
# parsing row 1851
# parsing row 1852
# parsing row 1853
# parsing row 1854
# parsing row 1855
# parsing row 1856
# parsing row 1857
# parsing row 1858
# parsing row 1859
# parsing row 1860
# parsing row 1861
# parsing row 1862
# parsing row 1863
# parsing row 1864
# parsing row 1865
# parsing row 1866
# parsing row 1867
# parsing row 1868
# parsing row 1869
# parsing row 1870
# parsing row 1871
# parsing row 1872
# parsing row 1873
# parsing row 1874
# parsing row 1875
# parsing row 1876
# parsing row 1877
# parsing row 1878
# parsing row 1879
# parsing row 1880
# parsing row 1881
# parsing row 1882
# parsing row 1883
# parsing row 1884
# parsing row 1885
# parsing row 1886
# parsing row 1887
# parsing row 1888
# parsing row 1889
# parsing row 1890
# parsing row 1891
# parsing row 1892
# parsing row 1893
# parsing row 1894
# parsing row 1895
# parsing row 1896
# parsing row 1897
# parsing row 1898
# parsing row 1899
# parsing row 1900
# parsing row 1901
# parsing row 1902
# parsing row 1903
# parsing row 1904
# parsing row 1905
# parsing row 1906
# parsing row 1907
# parsing row 1908
# parsing row 1909
# parsing row 1910
# parsing row 1911
# parsing row 1912
# parsing row 1913
# parsing row 1914
# parsing row 1915
# parsing row 1916
# parsing row 1917
# parsing row 1918
# parsing row 1919
# parsing row 1920
# parsing row 1921
# parsing row 1922
# parsing row 1923
# parsing row 1924
# parsing row 1925
# parsing row 1926
# parsing row 1927
# parsing row 1928
# parsing row 1929
# parsing row 1930
# parsing row 1931
# parsing row 1932
# parsing row 1933
# parsing row 1934
# parsing row 1935
# parsing row 1936
# parsing row 1937
# parsing row 1938
# parsing row 1939
# parsing row 1940
# parsing row 1941
# parsing row 1942
# parsing row 1943
# parsing row 1944
# parsing row 1945
# parsing row 1946
# parsing row 1947
# parsing row 1948
# parsing row 1949
# parsing row 1950
# parsing row 1951
# parsing row 1952
# parsing row 1953
# parsing row 1954
# parsing row 1955
# parsing row 1956
# parsing row 1957
# parsing row 1958
# parsing row 1959
# parsing row 1960
# parsing row 1961
# parsing row 1962
# parsing row 1963
# parsing row 1964
# parsing row 1965
# parsing row 1966
# parsing row 1967
# parsing row 1968
# parsing row 1969
# parsing row 1970
# parsing row 1971
# parsing row 1972
# parsing row 1973
# parsing row 1974
# parsing row 1975
# parsing row 1976
# parsing row 1977
# parsing row 1978
# parsing row 1979
# parsing row 1980
# parsing row 1981
# parsing row 1982
# parsing row 1983
# parsing row 1984
# parsing row 1985
# parsing row 1986
# parsing row 1987
# parsing row 1988
# parsing row 1989
# parsing row 1990
# parsing row 1991
# parsing row 1992
# parsing row 1993
# parsing row 1994
# parsing row 1995
# parsing row 1996
# parsing row 1997
# parsing row 1998
# parsing row 1999
# parsing row 2000
# parsing row 2001
# parsing row 2002
# parsing row 2003
# parsing row 2004
# parsing row 2005
# parsing row 2006
# parsing row 2007
# parsing row 2008
# parsing row 2009
# parsing row 2010
# parsing row 2011
# parsing row 2012
# parsing row 2013
# parsing row 2014
# parsing row 2015
# parsing row 2016
# parsing row 2017
# parsing row 2018
# parsing row 2019
# parsing row 2020
# parsing row 2021
# parsing row 2022
# parsing row 2023
# parsing row 2024
# parsing row 2025
# parsing row 2026
# parsing row 2027
# parsing row 2028
# parsing row 2029
# parsing row 2030
# parsing row 2031
# parsing row 2032
# parsing row 2033
# parsing row 2034
# parsing row 2035
# parsing row 2036
# parsing row 2037
# parsing row 2038
# parsing row 2039
# parsing row 2040
# parsing row 2041
# parsing row 2042
# parsing row 2043
# parsing row 2044
# parsing row 2045
# parsing row 2046
# parsing row 2047
# parsing row 2048
# parsing row 2049
# parsing row 2050
# parsing row 2051
# parsing row 2052
# parsing row 2053
# parsing row 2054
# parsing row 2055
# parsing row 2056
# parsing row 2057
# parsing row 2058
# parsing row 2059
# parsing row 2060
# parsing row 2061
# parsing row 2062
# parsing row 2063
# parsing row 2064
# parsing row 2065
# parsing row 2066
# parsing row 2067
# parsing row 2068
# parsing row 2069
# parsing row 2070
# parsing row 2071
# parsing row 2072
# parsing row 2073
# parsing row 2074
# parsing row 2075
# parsing row 2076
# parsing row 2077
# parsing row 2078
# parsing row 2079
# parsing row 2080
# parsing row 2081
# parsing row 2082
# parsing row 2083
# parsing row 2084
# parsing row 2085
# parsing row 2086
# parsing row 2087
# parsing row 2088
# parsing row 2089
# parsing row 2090
# parsing row 2091
# parsing row 2092
# parsing row 2093
# parsing row 2094
# parsing row 2095
# parsing row 2096
# parsing row 2097
# parsing row 2098
# parsing row 2099
# parsing row 2100
# parsing row 2101
# parsing row 2102
# parsing row 2103
# parsing row 2104
# parsing row 2105
# parsing row 2106
# parsing row 2107
# parsing row 2108
# parsing row 2109
# parsing row 2110
# parsing row 2111
# parsing row 2112
# parsing row 2113
# parsing row 2114
# parsing row 2115
# parsing row 2116
# parsing row 2117
# parsing row 2118
# parsing row 2119
# parsing row 2120
# parsing row 2121
# parsing row 2122
# parsing row 2123
# parsing row 2124
# parsing row 2125
# parsing row 2126
# parsing row 2127
# parsing row 2128
# parsing row 2129
# parsing row 2130
# parsing row 2131
# parsing row 2132
# parsing row 2133
# parsing row 2134
# parsing row 2135
# parsing row 2136
# parsing row 2137
# parsing row 2138
# parsing row 2139
# parsing row 2140
# parsing row 2141
# parsing row 2142
# parsing row 2143
# parsing row 2144
# parsing row 2145
# parsing row 2146
# parsing row 2147
# parsing row 2148
# parsing row 2149
# parsing row 2150
# parsing row 2151
# parsing row 2152
# parsing row 2153
# parsing row 2154
# parsing row 2155
# parsing row 2156
# parsing row 2157
# parsing row 2158
# parsing row 2159
# parsing row 2160
# parsing row 2161
# parsing row 2162
# parsing row 2163
# parsing row 2164
# parsing row 2165
# parsing row 2166
# parsing row 2167
# parsing row 2168
# parsing row 2169
# parsing row 2170
# parsing row 2171
# parsing row 2172
# parsing row 2173
# parsing row 2174
# parsing row 2175
# parsing row 2176
# parsing row 2177
# parsing row 2178
# parsing row 2179
# parsing row 2180
# parsing row 2181
# parsing row 2182
# parsing row 2183
# parsing row 2184
# parsing row 2185
# parsing row 2186
# parsing row 2187
# parsing row 2188
# parsing row 2189
# parsing row 2190
# parsing row 2191
# parsing row 2192
# parsing row 2193
# parsing row 2194
# parsing row 2195
# parsing row 2196
# parsing row 2197
# parsing row 2198
# parsing row 2199
# parsing row 2200
# parsing row 2201
# parsing row 2202
# parsing row 2203
# parsing row 2204
# parsing row 2205
# parsing row 2206
# parsing row 2207
# parsing row 2208
# parsing row 2209
# parsing row 2210
# parsing row 2211
# parsing row 2212
# parsing row 2213
# parsing row 2214
# parsing row 2215
# parsing row 2216
# parsing row 2217
# parsing row 2218
# parsing row 2219
# parsing row 2220
# parsing row 2221
# parsing row 2222
# parsing row 2223
# parsing row 2224
# parsing row 2225
# parsing row 2226
# parsing row 2227
# parsing row 2228
# parsing row 2229
# parsing row 2230
# parsing row 2231
# parsing row 2232
# parsing row 2233
# parsing row 2234
# parsing row 2235
# parsing row 2236
# parsing row 2237
# parsing row 2238
# parsing row 2239
# parsing row 2240
# parsing row 2241
# parsing row 2242
# parsing row 2243
# parsing row 2244
# parsing row 2245
# parsing row 2246
# parsing row 2247
# parsing row 2248
# parsing row 2249
# parsing row 2250
# parsing row 2251
# parsing row 2252
# parsing row 2253
# parsing row 2254
# parsing row 2255
# parsing row 2256
# parsing row 2257
# parsing row 2258
# parsing row 2259
# parsing row 2260
# parsing row 2261
# parsing row 2262
# parsing row 2263
# parsing row 2264
# parsing row 2265
# parsing row 2266
# parsing row 2267
# parsing row 2268
# parsing row 2269
# parsing row 2270
# parsing row 2271
# parsing row 2272
# parsing row 2273
# parsing row 2274
# parsing row 2275
# parsing row 2276
# parsing row 2277
# parsing row 2278
# parsing row 2279
# parsing row 2280
# parsing row 2281
# parsing row 2282
# parsing row 2283
# parsing row 2284
# parsing row 2285
# parsing row 2286
# parsing row 2287
# parsing row 2288
# parsing row 2289
# parsing row 2290
# parsing row 2291
# parsing row 2292
# parsing row 2293
# parsing row 2294
# parsing row 2295
# parsing row 2296
# parsing row 2297
# parsing row 2298
# parsing row 2299
# parsing row 2300
# parsing row 2301
# parsing row 2302
# parsing row 2303
# parsing row 2304
# parsing row 2305
# parsing row 2306
# parsing row 2307
# parsing row 2308
# parsing row 2309
# parsing row 2310
# parsing row 2311
# parsing row 2312
# parsing row 2313
# parsing row 2314
# parsing row 2315
# parsing row 2316
# parsing row 2317
# parsing row 2318
# parsing row 2319
# parsing row 2320
# parsing row 2321
# parsing row 2322
# parsing row 2323
# parsing row 2324
# parsing row 2325
# parsing row 2326
# parsing row 2327
# parsing row 2328
# parsing row 2329
# parsing row 2330
# parsing row 2331
# parsing row 2332
# parsing row 2333
# parsing row 2334
# parsing row 2335
# parsing row 2336
# parsing row 2337
# parsing row 2338
# parsing row 2339
# parsing row 2340
# parsing row 2341
# parsing row 2342
# parsing row 2343
# parsing row 2344
# parsing row 2345
# parsing row 2346
# parsing row 2347
# parsing row 2348
# parsing row 2349
# parsing row 2350
# parsing row 2351
# parsing row 2352
# parsing row 2353
# parsing row 2354
# parsing row 2355
# parsing row 2356
# parsing row 2357
# parsing row 2358
# parsing row 2359
# parsing row 2360
# parsing row 2361
# parsing row 2362
# parsing row 2363
# parsing row 2364
# parsing row 2365
# parsing row 2366
# parsing row 2367
# parsing row 2368
# parsing row 2369
# parsing row 2370
# parsing row 2371
# parsing row 2372
# parsing row 2373
# parsing row 2374
# parsing row 2375
# parsing row 2376
# parsing row 2377
# parsing row 2378
# parsing row 2379
# parsing row 2380
# parsing row 2381
# parsing row 2382
# parsing row 2383
# parsing row 2384
# parsing row 2385
# parsing row 2386
# parsing row 2387
# parsing row 2388
# parsing row 2389
# parsing row 2390
# parsing row 2391
# parsing row 2392
# parsing row 2393
# parsing row 2394
# parsing row 2395
# parsing row 2396
# parsing row 2397
# parsing row 2398
# parsing row 2399
# parsing row 2400
# parsing row 2401
# parsing row 2402
# parsing row 2403
# parsing row 2404
# parsing row 2405
# parsing row 2406
# parsing row 2407
# parsing row 2408
# parsing row 2409
# parsing row 2410
# parsing row 2411
# parsing row 2412
# parsing row 2413
# parsing row 2414
# parsing row 2415
# parsing row 2416
# parsing row 2417
# parsing row 2418
# parsing row 2419
# parsing row 2420
# parsing row 2421
# parsing row 2422
# parsing row 2423
# parsing row 2424
# parsing row 2425
# parsing row 2426
# parsing row 2427
# parsing row 2428
# parsing row 2429
# parsing row 2430
# parsing row 2431
# parsing row 2432
# parsing row 2433
# parsing row 2434
# parsing row 2435
# parsing row 2436
# parsing row 2437
# parsing row 2438
# parsing row 2439
# parsing row 2440
# parsing row 2441
# parsing row 2442
# parsing row 2443
# parsing row 2444
# parsing row 2445
# parsing row 2446
# parsing row 2447
# parsing row 2448
# parsing row 2449
# parsing row 2450
# parsing row 2451
# parsing row 2452
# parsing row 2453
# parsing row 2454
# parsing row 2455
# parsing row 2456
# parsing row 2457
# parsing row 2458
# parsing row 2459
# parsing row 2460
# parsing row 2461
# parsing row 2462
# parsing row 2463
# parsing row 2464
# parsing row 2465
# parsing row 2466
# parsing row 2467
# parsing row 2468
# parsing row 2469
# parsing row 2470
# parsing row 2471
# parsing row 2472
# parsing row 2473
# parsing row 2474
# parsing row 2475
# parsing row 2476
# parsing row 2477
# parsing row 2478
# parsing row 2479
# parsing row 2480
# parsing row 2481
# parsing row 2482
# parsing row 2483
# parsing row 2484
# parsing row 2485
# parsing row 2486
# parsing row 2487
# parsing row 2488
# parsing row 2489
# parsing row 2490
# parsing row 2491
# parsing row 2492
# parsing row 2493
# parsing row 2494
# parsing row 2495
# parsing row 2496
# parsing row 2497
# parsing row 2498
# parsing row 2499
# parsing row 2500
# parsing row 2501
# parsing row 2502
# parsing row 2503
# parsing row 2504
# parsing row 2505
# parsing row 2506
# parsing row 2507
# parsing row 2508
# parsing row 2509
# parsing row 2510
# parsing row 2511
# parsing row 2512
# parsing row 2513
# parsing row 2514
# parsing row 2515
# parsing row 2516
# parsing row 2517
# parsing row 2518
# parsing row 2519
# parsing row 2520
# parsing row 2521
# parsing row 2522
# parsing row 2523
# parsing row 2524
# parsing row 2525
# parsing row 2526
# parsing row 2527
# parsing row 2528
# parsing row 2529
# parsing row 2530
# parsing row 2531
# parsing row 2532
# parsing row 2533
# parsing row 2534
# parsing row 2535
# parsing row 2536
# parsing row 2537
# parsing row 2538
# parsing row 2539
# parsing row 2540
# parsing row 2541
# parsing row 2542
# parsing row 2543
# parsing row 2544
# parsing row 2545
# parsing row 2546
# parsing row 2547
# parsing row 2548
# parsing row 2549
# parsing row 2550
# parsing row 2551
# parsing row 2552
# parsing row 2553
# parsing row 2554
# parsing row 2555
# parsing row 2556
# parsing row 2557
# parsing row 2558
# parsing row 2559
# parsing row 2560
# parsing row 2561
# parsing row 2562
# parsing row 2563
# parsing row 2564
# parsing row 2565
# parsing row 2566
# parsing row 2567
# parsing row 2568
# parsing row 2569
# parsing row 2570
# parsing row 2571
# parsing row 2572
# parsing row 2573
# parsing row 2574
# parsing row 2575
# parsing row 2576
# parsing row 2577
# parsing row 2578
# parsing row 2579
# parsing row 2580
# parsing row 2581
# parsing row 2582
# parsing row 2583
# parsing row 2584
# parsing row 2585
# parsing row 2586
# parsing row 2587
# parsing row 2588
# parsing row 2589
# parsing row 2590
# parsing row 2591
# parsing row 2592
# parsing row 2593
# parsing row 2594
# parsing row 2595
# parsing row 2596
# parsing row 2597
# parsing row 2598
# parsing row 2599
# parsing row 2600
# parsing row 2601
# parsing row 2602
# parsing row 2603
# parsing row 2604
# parsing row 2605
# parsing row 2606
# parsing row 2607
# parsing row 2608
# parsing row 2609
# parsing row 2610
# parsing row 2611
# parsing row 2612
# parsing row 2613
# parsing row 2614
# parsing row 2615
# parsing row 2616
# parsing row 2617
# parsing row 2618
# parsing row 2619
# parsing row 2620
# parsing row 2621
# parsing row 2622
# parsing row 2623
# parsing row 2624
# parsing row 2625
# parsing row 2626
# parsing row 2627
# parsing row 2628
# parsing row 2629
# parsing row 2630
# parsing row 2631
# parsing row 2632
# parsing row 2633
# parsing row 2634
# parsing row 2635
# parsing row 2636
# parsing row 2637
# parsing row 2638
# parsing row 2639
# parsing row 2640
# parsing row 2641
# parsing row 2642
# parsing row 2643
# parsing row 2644
# parsing row 2645
# parsing row 2646
# parsing row 2647
# parsing row 2648
# parsing row 2649
# parsing row 2650
# parsing row 2651
# parsing row 2652
# parsing row 2653
# parsing row 2654
# parsing row 2655
# parsing row 2656
# parsing row 2657
# parsing row 2658
# parsing row 2659
# parsing row 2660
# parsing row 2661
# parsing row 2662
# parsing row 2663
# parsing row 2664
# parsing row 2665
# parsing row 2666
# parsing row 2667
# parsing row 2668
# parsing row 2669
# parsing row 2670
# parsing row 2671
# parsing row 2672
# parsing row 2673
# parsing row 2674
# parsing row 2675
# parsing row 2676
# parsing row 2677
# parsing row 2678
# parsing row 2679
# parsing row 2680
# parsing row 2681
# parsing row 2682
# parsing row 2683
# parsing row 2684
# parsing row 2685
# parsing row 2686
# parsing row 2687
# parsing row 2688
# parsing row 2689
# parsing row 2690
# parsing row 2691
# parsing row 2692
# parsing row 2693
# parsing row 2694
# parsing row 2695
# parsing row 2696
# parsing row 2697
# parsing row 2698
# parsing row 2699
# parsing row 2700
# parsing row 2701
# parsing row 2702
# parsing row 2703
# parsing row 2704
# parsing row 2705
# parsing row 2706
# parsing row 2707
# parsing row 2708
# parsing row 2709
# parsing row 2710
# parsing row 2711
# parsing row 2712
# parsing row 2713
# parsing row 2714
# parsing row 2715
# parsing row 2716
# parsing row 2717
# parsing row 2718
# parsing row 2719
# parsing row 2720
# parsing row 2721
# parsing row 2722
# parsing row 2723
# parsing row 2724
# parsing row 2725
# parsing row 2726
# parsing row 2727
# parsing row 2728
# parsing row 2729
# parsing row 2730
# parsing row 2731
# parsing row 2732
# parsing row 2733
# parsing row 2734
# parsing row 2735
# parsing row 2736
# parsing row 2737
# parsing row 2738
# parsing row 2739
# parsing row 2740
# parsing row 2741
# parsing row 2742
# parsing row 2743
# parsing row 2744
# parsing row 2745
# parsing row 2746
# parsing row 2747
# parsing row 2748
# parsing row 2749
# parsing row 2750
# parsing row 2751
# parsing row 2752
# parsing row 2753
# parsing row 2754
# parsing row 2755
# parsing row 2756
# parsing row 2757
# parsing row 2758
# parsing row 2759
# parsing row 2760
# parsing row 2761
# parsing row 2762
# parsing row 2763
# parsing row 2764
# parsing row 2765
# parsing row 2766
# parsing row 2767
# parsing row 2768
# parsing row 2769
# parsing row 2770
# parsing row 2771
# parsing row 2772
# parsing row 2773
# parsing row 2774
# parsing row 2775
# parsing row 2776
# parsing row 2777
# parsing row 2778
# parsing row 2779
# parsing row 2780
# parsing row 2781
# parsing row 2782
# parsing row 2783
# parsing row 2784
# parsing row 2785
# parsing row 2786
# parsing row 2787
# parsing row 2788
# parsing row 2789
# parsing row 2790
# parsing row 2791
# parsing row 2792
# parsing row 2793
# parsing row 2794
# parsing row 2795
# parsing row 2796
# parsing row 2797
# parsing row 2798
# parsing row 2799
# parsing row 2800
# parsing row 2801
# parsing row 2802
# parsing row 2803
# parsing row 2804
# parsing row 2805
# parsing row 2806
# parsing row 2807
# parsing row 2808
# parsing row 2809
# parsing row 2810
# parsing row 2811
# parsing row 2812
# parsing row 2813
# parsing row 2814
# parsing row 2815
# parsing row 2816
# parsing row 2817
# parsing row 2818
# parsing row 2819
# parsing row 2820
# parsing row 2821
# parsing row 2822
# parsing row 2823
# parsing row 2824
# parsing row 2825
# parsing row 2826
# parsing row 2827
# parsing row 2828
# parsing row 2829
# parsing row 2830
# parsing row 2831
# parsing row 2832
# parsing row 2833
# parsing row 2834
# parsing row 2835
# parsing row 2836
# parsing row 2837
# parsing row 2838
# parsing row 2839
# parsing row 2840
# parsing row 2841
# parsing row 2842
# parsing row 2843
# parsing row 2844
# parsing row 2845
# parsing row 2846
# parsing row 2847
# parsing row 2848
# parsing row 2849
# parsing row 2850
# parsing row 2851
# parsing row 2852
# parsing row 2853
# parsing row 2854
# parsing row 2855
# parsing row 2856
# parsing row 2857
# parsing row 2858
# parsing row 2859
# parsing row 2860
# parsing row 2861
# parsing row 2862
# parsing row 2863
# parsing row 2864
# parsing row 2865
# parsing row 2866
# parsing row 2867
# parsing row 2868
# parsing row 2869
# parsing row 2870
# parsing row 2871
# parsing row 2872
# parsing row 2873
# parsing row 2874
# parsing row 2875
# parsing row 2876
# parsing row 2877
# parsing row 2878
# parsing row 2879
# parsing row 2880
# parsing row 2881
# parsing row 2882
# parsing row 2883
# parsing row 2884
# parsing row 2885
# parsing row 2886
# parsing row 2887
# parsing row 2888
# parsing row 2889
# parsing row 2890
# parsing row 2891
# parsing row 2892
# parsing row 2893
# parsing row 2894
# parsing row 2895
# parsing row 2896
# parsing row 2897
# parsing row 2898
# parsing row 2899
# parsing row 2900
# parsing row 2901
# parsing row 2902
# parsing row 2903
# parsing row 2904
# parsing row 2905
# parsing row 2906
# parsing row 2907
# parsing row 2908
# parsing row 2909
# parsing row 2910
# parsing row 2911
# parsing row 2912
# parsing row 2913
# parsing row 2914
# parsing row 2915
# parsing row 2916
# parsing row 2917
# parsing row 2918
# parsing row 2919
# parsing row 2920
# parsing row 2921
# parsing row 2922
# parsing row 2923
# parsing row 2924
# parsing row 2925
# parsing row 2926
# parsing row 2927
# parsing row 2928
# parsing row 2929
# parsing row 2930
# parsing row 2931
# parsing row 2932
# parsing row 2933
# parsing row 2934
# parsing row 2935
# parsing row 2936
# parsing row 2937
# parsing row 2938
# parsing row 2939
# parsing row 2940
# parsing row 2941
# parsing row 2942
# parsing row 2943
# parsing row 2944
# parsing row 2945
# parsing row 2946
# parsing row 2947
# parsing row 2948
# parsing row 2949
# parsing row 2950
# parsing row 2951
# parsing row 2952
# parsing row 2953
# parsing row 2954
# parsing row 2955
# parsing row 2956
# parsing row 2957
# parsing row 2958
# parsing row 2959
# parsing row 2960
# parsing row 2961
# parsing row 2962
# parsing row 2963
# parsing row 2964
# parsing row 2965
# parsing row 2966
# parsing row 2967
# parsing row 2968
# parsing row 2969
# parsing row 2970
# parsing row 2971
# parsing row 2972
# parsing row 2973
# parsing row 2974
# parsing row 2975
# parsing row 2976
# parsing row 2977
# parsing row 2978
# parsing row 2979
# parsing row 2980
# parsing row 2981
# parsing row 2982
# parsing row 2983
# parsing row 2984
# parsing row 2985
# parsing row 2986
# parsing row 2987
# parsing row 2988
# parsing row 2989
# parsing row 2990
# parsing row 2991
# parsing row 2992
# parsing row 2993
# parsing row 2994
# parsing row 2995
# parsing row 2996
# parsing row 2997
# parsing row 2998
# parsing row 2999
# parsing row 3000
# parsing row 3001
# parsing row 3002
# parsing row 3003
# parsing row 3004
# parsing row 3005
# parsing row 3006
# parsing row 3007
# parsing row 3008
# parsing row 3009
# parsing row 3010
# parsing row 3011
# parsing row 3012
# parsing row 3013
# parsing row 3014
# parsing row 3015
# parsing row 3016
# parsing row 3017
# parsing row 3018
# parsing row 3019
# parsing row 3020
# parsing row 3021
# parsing row 3022
# parsing row 3023
# parsing row 3024
# parsing row 3025
# parsing row 3026
# parsing row 3027
# parsing row 3028
# parsing row 3029
# parsing row 3030
# parsing row 3031
# parsing row 3032
# parsing row 3033
# parsing row 3034
# parsing row 3035
# parsing row 3036
# parsing row 3037
# parsing row 3038
# parsing row 3039
# parsing row 3040
# parsing row 3041
# parsing row 3042
# parsing row 3043
# parsing row 3044
# parsing row 3045
# parsing row 3046
# parsing row 3047
# parsing row 3048
# parsing row 3049
# parsing row 3050
# parsing row 3051
# parsing row 3052
# parsing row 3053
# parsing row 3054
# parsing row 3055
# parsing row 3056
# parsing row 3057
# parsing row 3058
# parsing row 3059
# parsing row 3060
# parsing row 3061
# parsing row 3062
# parsing row 3063
# parsing row 3064
# parsing row 3065
# parsing row 3066
# parsing row 3067
# parsing row 3068
# parsing row 3069
# parsing row 3070
# parsing row 3071
# parsing row 3072
# parsing row 3073
# parsing row 3074
# parsing row 3075
# parsing row 3076
# parsing row 3077
# parsing row 3078
# parsing row 3079
# parsing row 3080
# parsing row 3081
# parsing row 3082
# parsing row 3083
# parsing row 3084
# parsing row 3085
# parsing row 3086
# parsing row 3087
# parsing row 3088
# parsing row 3089
# parsing row 3090
# parsing row 3091
# parsing row 3092
# parsing row 3093
# parsing row 3094
# parsing row 3095
# parsing row 3096
# parsing row 3097
# parsing row 3098
# parsing row 3099
# parsing row 3100
# parsing row 3101
# parsing row 3102
# parsing row 3103
# parsing row 3104
# parsing row 3105
# parsing row 3106
# parsing row 3107
# parsing row 3108
# parsing row 3109
# parsing row 3110
# parsing row 3111
# parsing row 3112
# parsing row 3113
# parsing row 3114
# parsing row 3115
# parsing row 3116
# parsing row 3117
# parsing row 3118
# parsing row 3119
# parsing row 3120
# parsing row 3121
# parsing row 3122
# parsing row 3123
# parsing row 3124
# parsing row 3125
# parsing row 3126
# parsing row 3127
# parsing row 3128
# parsing row 3129
# parsing row 3130
# parsing row 3131
# parsing row 3132
# parsing row 3133
# parsing row 3134
# parsing row 3135
# parsing row 3136
# parsing row 3137
# parsing row 3138
# parsing row 3139
# parsing row 3140
# parsing row 3141
# parsing row 3142
# parsing row 3143
# parsing row 3144
# parsing row 3145
# parsing row 3146
# parsing row 3147
# parsing row 3148
# parsing row 3149
# parsing row 3150
# parsing row 3151
# parsing row 3152
# parsing row 3153
# parsing row 3154
# parsing row 3155
# parsing row 3156
# parsing row 3157
# parsing row 3158
# parsing row 3159
# parsing row 3160
# parsing row 3161
# parsing row 3162
# parsing row 3163
# parsing row 3164
# parsing row 3165
# parsing row 3166
# parsing row 3167
# parsing row 3168
# parsing row 3169
# parsing row 3170
# parsing row 3171
# parsing row 3172
# parsing row 3173
# parsing row 3174
# parsing row 3175
# parsing row 3176
# parsing row 3177
# parsing row 3178
# parsing row 3179
# parsing row 3180
# parsing row 3181
# parsing row 3182
# parsing row 3183
# parsing row 3184
# parsing row 3185
# parsing row 3186
# parsing row 3187
# parsing row 3188
# parsing row 3189
# parsing row 3190
# parsing row 3191
# parsing row 3192
# parsing row 3193
# parsing row 3194
# parsing row 3195
# parsing row 3196
# parsing row 3197
# parsing row 3198
# parsing row 3199
# parsing row 3200
# parsing row 3201
# parsing row 3202
# parsing row 3203
# parsing row 3204
# parsing row 3205
# parsing row 3206
# parsing row 3207
# parsing row 3208
# parsing row 3209
# parsing row 3210
# parsing row 3211
# parsing row 3212
# parsing row 3213
# parsing row 3214
# parsing row 3215
# parsing row 3216
# parsing row 3217
# parsing row 3218
# parsing row 3219
# parsing row 3220
# parsing row 3221
# parsing row 3222
# parsing row 3223
# parsing row 3224
# parsing row 3225
# parsing row 3226
# parsing row 3227
# parsing row 3228
# parsing row 3229
# parsing row 3230
# parsing row 3231
# parsing row 3232
# parsing row 3233
# parsing row 3234
# parsing row 3235
# parsing row 3236
# parsing row 3237
# parsing row 3238
# parsing row 3239
# parsing row 3240
# parsing row 3241
# parsing row 3242
# parsing row 3243
# parsing row 3244
# parsing row 3245
# parsing row 3246
# parsing row 3247
# parsing row 3248
# parsing row 3249
# parsing row 3250
# parsing row 3251
# parsing row 3252
# parsing row 3253
# parsing row 3254
# parsing row 3255
# parsing row 3256
# parsing row 3257
# parsing row 3258
# parsing row 3259
# parsing row 3260
# parsing row 3261
# parsing row 3262
# parsing row 3263
# parsing row 3264
# parsing row 3265
# parsing row 3266
# parsing row 3267
# parsing row 3268
# parsing row 3269
# parsing row 3270
# parsing row 3271
# parsing row 3272
# parsing row 3273
# parsing row 3274
# parsing row 3275
# parsing row 3276
# parsing row 3277
# parsing row 3278
# parsing row 3279
# parsing row 3280
# parsing row 3281
# parsing row 3282
# parsing row 3283
# parsing row 3284
# parsing row 3285
# parsing row 3286
# parsing row 3287
# parsing row 3288
# parsing row 3289
# parsing row 3290
# parsing row 3291
# parsing row 3292
# parsing row 3293
# parsing row 3294
# parsing row 3295
# parsing row 3296
# parsing row 3297
# parsing row 3298
# parsing row 3299
# parsing row 3300
# parsing row 3301
# parsing row 3302
# parsing row 3303
# parsing row 3304
# parsing row 3305
# parsing row 3306
# parsing row 3307
# parsing row 3308
# parsing row 3309
# parsing row 3310
# parsing row 3311
# parsing row 3312
# parsing row 3313
# parsing row 3314
# parsing row 3315
# parsing row 3316
# parsing row 3317
# parsing row 3318
# parsing row 3319
# parsing row 3320
# parsing row 3321
# parsing row 3322
# parsing row 3323
# parsing row 3324
# parsing row 3325
# parsing row 3326
# parsing row 3327
# parsing row 3328
# parsing row 3329
# parsing row 3330
# parsing row 3331
# parsing row 3332
# parsing row 3333
# parsing row 3334
# parsing row 3335
# parsing row 3336
# parsing row 3337
# parsing row 3338
# parsing row 3339
# parsing row 3340
# parsing row 3341
# parsing row 3342
# parsing row 3343
# parsing row 3344
# parsing row 3345
# parsing row 3346
# parsing row 3347
# parsing row 3348
# parsing row 3349
# parsing row 3350
# parsing row 3351
# parsing row 3352
# parsing row 3353
# parsing row 3354
# parsing row 3355
# parsing row 3356
# parsing row 3357
# parsing row 3358
# parsing row 3359
# parsing row 3360
# parsing row 3361
# parsing row 3362
# parsing row 3363
# parsing row 3364
# parsing row 3365
# parsing row 3366
# parsing row 3367
# parsing row 3368
# parsing row 3369
# parsing row 3370
# parsing row 3371
# parsing row 3372
# parsing row 3373
# parsing row 3374
# parsing row 3375
# parsing row 3376
# parsing row 3377
# parsing row 3378
# parsing row 3379
# parsing row 3380
# parsing row 3381
# parsing row 3382
# parsing row 3383
# parsing row 3384
# parsing row 3385
# parsing row 3386
# parsing row 3387
# parsing row 3388
# parsing row 3389
# parsing row 3390
# parsing row 3391
# parsing row 3392
# parsing row 3393
# parsing row 3394
# parsing row 3395
# parsing row 3396
# parsing row 3397
# parsing row 3398
# parsing row 3399
# parsing row 3400
# parsing row 3401
# parsing row 3402
# parsing row 3403
# parsing row 3404
# parsing row 3405
# parsing row 3406
# parsing row 3407
# parsing row 3408
# parsing row 3409
# parsing row 3410
# parsing row 3411
# parsing row 3412
# parsing row 3413
# parsing row 3414
# parsing row 3415
# parsing row 3416
# parsing row 3417
# parsing row 3418
# parsing row 3419
# parsing row 3420
# parsing row 3421
# parsing row 3422
# parsing row 3423
# parsing row 3424
# parsing row 3425
# parsing row 3426
# parsing row 3427
# parsing row 3428
# parsing row 3429
# parsing row 3430
# parsing row 3431
# parsing row 3432
# parsing row 3433
# parsing row 3434
# parsing row 3435
# parsing row 3436
# parsing row 3437
# parsing row 3438
# parsing row 3439
# parsing row 3440
# parsing row 3441
# parsing row 3442
# parsing row 3443
# parsing row 3444
# parsing row 3445
# parsing row 3446
# parsing row 3447
# parsing row 3448
# parsing row 3449
# parsing row 3450
# parsing row 3451
# parsing row 3452
# parsing row 3453
# parsing row 3454
# parsing row 3455
# parsing row 3456
# parsing row 3457
# parsing row 3458
# parsing row 3459
# parsing row 3460
# parsing row 3461
# parsing row 3462
# parsing row 3463
# parsing row 3464
# parsing row 3465
# parsing row 3466
# parsing row 3467
# parsing row 3468
# parsing row 3469
# parsing row 3470
# parsing row 3471
# parsing row 3472
# parsing row 3473
# parsing row 3474
# parsing row 3475
# parsing row 3476
# parsing row 3477
# parsing row 3478
# parsing row 3479
# parsing row 3480
# parsing row 3481
# parsing row 3482
# parsing row 3483
# parsing row 3484
# parsing row 3485
# parsing row 3486
# parsing row 3487
# parsing row 3488
# parsing row 3489
# parsing row 3490
# parsing row 3491
# parsing row 3492
# parsing row 3493
# parsing row 3494
# parsing row 3495
# parsing row 3496
# parsing row 3497
# parsing row 3498
# parsing row 3499
# parsing row 3500
# parsing row 3501
# parsing row 3502
# parsing row 3503
# parsing row 3504
# parsing row 3505
# parsing row 3506
# parsing row 3507
# parsing row 3508
# parsing row 3509
# parsing row 3510
# parsing row 3511
# parsing row 3512
# parsing row 3513
# parsing row 3514
# parsing row 3515
# parsing row 3516
# parsing row 3517
# parsing row 3518
# parsing row 3519
# parsing row 3520
# parsing row 3521
# parsing row 3522
# parsing row 3523
# parsing row 3524
# parsing row 3525
# parsing row 3526
# parsing row 3527
# parsing row 3528
# parsing row 3529
# parsing row 3530
# parsing row 3531
# parsing row 3532
# parsing row 3533
# parsing row 3534
# parsing row 3535
# parsing row 3536
# parsing row 3537
# parsing row 3538
# parsing row 3539
# parsing row 3540
# parsing row 3541
# parsing row 3542
# parsing row 3543
# parsing row 3544
# parsing row 3545
# parsing row 3546
# parsing row 3547
# parsing row 3548
# parsing row 3549
# parsing row 3550
# parsing row 3551
# parsing row 3552
# parsing row 3553
# parsing row 3554
# parsing row 3555
# parsing row 3556
# parsing row 3557
# parsing row 3558
# parsing row 3559
# parsing row 3560
# parsing row 3561
# parsing row 3562
# parsing row 3563
# parsing row 3564
# parsing row 3565
# parsing row 3566
# parsing row 3567
# parsing row 3568
# parsing row 3569
# parsing row 3570
# parsing row 3571
# parsing row 3572
# parsing row 3573
# parsing row 3574
# parsing row 3575
# parsing row 3576
# parsing row 3577
# parsing row 3578
# parsing row 3579
# parsing row 3580
# parsing row 3581
# parsing row 3582
# parsing row 3583
# parsing row 3584
# parsing row 3585
# parsing row 3586
# parsing row 3587
# parsing row 3588
# parsing row 3589
# parsing row 3590
# parsing row 3591
# parsing row 3592
# parsing row 3593
# parsing row 3594
# parsing row 3595
# parsing row 3596
# parsing row 3597
# parsing row 3598
# parsing row 3599
# parsing row 3600
# parsing row 3601
# parsing row 3602
# parsing row 3603
# parsing row 3604
# parsing row 3605
# parsing row 3606
# parsing row 3607
# parsing row 3608
# parsing row 3609
# parsing row 3610
# parsing row 3611
# parsing row 3612
# parsing row 3613
# parsing row 3614
# parsing row 3615
# parsing row 3616
# parsing row 3617
# parsing row 3618
# parsing row 3619
# parsing row 3620
# parsing row 3621
# parsing row 3622
# parsing row 3623
# parsing row 3624
# parsing row 3625
# parsing row 3626
# parsing row 3627
# parsing row 3628
# parsing row 3629
# parsing row 3630
# parsing row 3631
# parsing row 3632
# parsing row 3633
# parsing row 3634
# parsing row 3635
# parsing row 3636
# parsing row 3637
# parsing row 3638
# parsing row 3639
# parsing row 3640
# parsing row 3641
# parsing row 3642
# parsing row 3643
# parsing row 3644
# parsing row 3645
# parsing row 3646
# parsing row 3647
# parsing row 3648
# parsing row 3649
# parsing row 3650
# parsing row 3651
# parsing row 3652
# parsing row 3653
# parsing row 3654
# parsing row 3655
# parsing row 3656
# parsing row 3657
# parsing row 3658
# parsing row 3659
# parsing row 3660
# parsing row 3661
# parsing row 3662
# parsing row 3663
# parsing row 3664
# parsing row 3665
# parsing row 3666
# parsing row 3667
# parsing row 3668
# parsing row 3669
# parsing row 3670
# parsing row 3671
# parsing row 3672
# parsing row 3673
# parsing row 3674
# parsing row 3675
# parsing row 3676
# parsing row 3677
# parsing row 3678
# parsing row 3679
# parsing row 3680
# parsing row 3681
# parsing row 3682
# parsing row 3683
# parsing row 3684
# parsing row 3685
# parsing row 3686
# parsing row 3687
# parsing row 3688
# parsing row 3689
# parsing row 3690
# parsing row 3691
# parsing row 3692
# parsing row 3693
# parsing row 3694
# parsing row 3695
# parsing row 3696
# parsing row 3697
# parsing row 3698
# parsing row 3699
# parsing row 3700
# parsing row 3701
# parsing row 3702
# parsing row 3703
# parsing row 3704
# parsing row 3705
# parsing row 3706
# parsing row 3707
# parsing row 3708
# parsing row 3709
# parsing row 3710
# parsing row 3711
# parsing row 3712
# parsing row 3713
# parsing row 3714
# parsing row 3715
# parsing row 3716
# parsing row 3717
# parsing row 3718
# parsing row 3719
# parsing row 3720
# parsing row 3721
# parsing row 3722
# parsing row 3723
# parsing row 3724
# parsing row 3725
# parsing row 3726
# parsing row 3727
# parsing row 3728
# parsing row 3729
# parsing row 3730
# parsing row 3731
# parsing row 3732
# parsing row 3733
# parsing row 3734
# parsing row 3735
# parsing row 3736
# parsing row 3737
# parsing row 3738
# parsing row 3739
# parsing row 3740
# parsing row 3741
# parsing row 3742
# parsing row 3743
# parsing row 3744
# parsing row 3745
# parsing row 3746
# parsing row 3747
# parsing row 3748
# parsing row 3749
# parsing row 3750
# parsing row 3751
# parsing row 3752
# parsing row 3753
# parsing row 3754
# parsing row 3755
# parsing row 3756
# parsing row 3757
# parsing row 3758
# parsing row 3759
# parsing row 3760
# parsing row 3761
# parsing row 3762
# parsing row 3763
# parsing row 3764
# parsing row 3765
# parsing row 3766
# parsing row 3767
# parsing row 3768
# parsing row 3769
# parsing row 3770
# parsing row 3771
# parsing row 3772
# parsing row 3773
# parsing row 3774
# parsing row 3775
# parsing row 3776
# parsing row 3777
# parsing row 3778
# parsing row 3779
# parsing row 3780
# parsing row 3781
# parsing row 3782
# parsing row 3783
# parsing row 3784
# parsing row 3785
# parsing row 3786
# parsing row 3787
# parsing row 3788
# parsing row 3789
# parsing row 3790
# parsing row 3791
# parsing row 3792
# parsing row 3793
# parsing row 3794
# parsing row 3795
# parsing row 3796
# parsing row 3797
# parsing row 3798
# parsing row 3799
# parsing row 3800
# parsing row 3801
# parsing row 3802
# parsing row 3803
# parsing row 3804
# parsing row 3805
# parsing row 3806
# parsing row 3807
# parsing row 3808
# parsing row 3809
# parsing row 3810
# parsing row 3811
# parsing row 3812
# parsing row 3813
# parsing row 3814
# parsing row 3815
# parsing row 3816
# parsing row 3817
# parsing row 3818
# parsing row 3819
# parsing row 3820
# parsing row 3821
# parsing row 3822
# parsing row 3823
# parsing row 3824
# parsing row 3825
# parsing row 3826
# parsing row 3827
# parsing row 3828
# parsing row 3829
# parsing row 3830
# parsing row 3831
# parsing row 3832
# parsing row 3833
# parsing row 3834
# parsing row 3835
# parsing row 3836
# parsing row 3837
# parsing row 3838
# parsing row 3839
# parsing row 3840
# parsing row 3841
# parsing row 3842
# parsing row 3843
# parsing row 3844
# parsing row 3845
# parsing row 3846
# parsing row 3847
# parsing row 3848
# parsing row 3849
# parsing row 3850
# parsing row 3851
# parsing row 3852
# parsing row 3853
# parsing row 3854
# parsing row 3855
# parsing row 3856
# parsing row 3857
# parsing row 3858
# parsing row 3859
# parsing row 3860
# parsing row 3861
# parsing row 3862
# parsing row 3863
# parsing row 3864
# parsing row 3865
# parsing row 3866
# parsing row 3867
# parsing row 3868
# parsing row 3869
# parsing row 3870
# parsing row 3871
# parsing row 3872
# parsing row 3873
# parsing row 3874
# parsing row 3875
# parsing row 3876
# parsing row 3877
# parsing row 3878
# parsing row 3879
# parsing row 3880
# parsing row 3881
# parsing row 3882
# parsing row 3883
# parsing row 3884
# parsing row 3885
# parsing row 3886
# parsing row 3887
# parsing row 3888
# parsing row 3889
# parsing row 3890
# parsing row 3891
# parsing row 3892
# parsing row 3893
# parsing row 3894
# parsing row 3895
# parsing row 3896
# parsing row 3897
# parsing row 3898
# parsing row 3899
# parsing row 3900
# parsing row 3901
# parsing row 3902
# parsing row 3903
# parsing row 3904
# parsing row 3905
# parsing row 3906
# parsing row 3907
# parsing row 3908
# parsing row 3909
# parsing row 3910
# parsing row 3911
# parsing row 3912
# parsing row 3913
# parsing row 3914
# parsing row 3915
# parsing row 3916
# parsing row 3917
# parsing row 3918
# parsing row 3919
# parsing row 3920
# parsing row 3921
# parsing row 3922
# parsing row 3923
# parsing row 3924
# parsing row 3925
# parsing row 3926
# parsing row 3927
# parsing row 3928
# parsing row 3929
# parsing row 3930
# parsing row 3931
# parsing row 3932
# parsing row 3933
# parsing row 3934
# parsing row 3935
# parsing row 3936
# parsing row 3937
# parsing row 3938
# parsing row 3939
# parsing row 3940
# parsing row 3941
# parsing row 3942
# parsing row 3943
# parsing row 3944
# parsing row 3945
# parsing row 3946
# parsing row 3947
# parsing row 3948
# parsing row 3949
# parsing row 3950
# parsing row 3951
# parsing row 3952
# parsing row 3953
# parsing row 3954
# parsing row 3955
# parsing row 3956
# parsing row 3957
# parsing row 3958
# parsing row 3959
# parsing row 3960
# parsing row 3961
# parsing row 3962
# parsing row 3963
# parsing row 3964
# parsing row 3965
# parsing row 3966
# parsing row 3967
# parsing row 3968
# parsing row 3969
# parsing row 3970
# parsing row 3971
# parsing row 3972
# parsing row 3973
# parsing row 3974
# parsing row 3975
# parsing row 3976
# parsing row 3977
# parsing row 3978
# parsing row 3979
# parsing row 3980
# parsing row 3981
# parsing row 3982
# parsing row 3983
# parsing row 3984
# parsing row 3985
# parsing row 3986
# parsing row 3987
# parsing row 3988
# parsing row 3989
# parsing row 3990
# parsing row 3991
# parsing row 3992
# parsing row 3993
# parsing row 3994
# parsing row 3995
# parsing row 3996
# parsing row 3997
# parsing row 3998
# parsing row 3999
# parsing row 4000
# parsing row 4001
# parsing row 4002
# parsing row 4003
# parsing row 4004
# parsing row 4005
# parsing row 4006
# parsing row 4007
# parsing row 4008
# parsing row 4009
# parsing row 4010
# parsing row 4011
# parsing row 4012
# parsing row 4013
# parsing row 4014
# parsing row 4015
# parsing row 4016
# parsing row 4017
# parsing row 4018
# parsing row 4019
# parsing row 4020
# parsing row 4021
# parsing row 4022
# parsing row 4023
# parsing row 4024
# parsing row 4025
# parsing row 4026
# parsing row 4027
# parsing row 4028
# parsing row 4029
# parsing row 4030
# parsing row 4031
# parsing row 4032
# parsing row 4033
# parsing row 4034
# parsing row 4035
# parsing row 4036
# parsing row 4037
# parsing row 4038
# parsing row 4039
# parsing row 4040
# parsing row 4041
# parsing row 4042
# parsing row 4043
# parsing row 4044
# parsing row 4045
# parsing row 4046
# parsing row 4047
# parsing row 4048
# parsing row 4049
# parsing row 4050
# parsing row 4051
# parsing row 4052
# parsing row 4053
# parsing row 4054
# parsing row 4055
# parsing row 4056
# parsing row 4057
# parsing row 4058
# parsing row 4059
# parsing row 4060
# parsing row 4061
# parsing row 4062
# parsing row 4063
# parsing row 4064
# parsing row 4065
# parsing row 4066
# parsing row 4067
# parsing row 4068
# parsing row 4069
# parsing row 4070
# parsing row 4071
# parsing row 4072
# parsing row 4073
# parsing row 4074
# parsing row 4075
# parsing row 4076
# parsing row 4077
# parsing row 4078
# parsing row 4079
# parsing row 4080
# parsing row 4081
# parsing row 4082
# parsing row 4083
# parsing row 4084
# parsing row 4085
# parsing row 4086
# parsing row 4087
# parsing row 4088
# parsing row 4089
# parsing row 4090
# parsing row 4091
# parsing row 4092
# parsing row 4093
# parsing row 4094
# parsing row 4095
# parsing row 4096
# parsing row 4097
# parsing row 4098
# parsing row 4099
# parsing row 4100
# parsing row 4101
# parsing row 4102
# parsing row 4103
# parsing row 4104
# parsing row 4105
# parsing row 4106
# parsing row 4107
# parsing row 4108
# parsing row 4109
# parsing row 4110
# parsing row 4111
# parsing row 4112
# parsing row 4113
# parsing row 4114
# parsing row 4115
# parsing row 4116
# parsing row 4117
# parsing row 4118
# parsing row 4119
# parsing row 4120
# parsing row 4121
# parsing row 4122
# parsing row 4123
# parsing row 4124
# parsing row 4125
# parsing row 4126
# parsing row 4127
# parsing row 4128
# parsing row 4129
# parsing row 4130
# parsing row 4131
# parsing row 4132
# parsing row 4133
# parsing row 4134
# parsing row 4135
# parsing row 4136
# parsing row 4137
# parsing row 4138
# parsing row 4139
# parsing row 4140
# parsing row 4141
# parsing row 4142
# parsing row 4143
# parsing row 4144
# parsing row 4145
# parsing row 4146
# parsing row 4147
# parsing row 4148
# parsing row 4149
# parsing row 4150
# parsing row 4151
# parsing row 4152
# parsing row 4153
# parsing row 4154
# parsing row 4155
# parsing row 4156
# parsing row 4157
# parsing row 4158
# parsing row 4159
# parsing row 4160
# parsing row 4161
# parsing row 4162
# parsing row 4163
# parsing row 4164
# parsing row 4165
# parsing row 4166
# parsing row 4167
# parsing row 4168
# parsing row 4169
# parsing row 4170
# parsing row 4171
# parsing row 4172
# parsing row 4173
# parsing row 4174
# parsing row 4175
# parsing row 4176
# parsing row 4177
# parsing row 4178
# parsing row 4179
# parsing row 4180
# parsing row 4181
# parsing row 4182
# parsing row 4183
# parsing row 4184
# parsing row 4185
# parsing row 4186
# parsing row 4187
# parsing row 4188
# parsing row 4189
# parsing row 4190
# parsing row 4191
# parsing row 4192
# parsing row 4193
# parsing row 4194
# parsing row 4195
# parsing row 4196
# parsing row 4197
# parsing row 4198
# parsing row 4199
# parsing row 4200
# parsing row 4201
# parsing row 4202
# parsing row 4203
# parsing row 4204
# parsing row 4205
# parsing row 4206
# parsing row 4207
# parsing row 4208
# parsing row 4209
# parsing row 4210
# parsing row 4211
# parsing row 4212
# parsing row 4213
# parsing row 4214
# parsing row 4215
# parsing row 4216
# parsing row 4217
# parsing row 4218
# parsing row 4219
# parsing row 4220
# parsing row 4221
# parsing row 4222
# parsing row 4223
# parsing row 4224
# parsing row 4225
# parsing row 4226
# parsing row 4227
# parsing row 4228
# parsing row 4229
# parsing row 4230
# parsing row 4231
# parsing row 4232
# parsing row 4233
# parsing row 4234
# parsing row 4235
# parsing row 4236
# parsing row 4237
# parsing row 4238
# parsing row 4239
# parsing row 4240
# parsing row 4241
# parsing row 4242
# parsing row 4243
# parsing row 4244
# parsing row 4245
# parsing row 4246
# parsing row 4247
# parsing row 4248
# parsing row 4249
# parsing row 4250
# parsing row 4251
# parsing row 4252
# parsing row 4253
# parsing row 4254
# parsing row 4255
# parsing row 4256
# parsing row 4257
# parsing row 4258
# parsing row 4259
# parsing row 4260
# parsing row 4261
# parsing row 4262
# parsing row 4263
# parsing row 4264
# parsing row 4265
# parsing row 4266
# parsing row 4267
# parsing row 4268
# parsing row 4269
# parsing row 4270
# parsing row 4271
# parsing row 4272
# parsing row 4273
# parsing row 4274
# parsing row 4275
# parsing row 4276
# parsing row 4277
# parsing row 4278
# parsing row 4279
# parsing row 4280
# parsing row 4281
# parsing row 4282
# parsing row 4283
# parsing row 4284
# parsing row 4285
# parsing row 4286
# parsing row 4287
# parsing row 4288
# parsing row 4289
# parsing row 4290
# parsing row 4291
# parsing row 4292
# parsing row 4293
# parsing row 4294
# parsing row 4295
# parsing row 4296
# parsing row 4297
# parsing row 4298
# parsing row 4299
# parsing row 4300
# parsing row 4301
# parsing row 4302
# parsing row 4303
# parsing row 4304
# parsing row 4305
# parsing row 4306
# parsing row 4307
# parsing row 4308
# parsing row 4309
# parsing row 4310
# parsing row 4311
# parsing row 4312
# parsing row 4313
# parsing row 4314
# parsing row 4315
# parsing row 4316
# parsing row 4317
# parsing row 4318
# parsing row 4319
# parsing row 4320
# parsing row 4321
# parsing row 4322
# parsing row 4323
# parsing row 4324
# parsing row 4325
# parsing row 4326
# parsing row 4327
# parsing row 4328
# parsing row 4329
# parsing row 4330
# parsing row 4331
# parsing row 4332
# parsing row 4333
# parsing row 4334
# parsing row 4335
# parsing row 4336
# parsing row 4337
# parsing row 4338
# parsing row 4339
# parsing row 4340
# parsing row 4341
# parsing row 4342
# parsing row 4343
# parsing row 4344
# parsing row 4345
# parsing row 4346
# parsing row 4347
# parsing row 4348
# parsing row 4349
# parsing row 4350
# parsing row 4351
# parsing row 4352
# parsing row 4353
# parsing row 4354
# parsing row 4355
# parsing row 4356
# parsing row 4357
# parsing row 4358
# parsing row 4359
# parsing row 4360
# parsing row 4361
# parsing row 4362
# parsing row 4363
# parsing row 4364
# parsing row 4365
# parsing row 4366
# parsing row 4367
# parsing row 4368
# parsing row 4369
# parsing row 4370
# parsing row 4371
# parsing row 4372
# parsing row 4373
# parsing row 4374
# parsing row 4375
# parsing row 4376
# parsing row 4377
# parsing row 4378
# parsing row 4379
# parsing row 4380
# parsing row 4381
# parsing row 4382
# parsing row 4383
# parsing row 4384
# parsing row 4385
# parsing row 4386
# parsing row 4387
# parsing row 4388
# parsing row 4389
# parsing row 4390
# parsing row 4391
# parsing row 4392
# parsing row 4393
# parsing row 4394
# parsing row 4395
# parsing row 4396
# parsing row 4397
# parsing row 4398
# parsing row 4399
# parsing row 4400
# parsing row 4401
# parsing row 4402
# parsing row 4403
# parsing row 4404
# parsing row 4405
# parsing row 4406
# parsing row 4407
# parsing row 4408
# parsing row 4409
# parsing row 4410
# parsing row 4411
# parsing row 4412
# parsing row 4413
# ...
#                              'social y la prevalencia \r\n'
#                              'e incremento de delitos paralelos, como la '
#                              'violencia y el robo \r\n'
#                              'domiciliario.\r\n'
#                              'Además, de la parálisis económica que tiene '
#                              'Coahuila, producto de la \r\n'
#                              'megadeuda convertida en meganegocio, y que en el '
#                              'caso de la Región \r\n'
#                              'Laguna, se ha traducido en la falta de inversión '
#                              'y abandono.\r\n'
#                              'Región que requiere atención en el tema del '
#                              'agua, con un \r\n'
#                              'reordenamiento en su distribución, y la '
#                              'actuación de la Comisión \r\n'
#                              'Nacional del Agua. Además, inversión en '
#                              'infraestructura, tanto de agua \r\n'
#                              'potable como de plantas tratadoras de aguas '
#                              'residuales.\r\n'
#                              'Aunado a la necesidad de inversión en '
#                              'infraestructura carretera, para la \r\n'
#                              'continuidad de los ejes carreteros; entre otros '
#                              'temas relevantes de la \r\n'
#                              'realidad que viven los habitantes de la Región '
#                              'Laguna.',
#                         'i': 1,
#                         'l': 'https://www.youtube.com/watch?v=9VnwyGPxwqc',
#                         'n': 'vocestvmx',
#                         't': '2023-04-19T05:17:15'},
#                        {'d': 'Mi nombre es Lenin Pérez, un revolucionario que '
#                              'sueña, así como tú, en que Coahuila puede ser '
#                              'mucho mejor, pero para que eso suceda, hay que '
#                              'sacar a los mismos políticos priistas que tienen '
#                              'secuestrado a nuestro estado desde hace 100 '
#                              'años.\n'
#                              '#SíHayOtroCamino',
#                         'i': 1,
#                         'l': 'https://www.youtube.com/watch?v=f6lqSF5Fya8',
#                         'n': 'Lenin Pérez',
#                         't': '2023-04-20T00:29:33'},
#                        {'d': 'Tras la revisión del presupuesto en materia de '
#                              'salud, para que su planteamiento tenga sustento, '
#                              'y no se convierta en demagogia, como lo hacen '
#                              'otros candidatos, LENIN PÉREZ, abanderado de la '
#                              'Coalición UDC-PV a la gubernatura, hizo el '
#                              'compromiso de que todos los niños y niñas con '
#                              'cáncer recibirán tratamiento oncológico '
#                              '#eleccionescoahuila  #candidatoscoahuila '
#                              '#coahuila #coahuila #eleccionescoahuila',
#                         'i': 0,
#                         'l': 'https://www.youtube.com/watch?v=lRrIzShaDDY',
#                         'n': 'Unidad Democrática de Coahuila',
#                         't': '2023-04-21T19:04:50'},
#                        {'d': 'Televisa Univision Saltillo',
#                         'i': 0,
#                         'l': 'https://www.youtube.com/watch?v=50yYw4gcazs',
#                         'n': 'Televisa Saltillo',
#                         't': '2023-04-21T07:33:04'},
#                        {'d': 'Apoya nuestro canal y las actividades de '
#                              '@SocCivilMx\n'
#                              'https://www.youtube.com/channel/UCV2yaa9tDWWH1VkpFbERYDg/join',
#                         'i': 26,
#                         'l': 'https://www.youtube.com/watch?v=c93UCuW8mrE',
#                         'n': 'Sociedad Civil México',
#                         't': '2023-04-20T02:22:17'},
#                        {'d': '#TelediarioCoahuila #Saltillo '
#                              '#TelediarioMatutino\n'
#                              '#AbrahamCazares #CintiaPuga\n'
#                              '\n'
#                              'La Coparmex organizó un segundo debate entre los '
#                              'candidatos a la gubernatura de Coahuila, el cual '
#                              'se llevó a cabo en el Tecnológico de Monterrey '
#                              'Campus Saltillo, en donde los candidatos se '
#                              'enfrentaron con sus argumentos.\n'
#                              '\n'
#                              'Sigue nuestra transmisión en vivo 👇🏻\n'
#                              'https://www.youtube.com/c/TELEDIARIOCOAHUILA\n'
#                              '\n'
#                              'Además todo el acontecer diario en\n'
#                              'https://multimedios.com/telediario\n'
#                              '\n'
#                              'Y nuestras redes sociales\n'
#                              'https://www.facebook.com/telediariocoahuila\n'
#                              'https://www.twitter.com/TelediarioCoah\n'
#                              'https://www.instagram.com/telediariocoahuila\n'
#                              '\n'
#                              'Programación\n'
#                              'Lunes a viernes:\n'
#                              'Telediario Matutino de 06:00- 10:00\n'
#                              'Telediario Mediodía de 12:00-14:00',
#                         'i': 11,
#                         'l': 'https://www.youtube.com/watch?v=mjK8ZZjyRxo',
#                         'n': 'Telediario Coahuila',
#                         't': '2023-04-20T20:00:10'},
#                        {'d': 'Toda la información que acontece en Piedras '
#                              'Negras, 5 manantiales, la carbonífera y el '
#                              'estado de Coahuila aquí.',
#                         'i': 2,
#                         'l': 'https://www.youtube.com/watch?v=544UjNBKyf4',
#                         'n': 'Televisa Piedras Negras',
#                         't': '2023-04-21T08:40:17'},
#                        {'d': 'El candidato LENIN PÉREZ de la Coalición UDC-PV '
#                              'promete tratamiento oncológico a niños y niñas '
#                              'con cáncer sin seguridad social en Coahuila. '
#                              'Argumenta que es factible y que muchas familias '
#                              'padecen la tragedia de luchar por sobrevivir.\n'
#                              '#EleccionesCoahuila #CompromisoPorLaSalud',
#                         'i': 0,
#                         'l': 'https://www.youtube.com/watch?v=5kF1TXGYVYk',
#                         'n': 'A TIEMPO TV',
#                         't': '2023-04-22T03:15:00'},
#                        {'d': 'Spot PVEM. Llegaron los de Siempre. Candidato '
#                              'Lenin Pérez Rivera de UDC-PVEM . Aspirante al '
#                              'gobierno de Coahuila',
#                         'i': 0,
#                         'l': 'https://www.youtube.com/watch?v=F6bvpJeq_5c',
#                         'n': 'Campaigns & Elections México',
#                         't': '2023-04-24T05:24:51'},
#                        {'d': '',
#                         'i': 55,
#                         'l': 'https://www.youtube.com/watch?v=gckeaOAAgFI',
#                         'n': 'De Buenas Fuentes con José Manuel Fuentes',
#                         't': '2023-04-20T14:22:29'},
#                        {'d': 'Debate organizado por la COPARMEX DE '
#                              'COAHUILA,aspirantes a la Gobernatura de Coahuila',
#                         'i': 381,
#                         'l': 'https://www.youtube.com/watch?v=XSILe3SRJFo',
#                         'n': 'La Grillotina Política',
#                         't': '2023-04-20T04:04:57'},
#                        {'d': '🔴ESCUCHA LO QUE PASO EN PRIMER DEBATE CIUDADANO '
#                              'EN COAHUILA DE NUEVO SE VEN LAS CARAS SE DICEN '
#                              'ESTO!\n'
#                              '\n'
#                              ' ✅SUSCRÍBETE A MI CANAL '
#                              'ALTERNO✅https://youtube.com/channel/UCFjDF1TaPBDkm3n2IUrKOqw \n'
#                              '\n'
#                              '👇👇👇👇🔴🔴🔴👇👇👇👇👇🔴🔴\n'
#                              'Si gustas apoyarme con un PAYPAL lo puedes hacer '
#                              'aquí.!\n'
#                              '👇👇\n'
#                              'http://www.paypal.me/vittorblogsoficial  \n'
#                              '\n'
#                              'https://www.facebook.com/Victtor-Blogs-375961543130667/\n'
#                              '\n'
#                              '\n'
#                              'noticias  gobierno de méxico noticias de hoy '
#                              'noticias de última hora zócalo en vivo\n'
#                              '\n'
#                              '#paypal   #AMLO #pri #prian #pan #traicion '
#                              '#noticias  #losperiodistas #adelamicha #pan  '
#                              '#corrupcion #haytiro #andrésmanuellópezobrador '
#                              '#mexico #méxico #periodista #markocortés #alito '
#                              '#alejandromoreno #vaxmexico #corruptos '
#                              '#robertogil #calderon #felipecalderón #felipe',
#                         'i': 470,
#                         'l': 'https://www.youtube.com/watch?v=F2YDgc_hs-o',
#                         'n': 'Vittor Blogs',
#                         't': '2023-04-20T04:44:47'},
#                        {'d': 'El candidato a gobernador por la Coalición '
#                              'UDC-PV, Lenin Pérez Rivera concluyó su agenda '
#                              'del domingo con una asamblea en la colonia '
#                              'Bucareli Norte de San Buenaventura, donde '
#                              'escuchó las necesidades y planteamientos '
#                              'ciudadanos. En Castaños, promovió su propuesta '
#                              'con los comerciantes del tianguis. \n'
#                              '#eleccionescoahuila  #CoaliciónUDC-PV '
#                              '#LeninPérez',
#                         'i': 0,
#                         'l': 'https://www.youtube.com/watch?v=LEkUTgs21is',
#                         'n': 'A TIEMPO TV',
#                         't': '2023-04-24T15:15:01'},
#                        {'d': '¡Dale like y comparte!\r\n'
#                              '\r\n'
#                              '\r\n'
#                              '\r\n'
#                              'Suscríbete a nuestro CANAL DE YOUTUBE: '
#                              'https://www.youtube.com/channel/UCAmhcXl_MpsZlS7RA-ISgdg\r\n'
#                              '\r\n'
#                              '\r\n'
#                              '\r\n'
#                              'Visita nuestro portal de noticias: '
#                              'http://www.sinpuntosnicomas.tv\r\n'
#                              '\r\n'
#                              'Síguenos en Twitter:  '
#                              'https://twitter.com/Sinpuntosnicom1\r\n'
#                              '\r\n'
#                              'Síguenos en Facebook: '
#                              'https://www.facebook.com/SPNCtv\r\n'
#                              '\r\n'
#                              'Síguenos en Instagram: '
#                              'https://www.instagram.com/spnctv\r\n'
#                              '\r\n'
#                              '\r\n'
#                              '\r\n'
#                              '\r\n'
#                              '#coahuila #mexico #elecciones2023',
#                         'i': 31,
#                         'l': 'https://www.youtube.com/watch?v=uxIiAdqBYhQ',
#                         'n': 'Sin Puntos Ni Comas Informa',
#                         't': '2023-04-19T13:44:24'},
#                        {'d': 'El candidato del PT a la gubernatura en '
#                              'Coahuila, Ricardo Mejía Berdeja, habla del por '
#                              'qué el candidato de Morena, Armando Guadiana, no '
#                              'es un opositor real al régimen de los hermanos '
#                              'priistas Humberto y Rubén Moreira en la '
#                              'entidad.\n'
#                              '\n'
#                              '#Coahuila #Moreira #Morena',
#                         'i': 1331,
#                         'l': 'https://www.youtube.com/watch?v=nJ2vgONVMAc',
#                         'n': 'LA OCTAVA',
#                         't': '2023-04-24T02:30:10'},
#                        {'d': 'Visita nuestro sitio web \n'
#                              'Zócalo http://bit.ly/2w4LMYd\n'
#                              '\n'
#                              'Síguenos en Redes Sociales\n'
#                              '\n'
#                              'Facebook\n'
#                              'Zócalo https://bit.ly/2Z3KPv7\n'
#                              'Tele Saltillo https://bit.ly/3jK7JQa\n'
#                              '\n'
#                              'Twitter\n'
#                              'Zócalo https://bit.ly/351HvUX\n'
#                              'Tele Saltillo https://bit.ly/3brTOLn\n'
#                              '\n'
#                              'Instagram\n'
#                              'Zócalo http://bit.ly/2VpvdRL\n'
#                              'Tele Saltillo http://bit.ly/37ZHsqt',
#                         'i': 0,
#                         'l': 'https://www.youtube.com/watch?v=TGB68i_daGU',
#                         'n': 'Tele Saltillo',
#                         't': '2023-04-22T18:50:46'},
#                        {'d': 'En compañía de candidatos de la Coalición a '
#                              'diputaciones locales de distritos de la Región '
#                              'Sureste Lenin Pérez Rivera, realizó volanteo y '
#                              'pega de calcas en cruceros de #Saltillo además '
#                              'de visitar colonias como la Guayulera\n'
#                              '#Enlace13Saltillo #Coahuila #Elecciones2023',
#                         'i': 0,
#                         'l': 'https://www.youtube.com/watch?v=YbZmOeUJmwU',
#                         'n': 'Enlace 13 Saltillo  ',
#                         't': '2023-04-24T17:17:00'},
#                        {'d': 'AHORA DICEN QUE EL CASO VON ROERICH ES '
#                              'PERSECUCIÓN, SON PANISTAS\n'
#                              '#noticiasméxico \n'
#                              '#sinbozalmx \n'
#                              '#scjn \n'
#                              '#lorenzocórdova \n'
#                              '#lillytellez \n'
#                              '#ministros \n'
#                              '#presidente',
#                         'i': 6150,
#                         'l': 'https://www.youtube.com/watch?v=o1eUdyEdEBg',
#                         'n': 'Sin Bozal Mx',
#                         't': '2023-04-22T07:10:40'},
#                        {'d': '#noticiasmexico \n'
#                              '#acmcanal54 \n'
#                              '#noticias \n'
#                              '#pvem \n'
#                              '#candidato \n'
#                              '#coahuila \n'
#                              '#elecciones2023 \n'
#                              '#politica',
#                         'i': 1052,
#                         'l': 'https://www.youtube.com/watch?v=2nkN-Nntp7s',
#                         'n': 'ACM Canal 54',
#                         't': '2023-04-22T01:15:02'}]},
#  'query': '"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr',
#  'visualization_url': 'https://informationtracer.com/?result=8123d531a23c09b041655dcd85e04079e3beac62218314eab4b7e6e65f8afee0'}
# network table done

# %% [markdown]
# # Daily update

# %%
query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}

# %%
print('##############################')
print('Update starts')

# helper: daily update
# print('helper table starts')
# today = datetime.now(pytz.timezone('America/Mexico_City')).date()
# tomorrow=datetime.now(pytz.timezone('America/Mexico_City')).date() + timedelta(days=1)
# generate_helper_table(start_date=tomorrow, end_date=tomorrow, update_db=True)
# print('helper table done')


# infotracer and sentiment: daily update
print('infotracer and sentiment table start')
# today = datetime.now(pytz.timezone('America/Mexico_City')).date().strftime('%Y-%m-%d')
# tomorrow=(datetime.now(pytz.timezone('America/Mexico_City')).date() + timedelta(days=1)).strftime('%Y-%m-%d')
today='2023-04-16'
tomorrow='2023-04-17'
generate_infotracer_and_sentiment_table(start_date=today, end_date=tomorrow, ytb_end_date=tomorrow,update_db=True)
print('infotracer and sentiment table done')

# wordcloud: daily update
print('wordcloud table starts')
generate_wordcloud_table()
print('wordcloud table done')

# network: daily update
print('network table starts')
generate_network_table(start_date=today, end_date=tomorrow,update_db=True)
print('network table done')

print('Update ends')
print('##############################')
