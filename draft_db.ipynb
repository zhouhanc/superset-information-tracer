# %%
# !pip install mysql-connector-python
# !pip install informationtracer
# !pip install pysentimiento
pip install --upgrade accelerate

# %%
pip install transformers==4.28.0

# %% [markdown]
# # Import

# %%
import os

from informationtracer import informationtracer
import requests
import mysql.connector

import pandas as pd
import numpy as np
import random

import pytz
from pytz import timezone
from datetime import datetime
from datetime import date
from datetime import datetime, timedelta

from pysentimiento.preprocessing import preprocess_tweet
from pysentimiento import create_analyzer


import itertools

import re
import string
from wordcloud import WordCloud

# %% [markdown]
# # Create database and table

# %%
with open(os.path.expanduser('db_info.txt'), 'r') as f:
    lines = f.readlines()

localhost = lines[0].strip()
username = lines[1].strip()
pw = lines[2].strip()


#connect to database
mydb = mysql.connector.connect(
  host=localhost,
  user=username,
  password=pw
)


mycursor = mydb.cursor()
# create a databse called "dashboard"
#mycursor.execute("CREATE DATABASE dashboard")

# %%
# select database to modify
mycursor.execute("use dashboard")

# delete table
# mycursor.execute("drop table if exists infotracer")
# mycursor.execute("drop table if exists sentiment")
# mycursor.execute("drop table if exists wordcloud")
# mycursor.execute("drop table if exists network")
# mycursor.execute("drop table if exists helper")

# create table
# mycursor.execute("create table infotracer (candidate_name varchar(255), text MediumTEXT, username varchar(255), num_interaction int, datetime timestamp, platform varchar(255) )")
# mycursor.execute("create table sentiment (text MediumTEXT, processed_text MediumTEXT, positive float, neutral float, negative float, label varchar(255),candidate_name varchar(255), platform varchar(255), username varchar(255), num_interaction int, datetime timestamp )")
# mycursor.execute("create table wordcloud (word varchar(255), weight float, candidate_name varchar(255),platform varchar(255))")
# mycursor.execute("create table network (source varchar(255), target varchar(255), weight float, source_cat varchar(255), target_cat varchar(255), source_datetime timestamp, target_datetime timestamp, candidate_name varchar(255))")
# mycursor.execute("create table helper (datetime timestamp,candidate_name varchar(255),label varchar(255),platform varchar(255))")
# mydb.commit()

# %% [markdown]
# delete data

# %%
# # !!!!!!!!!!!!!!!!!!!!!!!!always remember to commit!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# mycursor.execute("DELETE FROM infotracer WHERE datetime >= '2023-05-26 18:00:00' AND datetime <= '2023-05-27 18:00:00'")
# mycursor.execute("DELETE FROM sentiment WHERE datetime >= '2023-05-26 18:00:00' AND datetime <= '2023-05-27 18:00:00'")
# # mycursor.execute("DELETE FROM network")
# # 18:00 is mexico time, when collect still use 00:00 to 23:59
# mydb.commit()

# %% [markdown]
# modify candidate name

# %%
# mycursor.execute("UPDATE wordcloud SET candidate_name = 'Ricardo Mejía Berdeja' WHERE candidate_name = 'Ricardo Mejia Berdeja'")
# mycursor.execute("UPDATE wordcloud SET candidate_name = 'Lenin Pérez Rivera' WHERE candidate_name = 'Lenin Perez Rivera'")
# mycursor.execute("UPDATE infotracer SET candidate_name = 'Ricardo Mejía Berdeja' WHERE candidate_name = 'Ricardo Mejia Berdeja'")
# mycursor.execute("UPDATE infotracer SET candidate_name = 'Lenin Pérez Rivera' WHERE candidate_name = 'Lenin Perez Rivera'")
# mycursor.execute("UPDATE sentiment SET candidate_name = 'Ricardo Mejía Berdeja' WHERE candidate_name = 'Ricardo Mejia Berdeja'")
# mycursor.execute("UPDATE sentiment SET candidate_name = 'Lenin Pérez Rivera' WHERE candidate_name = 'Lenin Perez Rivera'")
# mycursor.execute("UPDATE helper SET candidate_name = 'Ricardo Mejía Berdeja' WHERE candidate_name = 'Ricardo Mejia Berdeja'")
# mycursor.execute("UPDATE helper SET candidate_name = 'Lenin Pérez Rivera' WHERE candidate_name = 'Lenin Perez Rivera'")
# mydb.commit()

# %% [markdown]
# #ELT helper table

# %%
def generate_helper_table(start_date,end_date,update_db=True):
  
##############################################################################
##  This function generates a helper table that is used to join with other table to fill in time gaps.
##  Records are inserted to table within function.
##############################################################################

  # Define platforms and labels
  platforms = ['facebook','twitter','instagram','youtube','youtube comment']
  labels = ['POS','NEU','NEG']
  candidate_name=['Manolo Jiménez Salinas','Armando Guadiana Tijerina','Ricardo Mejia Berdeja','Lenin Perez Rivera']
  # Generate date range
  date_range = pd.date_range(start=start_date, end=end_date)

  # Generate combinations of platform and label for each date
  date_platform_label = list(itertools.product(date_range, platforms, labels,candidate_name))

  # Create DataFrame
  helper_df = pd.DataFrame(date_platform_label, columns=["datetime", "platform", "label",'candidate_name'])


  if update_db==True:
    # Insert to db
    helper_data = helper_df.apply(tuple, axis=1).tolist()
    # change order of column to fit df
    query="insert into helper (datetime,platform,label, candidate_name) Values(%s,%s,%s,%s);" 
    mycursor.executemany(query,helper_data)
    mydb.commit()

  return

# %% [markdown]
# # ETL for infotracer table

# %%
def convert_time(column):

##############################################################################
##  This function takes the datetime column of any dataframe 
##  and convert utc time to mexico time.
##  This function is part of another function. DO NOT run directly.
##############################################################################

  column=column.apply(lambda x: pytz.utc.localize(x))
  #utc to mexico time
  mexico_tz = timezone('America/Mexico_City')
  convert_timestamp = lambda x: x.astimezone(mexico_tz).replace(tzinfo=None)
  column = column.apply(convert_timestamp)
  return column

# %%
def generate_infotracer_table(start_date,end_date,update_db=True):

########################################################################################
##  This function query data using information tracer, store in df, convert time and insert
##  data into information tracer table. It returns a df of qury result. This result will be used for sentiment analysis.
##  This function is part of another function. DO NOT run directly.
########################################################################################

  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # query with information tracer api
  df=[]

  for candidate, query in query_dict.items():
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date)
    url = "https://informationtracer.com/api/v1/result?token={}&id_hash256={}".format(your_token, id_hash256)
    results = requests.get(url).json() #will get json for all data of keyword, results is a dictionary

    for pf in ['facebook','twitter','instagram','youtube']:
      platform_data=pd.DataFrame(results['posts'][pf], columns=['d','i','n','t'])
      platform_data['platform']=pf
      platform_data['candidate_name']=candidate
      platform_data['t']=pd.to_datetime(platform_data['t'])
      df.append(platform_data)

  df=pd.concat(df)
  df=df.rename(columns={'d':'text','i':'num_interaction','n':'username','t':'datetime'})

  # convert timezone
  df['datetime'] = convert_time(df['datetime'])
  df=df.drop_duplicates()

  print('#################################################')
  print('the shape of infotracer table is:',df.shape)
  print('#################################################')

  if update_db==True:
    # insert to db
    infotracer_data = df.apply(tuple, axis=1).tolist()
    query="insert into infotracer (text,num_interaction,username,datetime,platform,candidate_name) Values(%s,%s,%s,%s,%s,%s);"
    mycursor.executemany(query,infotracer_data)

    mydb.commit()
    # return query result
  return df

# %%
# result416=generate_infotracer_table(start_date='2023-04-16',end_date='2023-04-17',update_db=False)

# %% [markdown]
# # ETL data for sentiment table

# %% [markdown]
# ## youtube comment functions

# %%
##############################################################################
##  NOTE: register youtube API key!
## 
##  Follow instruction here: 
##  https://developers.google.com/youtube/registering_an_application
##
##  One key is enough, more keys can speed up the data collection process
#############################################################################

# read a dictionary of names and values of youtube api key 
API_KEY= {}

with open(os.path.expanduser('youtube_tokens.txt'), 'r') as f:
    for line in f:
        key, value = line.strip().split(',')
        API_KEY[key] = value

API_KEY = list(API_KEY.values())

def search_replies(comment_id):
    headers = {
        'Accept': 'application/json',
    }    

    params = (
        ('part', 'snippet,id'),
        ('parentId', comment_id),
        ('key', random.choice(API_KEY)),
        ('maxResults', '100')        
    )
    
    results = []
    response = requests.get('https://www.googleapis.com/youtube/v3/comments', headers=headers, params=params)
    
    print("Youtube response code --> ", response.status_code)
    if int(response.status_code) > 300:
        print(response.text)
        print('Youtube API v3/videos returns non 200 status code, something is very wrong')
        return results

    results += [item for item in response.json()['items']]
#     print(results)
    nextPageToken = response.json().get('nextPageToken', None)
    
    while nextPageToken:
        print(nextPageToken)
        params = (
            ('part', 'snippet,id'),
            ('parentId', comment_id),
            ('key', random.choice(API_KEY)),
            ('maxResults', '100'),
            ('pageToken', nextPageToken)
        )
        
        response = requests.get('https://www.googleapis.com/youtube/v3/comments', headers=headers, params=params)
        print("Youtube response code --> ", response.status_code)
        if int(response.status_code) > 300:
            print(response.text)
            print('Youtube API v3/videos returns non 200 status code, something is very wrong')
            break
    
        results += [item for item in response.json()['items']]
        nextPageToken = response.json().get('nextPageToken', None)
        
    return results




def search_comments(video_id):        
    headers = {
        'Accept': 'application/json',
    }    

    params = (
        ('part', 'snippet,replies'),
        ('videoId', video_id),
        ('key', random.choice(API_KEY)),
        ('maxResults', '100')        
    )
    
    results = []
    response = requests.get('https://www.googleapis.com/youtube/v3/commentThreads', headers=headers, params=params)
    print("Youtube response code --> ", response.status_code)
    if int(response.status_code) > 300:
        print(response.text)
        print('Youtube API v3/videos returns non 200 status code, something is very wrong')
        return results

    results += [item for item in response.json()['items']]
    nextPageToken = response.json().get('nextPageToken', None)
    
    while nextPageToken:
        print(nextPageToken)
        params = (
            ('part', 'snippet,replies'),
            ('videoId', video_id),
            ('key', random.choice(API_KEY)),
            ('maxResults', '100'),
            ('pageToken', nextPageToken)
        )
        
        response = requests.get('https://www.googleapis.com/youtube/v3/commentThreads', headers=headers, params=params)
        print("Youtube response code --> ", response.status_code)
        if int(response.status_code) > 300:
            print(response.text)
            print('Youtube API v3/videos returns non 200 status code, something is very wrong')
            break
    
        results += [item for item in response.json()['items']]
        nextPageToken = response.json().get('nextPageToken', None)
    
    for i in results:
        if i['snippet']['totalReplyCount'] > 5:
            print('hydrating more comments...')
            i['replies']['comments'] = search_replies(i['id'])
            print(len(i['replies']['comments']))

    # save results    
    return results

# %%
def convert_time_ytb(column):
##############################################################################
##  This function takes the datetime column of any dataframe 
##  and convert utc time to mexico time. For ytb comment only.
##  This function is part of another function. DO NOT run directly.
##############################################################################

  #utc to mexico time
  mexico_tz = timezone('America/Mexico_City')
  convert_timestamp = lambda x: x.astimezone(mexico_tz).replace(tzinfo=None)
  column = column.apply(convert_timestamp)
  return column

# %% [markdown]
# ## youtube query

# %%
def query_youtube_comment(start_date,end_date):
##############################################################################
##  This function use information tracer result to query for youtube comment, 
##  and convert utc time to mexico time.
##  This function is part of another function. DO NOT run directly.
##############################################################################
  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # get video id from information tracer source data
  videoId_dic={}
  for candidate, query in query_dict.items():
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date,skip_result=True)
    url="https://informationtracer.com/loadsource?source={}&id_hash256={}&token={}".format('youtube', id_hash256, your_token)
    results=requests.get(url).json()
    videoId_dic[candidate] = [data['id']['videoId'] for data in results] 
  
  # query comments using youtube api
  ytbcomment_df=[]
  for candidate, videoId_list in videoId_dic.items():
    comment=[]
    username=[]
    likeCount=[]
    date=[]
    for vid in videoId_list:
      if vid!=[]:
        result=search_comments(vid)
        for i in np.arange(0,len(result),1):
          comment.append(result[i]['snippet']['topLevelComment']['snippet']['textDisplay'])
          username.append(result[i]['snippet']['topLevelComment']['snippet']['authorDisplayName'])
          likeCount.append(result[i]['snippet']['topLevelComment']['snippet']['likeCount'])
          date.append(result[i]['snippet']['topLevelComment']['snippet']['publishedAt'])
      ytbcomment= pd.DataFrame({'text': comment, 'num_interaction': likeCount, 
                      'username': username,'datetime': date})
      ytbcomment['platform']='youtube comment'
      ytbcomment['candidate_name']=candidate
      ytbcomment['datetime']=pd.to_datetime(ytbcomment['datetime'])
      ytbcomment_df.append(ytbcomment)
  ytbcomment_df=pd.concat(ytbcomment_df)
  

  # convert timezone
  if ytbcomment_df.empty==False:
    ytbcomment_df['datetime'] = convert_time_ytb(ytbcomment_df['datetime'])
    ytbcomment_df=ytbcomment_df.drop_duplicates()

  print('#################################################')
  print('the shape of youtube comment is:',ytbcomment_df.shape)
  print('#################################################')
  # return query result
  return ytbcomment_df

# %% [markdown]
# ## text process functions

# %%
# remove \n and ...
def remove_n(df):
  df['text'] = df['text'].str.replace(r'\n|\n.', '', regex=True)
  df['text'] = df['text'].str.replace(r'\.{2,}', '.', regex=True)
  return df
  
# parse
def parse(df):
  print('#################################################')
  print('the shape of merged df is:',df.shape)
  print('start parsing')
  print('#################################################')
  df=remove_n(df)
  df=df.drop_duplicates()
  # new_df = pd.DataFrame(columns=df.columns)
  parsed_df=[]
  # iterate over each row in the original dataframe
  for index, row in df.iterrows():
    print('parsing row', index)
    # split the "text" column value into a list of sentences
    sentences = row['text'].split('. ')  # assuming sentences are separated by ". "
    new_df=pd.DataFrame({
            'text': sentences,
            'num_interaction': row['num_interaction'],
            'username':row['username'],
            'datetime': row['datetime'],
            'platform': row['platform'],
            'candidate_name': row['candidate_name']            
    })
    parsed_df.append(new_df)

  parsed_df=pd.concat(parsed_df)
  return parsed_df

# %%
# Define a function to restore spanish accents
def replace_special_chars(text):
  text = re.sub(r'\\u([\da-fA-F]{4})', lambda m: chr(int(m.group(1), 16)), text)
  # Remove punctuation
  text = text.translate(str.maketrans('', '', string.punctuation))
  text = ''.join([i for i in text if not i.isdigit()])
  # # Create a SnowballStemmer for Spanish
  # stemmer = SnowballStemmer('spanish')
  # # Apply stemming
  # words = text.split()
  # stemmed_words = [stemmer.stem(word) for word in words]
  # return ' '.join(stemmed_words)
  return text

def text_process(df):
  # restore accent
  df['text'] = df['text'].apply(replace_special_chars)
  # process tweet is a func from pysentimiento
  df['processed_text'] = df['text'].apply(preprocess_tweet)

  # other steps

  return df

# %% [markdown]
# ## sentiment analysis function

# %%
# do sentiment analysis in batches
def sent_analyze(df):
  batch=512
  analyzer = create_analyzer(task="sentiment", lang="es", batch_size=batch)

  text=df['processed_text'].tolist() #list of texts
  label=[]
  pos_prob=[]
  neu_prob=[]
  neg_prob=[]
  for i in range(0, len(text), batch):
    analyze_result=analyzer.predict(text[i:i+batch])

    label+=[r.output for r in analyze_result]
    pos_prob+=[r.probas['POS'] for r in analyze_result]
    neu_prob+=[r.probas['NEU'] for r in analyze_result]
    neg_prob+=[r.probas['NEG'] for r in analyze_result]
    print("Batch {} done".format(int(i/512)))

  df['label']=label
  df['positive']=pos_prob
  df['neutral']=neu_prob
  df['negative']=neg_prob
  return df

# %%
def generate_infotracer_and_sentiment_table(start_date,end_date,ytb_end_date,update_db=True):

###########################################################################
## This function generates both infotracer and sentiment table.
## It calls information tracer and ytb comment function within it,
## merge result, process text and conduct sentiment analysis.
###########################################################################

  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}
  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  # get information tracer query result (also insert to db)
  df=generate_infotracer_table(start_date=start_date,end_date=end_date,update_db=update_db)

  #get youtube comment query result
  ytbcomment_df=query_youtube_comment(start_date=start_date,end_date=ytb_end_date)

  # merge results
  # text for sentiment table: everything in df + used youtube raw data to extract comment
  sentiment_df=pd.concat([ytbcomment_df,df])
  sentiment_df=sentiment_df.reset_index(drop=True)

  #parse post into sentences
  sentiment=parse(sentiment_df)

  #################################
  ## text processing
  #################################
  sentiment=text_process(sentiment)

  # sentiment calculation

  full_sentiment=sent_analyze(sentiment)
  if update_db==True:
    # commit full sentiment to sentiment table in db
    sent_data = full_sentiment.apply(tuple, axis=1).tolist()
    query="insert into sentiment (text,num_interaction,username,datetime,platform,candidate_name,processed_text,label, positive, neutral, negative) Values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);" 
    mycursor.executemany(query,sent_data)

    mydb.commit()

  return

# %% [markdown]
# # ETL data for wordcloud

# %%
def clean_text(sentence):
  # all lower-case
  sentence = sentence.lower()
  # remove punctuations 
  sentence = re.sub(r"[,.¡¿\"@#$%^&*(){}?/;:<>+=-]", "", sentence)
  # remove numbers
  sentence = re.sub(r'\d+', '', sentence)
  # remove leading/trailing whitespace
  sentence = sentence.strip()
  
  return sentence

# %%
def generate_wordcloud_table():
  #query for data in last 14 days
  wc_query= "SELECT processed_text, platform, candidate_name, datetime FROM sentiment WHERE datetime >= DATE_SUB(NOW(), INTERVAL 14 DAY) "
  word_cloud_df= pd.read_sql_query(wc_query, mydb)
  
  #process text
  word_cloud_df['processed_text']=word_cloud_df['processed_text'].apply(lambda x: clean_text(x))


  # stop words
  
  with open(os.path.expanduser('spanish.txt'), 'r') as f:
    spanish_stopwords = [line.strip() for line in f]
  stop_words = set(spanish_stopwords)
  stop_words.add('emoji') 
  stop_words.add('http')
  stop_words.add('youtube')
  stop_words.add('twitter')
  stop_words.add('instagram')
  stop_words.add('facebook')

  # generate wordcloud df
  wc=[]
  for platform in word_cloud_df['platform'].unique():
    for candidate in word_cloud_df['candidate_name'].unique():
      all_text = ' '.join(word_cloud_df[(word_cloud_df['platform']==platform)&(word_cloud_df['candidate_name']==candidate)]['processed_text'])
      if all_text=='':
        all_text='NADA'
        print(platform, candidate, all_text)
      wordcloud = WordCloud(stopwords=stop_words).generate(all_text)
      # Get list of words in wordcloud
      word_list = list(wordcloud.words_.keys())
      word_weights = list(wordcloud.words_.values())
      sub_wc=pd.DataFrame({'word':word_list, 'frequency':word_weights,'platform': platform,'candidate_name':candidate})
      wc.append(sub_wc)

  wc=pd.concat(wc)
  print('shape of wordcloud is',wc.shape)

  # empty the table
  print('empty the table')
  mycursor.execute(f'DELETE FROM wordcloud')
  mydb.commit()

  # insert to db last 14 days data
  print('start inserting')
  wc_data = wc.apply(tuple, axis=1).tolist()
  query="insert into wordcloud (word,weight, platform, candidate_name) Values(%s,%s,%s,%s);" 
  mycursor.executemany(query,wc_data)
  print('done')

  mydb.commit()

  return

# %% [markdown]
# # ETL data for network

# %%
def generate_network_table(start_date,end_date,update_db=True):
  
  # predefined query
  query_dict={'Manolo Jiménez Salinas':'"Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejia Berdeja':'"Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Perez Rivera':'"Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}

  # information tracer token
  with open(os.path.expanduser('infotracer_token.txt'), 'r') as f:
      your_token = f.read()

  for candidate, query in query_dict.items():
    ## extract data
    id_hash256 = informationtracer.trace(query=query, token=your_token, start_date=start_date, end_date=end_date)
    url = "https://informationtracer.com/cross_platform/{}/interaction_network_{}.json".format(id_hash256[:3], id_hash256)

    network_json = requests.get(url).json()

    ## construct df
    node_id_to_category = {}
    node_id_to_name={}
    node_id_to_datetime={}
    node_id_to_platform={}

    ## iterate all nodes to save node type
    for node in network_json['nodes']:
      node_id_to_category[node['id']] = node['type']
      node_id_to_name[node['id']]=node['name']
      node_id_to_datetime[node['id']]=node['timestamp']
      node_id_to_platform[node['id']]=node['platform']

    ## iterate all links
    source=[]
    target=[]
    weight=[]
    source_cat=[]
    target_cat=[]
    source_datetime=[]
    target_datetime=[]

    for link in network_json['links']:
      source_id = link['source']
      target_id = link['target']
      source_datetime.append(node_id_to_datetime[source_id])
      target_datetime.append(node_id_to_datetime[target_id])

      source_cat.append(node_id_to_category[source_id])
      target_cat.append(node_id_to_category[target_id])

      # to distinguish user with same name on different platform
      if node_id_to_category[source_id]=='user':
        source.append((node_id_to_name[source_id]+' '+node_id_to_platform[source_id]))
      else: 
        source.append(node_id_to_name[source_id])
      
      if node_id_to_category[target_id]=='user':
        target.append((node_id_to_name[target_id]+' '+node_id_to_platform[target_id]))
      else:
        target.append(node_id_to_name[target_id])
      
      weight.append(link['weight'])


    nw_df = pd.DataFrame({
        'source': source,
        'target': target,
        'weight': weight,
        'source_cat': source_cat,
        'target_cat': target_cat,
        'source_datetime': source_datetime,
        'target_datetime': target_datetime
    })
    nw_df['source_datetime']=pd.to_datetime(nw_df['source_datetime'])
    nw_df['target_datetime']=pd.to_datetime(nw_df['target_datetime'])
    nw_df['source_datetime']=convert_time(nw_df['source_datetime'])
    nw_df['target_datetime']=convert_time(nw_df['target_datetime'])

    nw_df['candidate_name']=candidate
    if update_db==True:
      ##### insert into mysql table source, target, weight, source_category, target_category
      nw_data=nw_df.apply(tuple, axis=1).tolist()
      query="insert into network (source, target, weight, source_cat, target_cat, source_datetime, target_datetime, candidate_name) Values(%s,%s,%s,%s,%s,%s,%s,%s);"
      mycursor.executemany(query,nw_data)

      mydb.commit()

  return

# %% [markdown]
# # Historical

# %% [markdown]
# **different from databse_buildup.py !!!!!!!!!!!!!!!!!!**
# <br>
# **add query_dict parameter**

# %%
# if start date=0415, end date=0416, it means from 0415 00:00 to 0416 23:59!!!
# 0415 00：00-0416-23：59 << start 0415, end 0416
# 0416 00：00-0416 23：59 << start 0416, end 0416

# %%
# !!!!!!!!!!!!!!!!!!!!!!!!always remember to commit!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
mycursor.execute("DELETE FROM infotracer WHERE datetime >= '2023-05-26 18:00:00' AND datetime <= '2023-05-27 18:00:00'")
mycursor.execute("DELETE FROM sentiment WHERE datetime >= '2023-05-26 18:00:00' AND datetime <= '2023-05-27 18:00:00'")
# mycursor.execute("DELETE FROM network")
# 18:00 is mexico time, when collect still use 00:00 to 23:59
mydb.commit()

# %%
# # infotracer and sentiment: add historical data
generate_infotracer_and_sentiment_table(start_date="2023-05-27",end_date="2023-05-27",ytb_end_date="2023-05-27",update_db=True)

# # network: add historical data
# print('network table starts')
# generate_network_table(start_date="2023-04-19",end_date="2023-04-24",update_db=True)
# print('network table done')

# # helper: add historical data
# generate_helper_table(start_date="2023-01-01",end_date="2023-04-08")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#                               'Dios es nuestra fuerza y el voto 🗳️ nuestra '
#                               'arma ! \n'
#                               '\n'
#                               'Amén 🙏',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/893090070733896/permalink/6420908877951960',
#                          'n': 'OFERTAS PARRAS ✔️',
#                          't': '2023-05-27T16:05:09'},
#                         {'d': 'En Coahuila ! Apoyamos a Amlo 18 años ! Para '
#                               'llegar a la Presidencia de Mexico Nos prometió '
#                               'meter a la cárcel a los Moreira ! \n'
#                               '\n'
#                               'Lo seguimos apoyando y estamos esperando que '
#                               'los meta a la cárcel ! \n'
#                               '\n'
#                               'Ricardo Mejia Berdeja ha sido leal y fiel a su '
#                               'Gobierno ! \n'
#                               '\n'
#                               'Hoy lo menos que esperamos es que Amlo apoye y '
#                               'respete la voluntad de miles que queremos '
#                               'cambiar nuestro Estado ! \n'
#                               '\n'
#                               'Nosotros no tenemos la culpa de que las '
#                               'encuestas en Morena sean falsas y su candidato '
#                               'Guadiana un perdedor ! \n'
#                               '\n'
#                               'Manolo Jiménez es el adversario , el pri y los '
#                               'Moreira se tienen que ir de Coahuila ! \n'
#                               '\n'
#                               'Todos unidos con #mejia ! \n'
#                               '\n'
#                               'Que viva Coahuila ! \n'
#                               '\n'
#                               'Luchemos y votemos este 4 de junio por nuestra '
#                               'libertad ! \n'
#                               '\n'
#                               'Unidos corrijamos el rumbo ! \n'
#                               '\n'
#                               'Dios es nuestra fuerza y el voto 🗳️ nuestra '
#                               'arma ! \n'
#                               '\n'
#                               'Amén 🙏',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/893090070733896/permalink/6420896351286546',
#                          'n': 'OFERTAS PARRAS ✔️',
#                          't': '2023-05-27T16:00:36'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/529455983875822/permalink/2619590701528996',
#                          'n': 'Ofertas y Ventas Parras',
#                          't': '2023-05-27T16:41:51'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/613647975394373/permalink/6297107903714990',
#                          'n': 'ciberpulga de muzquiz coahuila',
#                          't': '2023-05-27T16:41:59'},
#                         {'d': '🎧🇲🇽 ¿Ya escucharon la canción que le hicieron a '
#                               'Ricardo Mejia Berdeja?\n'
#                               '\n'
#                               '😎👉🏻 ¡El pueblo sabe quién será el próximo '
#                               'Gobernador de Coahuila!',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/192380770905808/permalink/3303234796487041',
#                          'n': 'Bazar 5 Manantiales',
#                          't': '2023-05-27T15:30:32'},
#                         {'d': '📢 ¡𝗖𝗶𝗲𝗿𝗿𝗲 𝗥𝗲𝗴𝗶𝗼𝗻𝗮𝗹 𝗲𝗻 𝗔𝗰𝘂𝗻̃𝗮! Seguimos firmes '
#                               'con la transformación de #Coahuila, aquí nadie '
#                               'se raja. Este 4 de Junio es el día de la '
#                               'libertad de nuestro estado, vota todo PT. 🐅 '
#                               '#RicardoMejía #VotaPT',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/687954024628445/permalink/6198531483570644',
#                          'n': 'AUTOS ACUÑA ...',
#                          't': '2023-05-27T04:26:46'},
#                         {'d': '#Noticias24siete\n'
#                               '\n'
#                               '🔴 Aparecen mensajes en Coahuila en apoyo a '
#                               'Ricardo Mejia Berdeja\n'
#                               '\n'
#                               'Aquí la información ➡️ https://n9.cl/fm3oq',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1189932567699121/permalink/24026948903570830',
#                          'n': 'Bazar Allende Coahuila',
#                          't': '2023-05-27T19:36:32'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1189932567699121/permalink/24026117960320591',
#                          'n': 'Bazar Allende Coahuila',
#                          't': '2023-05-27T16:42:01'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/119217241620123/permalink/2390297714512053',
#                          'n': 'Ciberpulga Sabinas - Rosita - palau - Muzquiz',
#                          't': '2023-05-27T16:41:33'},
#                         {'d': '📢 ¡𝗧𝗼𝗱𝗼𝘀 𝗮 𝘃𝗼𝘁𝗮𝗿 𝗽𝗼𝗿 𝗘𝗹 𝗧𝗶𝗴𝗿𝗲! Demos el último '
#                               'jalón, sigamos convenciendo a más tigres para '
#                               'que se unan al verdadero movimiento del cambio. '
#                               'Vota todo PT este 4 de Junio. 🐅 #RicardoMejía '
#                               '#VotaPT',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/119217241620123/permalink/2390091257866032',
#                          'n': 'Ciberpulga Sabinas - Rosita - palau - Muzquiz',
#                          't': '2023-05-27T10:08:15'},
#                         {'d': 'Cierre de campaña en Muzquiz de nuestro amigo '
#                               'Ricardo Mejia Berdeja',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1426869837621338/permalink/3118300185144953',
#                          'n': 'AUTOS LAGUNA',
#                          't': '2023-05-27T02:12:34'},
#                         {'d': 'A pesar de las presiones que hacen desde Ciudad '
#                               'de México, nuestro voto no se mueve. Vamos con '
#                               'Ricardo Mejia Berdeja del Partido del Trabajo.',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/810155579084868/permalink/5788563781243998',
#                          'n': 'AUTOS USADOS PIEDRAS NEGRAS Y 5 MANANTIALES',
#                          't': '2023-05-27T14:29:50'},
#                         {'d': 'En Coahuila ! Apoyamos a Amlo 18 años ! Para '
#                               'llegar a la Presidencia de Mexico Nos prometió '
#                               'meter a la cárcel a los Moreira ! \n'
#                               '\n'
#                               'Lo seguimos apoyando y estamos esperando que '
#                               'los meta a la cárcel ! \n'
#                               '\n'
#                               'Ricardo Mejia Berdeja ha sido leal y fiel a su '
#                               'Gobierno ! \n'
#                               '\n'
#                               'Hoy lo menos que esperamos es que Amlo apoye y '
#                               'respete la voluntad de miles que queremos '
#                               'cambiar nuestro Estado ! \n'
#                               '\n'
#                               'Nosotros no tenemos la culpa de que las '
#                               'encuestas en Morena sean falsas y su candidato '
#                               'Guadiana un perdedor ! \n'
#                               '\n'
#                               'Manolo Jiménez es el adversario , el pri y los '
#                               'Moreira se tienen que ir de Coahuila ! \n'
#                               '\n'
#                               'Todos unidos con #mejia ! \n'
#                               '\n'
#                               'Que viva Coahuila ! \n'
#                               '\n'
#                               'Luchemos y votemos este 4 de junio por nuestra '
#                               'libertad ! \n'
#                               '\n'
#                               'Unidos corrijamos el rumbo ! \n'
#                               '\n'
#                               'Dios es nuestra fuerza y el voto 🗳️ nuestra '
#                               'arma ! \n'
#                               '\n'
#                               'Amén 🙏',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/598110110985087/permalink/1422964735166283',
#                          'n': 'VENTAS EN TODO SALTILLO',
#                          't': '2023-05-27T18:35:17'},
#                         {'d': 'Cierre de campaña en Muzquiz de nuestro amigo '
#                               'Ricardo Mejia Berdeja',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/316259222175201/permalink/1693038021163974',
#                          'n': 'Fayuca Laguna',
#                          't': '2023-05-27T02:12:20'},
#                         {'d': '🔴 #MejíaEnVivo \n'
#                               '¡𝗚𝗿𝗮𝗻 𝗖𝗶𝗲𝗿𝗿𝗲 𝗥𝗲𝗴𝗶𝗼𝗻𝗮𝗹! Andamos sacando la garra '
#                               'en Múzquiz con el Gran Cierre de la Región '
#                               'Carbonífera. Hagamos historia este 4 de Junio y '
#                               'vota todo PT. 🐅 #RicardoMejía #VotaPT',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/5274875065860154/permalink/6881020491912262',
#                          'n': 'CIUDAD UNIDA RAMOS ARIZPE',
#                          't': '2023-05-27T03:58:06'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/5274875065860154/permalink/6880993201914991',
#                          'n': 'CIUDAD UNIDA RAMOS ARIZPE',
#                          't': '2023-05-27T03:46:45'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/149593358535710/permalink/2436953736466316',
#                          'n': 'CIBER PULGA Region Carbonifera',
#                          't': '2023-05-27T16:41:19'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/459984690796585/permalink/6003709259757406',
#                          'n': 'Ciber pulga de muzquiz',
#                          't': '2023-05-27T13:08:47'},
#                         {'d': 'En Coahuila ! Apoyamos a Amlo 18 años ! Para '
#                               'llegar a la Presidencia de Mexico Nos prometió '
#                               'meter a la cárcel a los Moreira ! \n'
#                               '\n'
#                               'Lo seguimos apoyando y estamos esperando que '
#                               'los meta a la cárcel ! \n'
#                               '\n'
#                               'Ricardo Mejia Berdeja ha sido leal y fiel a su '
#                               'Gobierno ! \n'
#                               '\n'
#                               'Hoy lo menos que esperamos es que Amlo apoye y '
#                               'respete la voluntad de miles que queremos '
#                               'cambiar nuestro Estado ! \n'
#                               '\n'
#                               'Nosotros no tenemos la culpa de que las '
#                               'encuestas en Morena sean falsas y su candidato '
#                               'Guadiana un perdedor ! \n'
#                               '\n'
#                               'Manolo Jiménez es el adversario , el pri y los '
#                               'Moreira se tienen que ir de Coahuila ! \n'
#                               '\n'
#                               'Todos unidos con #mejia ! \n'
#                               '\n'
#                               'Que viva Coahuila ! \n'
#                               '\n'
#                               'Luchemos y votemos este 4 de junio por nuestra '
#                               'libertad ! \n'
#                               '\n'
#                               'Unidos corrijamos el rumbo ! \n'
#                               '\n'
#                               'Dios es nuestra fuerza y el voto 🗳️ nuestra '
#                               'arma ! \n'
#                               '\n'
#                               'Amén 🙏',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/459984690796585/permalink/6002333893228276',
#                          'n': 'Ciber pulga de muzquiz',
#                          't': '2023-05-27T03:55:25'},
#                         {'d': 'Cierre de campaña en Muzquiz de nuestro amigo '
#                               'Ricardo Mejia Berdeja',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/459984690796585/permalink/6002063126588686',
#                          'n': 'Ciber pulga de muzquiz',
#                          't': '2023-05-27T02:03:26'},
#                         {'d': '📢 ¡𝗧𝗼𝗱𝗼𝘀 𝗮 𝘃𝗼𝘁𝗮𝗿 𝗽𝗼𝗿 𝗘𝗹 𝗧𝗶𝗴𝗿𝗲! Demos el último '
#                               'jalón, sigamos convenciendo a más tigres para '
#                               'que se unan al verdadero movimiento del cambio. '
#                               'Vota todo PT este 4 de Junio. 🐅 #RicardoMejía '
#                               '#VotaPT',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1031596363613687/permalink/5869973033109305',
#                          'n': 'AUTOS sabinas y la region 🚘🛵🛺🏎✈️',
#                          't': '2023-05-27T13:10:36'},
#                         {'d': 'Ramos Arizpe, Coahuila. \n'
#                               '\n'
#                               'Tengan cuidado con este Estafador “Jaime '
#                               'Alonso”',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/3139051926119033/permalink/6546245668732958',
#                          'n': 'Comida a domicilio 🌭🍔🍟🍕🍗🌮🥗 SALTILLO, Coahuila',
#                          't': '2023-05-27T01:58:18'},
#                         {'d': '🟣 ¡𝗘𝗹 𝗧𝗶𝗴𝗿𝗲 𝗲𝘀𝘁𝗮́ 𝗰𝗼𝗻 𝗹𝗮𝘀 𝗺𝘂𝗷𝗲𝗿𝗲𝘀! Vamos a '
#                               'eliminar cualquier tipo de violencia de género, '
#                               'ayer marcharon por una mejor seguridad, mejores '
#                               'oportunidades y respeto. Ellas no quieren al '
#                               'misógino violentador de mujeres de Manolo '
#                               'Jiménez como Gobernador, quieren un cambio, '
#                               'vota todo PT. 🐅 #RicardoMejía #VotaPT',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/399762874147162/permalink/1404144747042298',
#                          'n': 'Ventas! Plaza, Toreo y Alrededores💕',
#                          't': '2023-05-27T20:15:39'},
#                         {'d': '🐅 ¡𝗛𝗮𝗴𝗮𝗺𝗼𝘀 𝗲𝗹 𝗰𝗮𝗺𝗯𝗶𝗼! No desperdicies tu voto, '
#                               'este 4 de Junio vota todo PT para tener un '
#                               'mejor mañana en #Coahuila, rescatemos a nuestro '
#                               'estado #VotaPT Ricardo Mejia Berdeja',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/225224707672520/permalink/2243967122464925',
#                          'n': 'bazar de Morelos Coahuila',
#                          't': '2023-05-27T02:03:15'},
#                         {'d': '📢 ¡𝗚𝗿𝗮𝗻 𝗖𝗶𝗲𝗿𝗿𝗲 𝗥𝗲𝗴𝗶𝗼𝗻𝗮𝗹! Mañana nos vemos '
#                               'Región Centro, te espero a las 6:00 PM en la '
#                               'Plaza del Magisterio. Se acerca el 4 de Junio, '
#                               'el día de la libertad de #Coahuila, vota todo '
#                               'PT. 🐅 #RicardoMejía #VotaPT',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1017494711699299/permalink/6391569247625125',
#                          'n': 'AUTOS BARATOS MONCLOVA',
#                          't': '2023-05-27T02:19:29'},
#                         {'d': 'El verdadero candidato del pueblo! Ricardo '
#                               'Mejia Berdeja es el único representante de la '
#                               'voluntad y conciencia del pueblo de '
#                               'Coahuila.Nadie puede imponerse o impedir el '
#                               'derecho legitimo en nuestro estado ! \n'
#                               'Señor presidente ,usted paso por lo mismo ,no '
#                               'permita que suceda de nuevo ! El pueblo sabio y '
#                               'noble elige ! Ya no se permiten las '
#                               'imposiciones !!\n'
#                               'El poder está en el pueblo ! Viva la '
#                               'democracia!',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/128119787322191/permalink/2951593681641440',
#                          'n': 'Ventas Monclova Frontera Castaños',
#                          't': '2023-05-27T19:31:14'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/128119787322191/permalink/2951469481653860',
#                          'n': 'Ventas Monclova Frontera Castaños',
#                          't': '2023-05-27T16:41:04'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/128119787322191/permalink/2951469431653865',
#                          'n': 'Ventas Monclova Frontera Castaños',
#                          't': '2023-05-27T16:41:01'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/527093560642305/permalink/6727102767307989',
#                          'n': 'Ciberpulga de Rosita, sabinas y sus alrededores',
#                          't': '2023-05-27T18:35:58'},
#                         {'d': '🚨𝗘𝘀𝘁𝗼 𝗲𝘀𝘁𝗮́ 𝗽𝗮𝘀𝗮𝗻𝗱𝗼 𝗲𝗻 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮: aunque el '
#                               'Manolo Jiménez y el PRI traten de ocultarlo, '
#                               'los GATES han cometido graves faltas a los '
#                               'derechos humanos, ayúdame a compartir el '
#                               'lamentable caso de este joven. #YaBastaDelPRI '
#                               '#RicardoMejía',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/527093560642305/permalink/6726799477338318',
#                          'n': 'Ciberpulga de Rosita, sabinas y sus alrededores',
#                          't': '2023-05-27T16:41:39'},
#                         {'d': 'En Coahuila ! Apoyamos a Amlo 18 años ! Para '
#                               'llegar a la Presidencia de Mexico Nos prometió '
#                               'meter a la cárcel a los Moreira ! \n'
#                               '\n'
#                               'Lo seguimos apoyando y estamos esperando que '
#                               'los meta a la cárcel ! \n'
#                               '\n'
#                               'Ricardo Mejia Berdeja ha sido leal y fiel a su '
#                               'Gobierno ! \n'
#                               '\n'
#                               'Hoy lo menos que esperamos es que Amlo apoye y '
#                               'respete la voluntad de miles que queremos '
#                               'cambiar nuestro Estado ! \n'
#                               '\n'
#                               'Nosotros no tenemos la culpa de que las '
#                               'encuestas en Morena sean falsas y su candidato '
#                               'Guadiana un perdedor ! \n'
#                               '\n'
#                               'Manolo Jiménez es el adversario , el pri y los '
#                               'Moreira se tienen que ir de Coahuila ! \n'
#                               '\n'
#                               'Todos unidos con #mejia ! \n'
#                               '\n'
#                               'Que viva Coahuila ! \n'
#                               '\n'
#                               'Luchemos y votemos este 4 de junio por nuestra '
#                               'libertad ! \n'
#                               '\n'
#                               'Unidos corrijamos el rumbo ! \n'
#                               '\n'
#                               'Dios es nuestra fuerza y el voto 🗳️ nuestra '
#                               'arma ! \n'
#                               '\n'
#                               'Amén 🙏',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1486147051650876/permalink/3319152278350335',
#                          'n': 'El COLOSO ACAPULCO',
#                          't': '2023-05-27T18:16:44'},
#                         {'d': 'AKI EN COAHUILA EL ÚNICO TRAIDOR ES ESTE '
#                               'ESPURIO (falso, c1n1c0, h1p0cr1t4) SUJETO DEL '
#                               'MARIO DELGADO K RECIBIÓ 300 MDP DE PARTE DE LOS '
#                               'MOREIRA Y RIKELME SOLÍS PARA DEJARLES VÍA '
#                               'LIBRE.,\n'
#                               'VOTO ÚTIL Y MASIVO  X EL P.T CON RICARDO MEJIA '
#                               'BERDEJA¡¡',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/541886219516414/permalink/1963560700682285',
#                          'n': 'Alza La Voz, Monclova y Frontera',
#                          't': '2023-05-27T14:55:39'},
#                         {'d': '🚨 #ÚLTIMAHORA El Partido Verde anunció la '
#                               'declinación de su candidato Lenin Perez a favor '
#                               'del candidato de Morena a la gubernatura de '
#                               'Coahuila, Armando Guadiana.\n'
#                               '\n'
#                               'A una semana de las elecciones, Mario Delgado, '
#                               'acompañado de Guadiana, la presidenta del '
#                               'Partido Verde, Karen Castrejón, y el senador '
#                               'Manuel Velasco Coello, hicieron el anuncio '
#                               'oficial. \n'
#                               '\n'
#                               '“Ha habido momentos decisivos y este es uno de '
#                               'ellos. Junto con ellos vamos a gobernar '
#                               'Coahuila y vamos a impulsar la agenda ambiental '
#                               'porque hay una coincidencia con ellos muy '
#                               'amplia. Se empieza a configurar lo del 2024, es '
#                               'momento de escuchar los principios y atender el '
#                               'llamado que hace el pueblo de Coahuila para que '
#                               'haya un cambio”, dijo el dirigente de Morena.\n'
#                               '\n'
#                               'Morena ha llamado en los últimos días al '
#                               'Partido Verde y al PT a declinar por el '
#                               'candidato de Morena para no dejar que el PRI se '
#                               'lleve la gubernatura. \n'
#                               '\n'
#                               '“Estamos muy contentos de que el llamado que '
#                               'hicimos a sumar el voto del cambio para evitar '
#                               'que el PRI llegue a cien años en Coahuila, lo '
#                               'cual sería la peor de las maldiciones para este '
#                               'pueblo trabajador, honesto, que ha tenido ya '
#                               'muchos años de gobiernos abusivos, de gobiernos '
#                               'que han deteriorado el nivel de vida de la '
#                               'gente; que han abusado, que se han llenado de '
#                               'privilegios, pues sería una maldición que no '
#                               'escuchemos el llamado del pueblo a juntarnos y '
#                               'que haya un cambio”, expresó Delgado. \n'
#                               '\n'
#                               'El dirigente de Morena considera que es '
#                               'necesario llegar al día de la elección con una '
#                               'ventaja importante para que el PRIANRD no tenga '
#                               'posibilidad de hacer un fraude electoral. \n'
#                               '\n'
#                               'Sobre la declinación de su candidato, la '
#                               'presidenta del Partido Verde señaló que este '
#                               'acto tiene como objetivo lograr la unidad entre '
#                               'los tres partidos aliados. \n'
#                               '\n'
#                               '“Hoy refrendamos el compromiso que tenemos con '
#                               'el presidente de la República y seguimos juntos '
#                               'no solo para el Estado de Coahuila, sino para '
#                               'que se concrete en todo el país”, expresó '
#                               'Castrejón. \n'
#                               '\n'
#                               'Al respecto, el senador del Verde y ex '
#                               'gobernador de Chiapas, Manuel Velasco, confío '
#                               'en que con la declinación, Guadiana gane la '
#                               'gubernatura. \n'
#                               '\n'
#                               '“En prácticamente todas las elecciones que '
#                               'hemos hecho alianza para gobernador hemos '
#                               'tenido un índice de efectividad de más del 90 '
#                               'por ciento. Estamos respaldando la candidatura '
#                               'de Armando Guadiana. Es una alianza que ha '
#                               'tenido éxito en el ámbito legislativo y también '
#                               'en el ámbito electoral. Estamos convencidos de '
#                               'que el Presidente ha hecho un buen gobierno con '
#                               'obras públicas de trascendencia. No es momento '
#                               'de titubeos, es momento de ir para adelante y '
#                               'estamos convencidos de la victoria”, dijo '
#                               'Velasco.\n'
#                               '\n'
#                               'Hasta ahora, el PT y su candidato, Ricardo '
#                               'Mejia Berdeja, no han emitido ningún '
#                               'posicionamiento al respecto.',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/100066943703034/posts/586698000238318',
#                          'n': 'Corporativo Conde y Asoc.',
#                          't': '2023-05-27T18:59:45'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/285014522101177/permalink/1307043946564891',
#                          'n': 'Taxistas de Saltillo',
#                          't': '2023-05-27T02:38:17'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1793371900922792/permalink/3470882566505042',
#                          'n': 'Hipodromo y Oriente Ventas (Monclova)',
#                          't': '2023-05-27T12:40:50'},
#                         {'d': 'En Coahuila ! Apoyamos a Amlo 18 años ! Para '
#                               'llegar a la Presidencia de Mexico Nos prometió '
#                               'meter a la cárcel a los Moreira ! \n'
#                               '\n'
#                               'Lo seguimos apoyando y estamos esperando que '
#                               'los meta a la cárcel ! \n'
#                               '\n'
#                               'Ricardo Mejia Berdeja ha sido leal y fiel a su '
#                               'Gobierno ! \n'
#                               '\n'
#                               'Hoy lo menos que esperamos es que Amlo apoye y '
#                               'respete la voluntad de miles que queremos '
#                               'cambiar nuestro Estado ! \n'
#                               '\n'
#                               'Nosotros no tenemos la culpa de que las '
#                               'encuestas en Morena sean falsas y su candidato '
#                               'Guadiana un perdedor ! \n'
#                               '\n'
#                               'Manolo Jiménez es el adversario , el pri y los '
#                               'Moreira se tienen que ir de Coahuila ! \n'
#                               '\n'
#                               'Todos unidos con #mejia ! \n'
#                               '\n'
#                               'Que viva Coahuila ! \n'
#                               '\n'
#                               'Luchemos y votemos este 4 de junio por nuestra '
#                               'libertad ! \n'
#                               '\n'
#                               'Unidos corrijamos el rumbo ! \n'
#                               '\n'
#                               'Dios es nuestra fuerza y el voto 🗳️ nuestra '
#                               'arma ! \n'
#                               '\n'
#                               'Amén 🙏',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/641112086350253/permalink/1687535928374525',
#                          'n': 'ALERTA ALERTA  LAGUNA',
#                          't': '2023-05-27T12:11:02'},
#                         {'d': '🗯️ ¡𝗟𝗮 𝗰𝗼𝗿𝗿𝘂𝗽𝗰𝗶𝗼́𝗻 𝗲𝘀 𝗲𝗹 𝗰𝗮́𝗻𝗰𝗲𝗿 𝗱𝗲 #𝗖𝗼𝗮𝗵𝘂𝗶𝗹𝗮! '
#                               'La mega deuda la pagamos cuando vemos las '
#                               'calles sin pavimentación, cuando nos falta '
#                               'infraestructura, cuando nos cobran las actas de '
#                               'nacimiento; mientras que estos corruptos son '
#                               'millonarios a costa del pueblo. Este 4 de Junio '
#                               'vota todo PT para encarcelarlos. 🐅 '
#                               '#RicardoMejía #VotaPT',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/206735446411327/permalink/1719450345139822',
#                          'n': 'Que todo saltillo se entere #1',
#                          't': '2023-05-27T17:07:40'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/206735446411327/permalink/1719059645178892',
#                          'n': 'Que todo saltillo se entere #1',
#                          't': '2023-05-27T02:38:08'},
#                         {'d': 'Nuestro presidente AMLO no apoya a traidores '
#                               'como Ricardo Mejia Berdeja candidato de PT',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/373326086870670/permalink/1296494184553851',
#                          'n': 'Noticiero Univisión',
#                          't': '2023-05-27T04:01:45'},
#                         {'d': 'Ricardo Mejia Berdeja del PT se ha ganado el '
#                               'cariño de la gente por eso es el político más '
#                               'atacado en Coahuila. El 4 de Junio vamos con el '
#                               'Candidato del Pueblo.',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1897923733681238/permalink/2777697855703817',
#                          'n': '☆Fans y amigos de ¡¡¡Obrador!!!',
#                          't': '2023-05-27T15:36:12'},
#                         {'d': 'En Coahuila ! Apoyamos a Amlo 18 años ! Para '
#                               'llegar a la Presidencia de Mexico Nos prometió '
#                               'meter a la cárcel a los Moreira ! \n'
#                               '\n'
#                               'Lo seguimos apoyando y estamos esperando que '
#                               'los meta a la cárcel ! \n'
#                               '\n'
#                               'Ricardo Mejia Berdeja ha sido leal y fiel a su '
#                               'Gobierno ! \n'
#                               '\n'
#                               'Hoy lo menos que esperamos es que Amlo apoye y '
#                               'respete la voluntad de miles que queremos '
#                               'cambiar nuestro Estado ! \n'
#                               '\n'
#                               'Nosotros no tenemos la culpa de que las '
#                               'encuestas en Morena sean falsas y su candidato '
#                               'Guadiana un perdedor ! \n'
#                               '\n'
#                               'Manolo Jiménez es el adversario , el pri y los '
#                               'Moreira se tienen que ir de Coahuila ! \n'
#                               '\n'
#                               'Todos unidos con #mejia ! \n'
#                               '\n'
#                               'Que viva Coahuila ! \n'
#                               '\n'
#                               'Luchemos y votemos este 4 de junio por nuestra '
#                               'libertad ! \n'
#                               '\n'
#                               'Unidos corrijamos el rumbo ! \n'
#                               '\n'
#                               'Dios es nuestra fuerza y el voto 🗳️ nuestra '
#                               'arma ! \n'
#                               '\n'
#                               'Amén 🙏',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/1265540263643731/permalink/2167562463441502',
#                          'n': 'DURANGO APOYA LA CUARTA TRANSFORMACIÓN',
#                          't': '2023-05-27T01:05:41'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/675945676302574/permalink/1371104726786662',
#                          'n': 'AMIGOS DE SIN CENSURA CON VICENTE SERRANO',
#                          't': '2023-05-27T20:21:52'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/582892219329814/permalink/1286655758953453',
#                          'n': '🇲🇽 MEMES PRO AMLO 🇲🇽',
#                          't': '2023-05-27T18:38:57'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/257622695387918/permalink/949709719512542',
#                          'n': 'Apoyo masivo amlo',
#                          't': '2023-05-27T03:40:31'},
#                         {'d': '',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/257622695387918/permalink/949670839516430',
#                          'n': 'Apoyo masivo amlo',
#                          't': '2023-05-27T02:03:07'},
#                         {'d': '¡Morena cierra filas con Ricardo Mejía! Ultima '
#                               'Hora, Coahuila podría tener a su próximo '
#                               'Gobernador, arrasa en todo el Estado Ricardo '
#                               'Mejia Berdeja #amlo #Leososa #mañanera #cdmx',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/100069379082314/posts/558847189771246',
#                          'n': 'Morena Coahuila Unidos',
#                          't': '2023-05-27T14:54:25'},
#                         {'d': 'Responde Tania flores Alcaldesa de Muzquiz, '
#                               'mediante sus redes sociales a esposa de Mejía '
#                               'Berdeja \n'
#                               '\n'
#                               'No Señora, no se equivoqué! ￼\n'
#                               '\n'
#                               'El que se mete con AMLO se mete con todos los '
#                               'Mexicanos. \n'
#                               '\n'
#                               'No tengo palabras para expresar mi molestia '
#                               'sobre las últimas publicaciones de esta señora. '
#                               'Y entenderé que me ataque a mi y a todos los '
#                               'que decidimos no apoyar el proyecto de Mejia '
#                               'porque no nos gusto la idea de dividir el voto '
#                               'opositor para beneficiar a el PRI. Pero hoy me '
#                               'veo en la necesidad de contestarle. \n'
#                               '\n'
#                               'Señora no se equivoqué, no olvide sus raíces y '
#                               'de donde vienen. Le recuerdo que en el 2018, '
#                               'cuando fue la lucha más grande en contra de el '
#                               'sistema encabezada por el pueblo Mexicano y '
#                               'nuestro presidente AMLO, usted y su esposo '
#                               'Ricardo Mejia Berdeja apoyaron a el PRIAN, le '
#                               'levantaron la mano a el contrincante de nuestro '
#                               'presidente AMLO, a Ricardo Anaya, hoy prófugo '
#                               'de la justicia. Se llenaban la boca diciendo '
#                               'que el PAN era quien merecía ganar. Ustede '
#                               'lucharon en contra de la transformación que hoy '
#                               'vivimos en Mexico, ustedes fueron parte de el '
#                               'sistema que jugó en contra de nuestro '
#                               'presidente en el 2018. Miéntese que Guadiana al '
#                               'que hoy atacan ferozmente, se mantuvo leal en '
#                               'la lucha de Morena y de nuestro presídete. Y es '
#                               'de los pocos coahuilenses que ah alzado la voz '
#                               'a favor de Coahuila en contra del Moreirato. \n'
#                               'Y aún así que Mejia no apoyo a el Presidente, '
#                               'el mismo Andrés Manuel López Obrador le dio una '
#                               'oportunidad en su gabinete, lo único que le '
#                               'pido fue lealtad y compromiso a el pueblo '
#                               'Mexico y a el movimiento de la 4ta '
#                               'transformación. \n'
#                               'Que hizo Ricardo Mejia con esa oportunidad? '
#                               'TRAICIONAR, MENTIR y MANIPULAR. \n'
#                               'El decidió participar en una encuesta, que al '
#                               'no salir favorecido decidió iniciar un '
#                               'movimiento para desacreditar el Movimiento de '
#                               'el presidente. Movimiento que a Mejia no le '
#                               'costó construir, y mucho menos defender. \n'
#                               'Mejia y usted sabe perfectamente que lo único '
#                               'que están haciendo es dividiendo el voto de '
#                               'Morena para favorecer a el PRI, saben que no '
#                               'ganarán, y este 4 de Junio con el resultado en '
#                               'las urnas, habrá quedado claro que regreso '
#                               'Mejia a Coahuila después de 20 años solo para '
#                               'apoyar a quien dice son sus enemigos el PRI, '
#                               'que hoy lo dudo. Morena insistió buscar a Mejia '
#                               'para sumarse para llegar a un acuerdo, su '
#                               'soberbia de yo soy el mejor y todos me deben de '
#                               'rendir será su cruz y su desgracia. \n'
#                               '\n'
#                               'Hay mucha tela de donde cortar, hay mucho que '
#                               'decir, se equivoco Señora, con AMLO NO!! \n'
#                               '\n'
#                               'El que se mete con el Presidente, se mete '
#                               'conmigo! \n'
#                               'No se vale Mejia.',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/2311684099097013/permalink/3439444926320919',
#                          'n': 'ESTO PASA EN PIEDRAS NEGRAS , EAGLE PASS Y 5 '
#                               'MANANTIALES',
#                          't': '2023-05-27T01:40:27'},
#                         {'d': '🟣 Negocia Morena con PVEM para ganar '
#                               'gubernatura en Coahuila, hacen alianza de '
#                               'último momento 🙃 Desde territorio coahuilense '
#                               'el dirigente nacional de Morena, Mario Delgado '
#                               'Carrillo, y la lider del PVEM, Karen Castrejón '
#                               'Trujillo, de cara a la votación por la '
#                               'gubernatura el próximo 4 de junio, anuncian '
#                               'alianza para desterrar al PRI. A casi una '
#                               'semana de la votación, Morena logró sumar al '
#                               'PVEM, mientras que el Partido del Trabajo (PT), '
#                               'se mantiene firme con la candidatura de Ricardo '
#                               'Mejia Berdeja, figura que destacó según '
#                               'usuarios en redes sociales, en los debates '
#                               'previo a la elección.',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/100065064878130/posts/637933738385450',
#                          'n': 'Texmelucan al Día',
#                          't': '2023-05-27T17:54:27'},
#                         {'d': '#Noticias24siete\n'
#                               '\n'
#                               '🔴 Aparecen mensajes en Coahuila en apoyo a '
#                               'Ricardo Mejia Berdeja\n'
#                               '\n'
#                               'Aquí la información ➡️ https://n9.cl/fm3oq',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/270603610896781/permalink/923128205644315',
#                          'n': 'BOLSA DE TRABAJO Y RECLUTAMIENTO SALTILLO Y '
#                               'RAMOS',
#                          't': '2023-05-27T19:34:55'},
#                         {'d': 'Morena en Coahuila es Primor, así que los que '
#                               'somos de Coahuila sabemos que el único que '
#                               'puede cambiar nuestro estado es Ricardo Mejia '
#                               'Berdeja para Gobernar y meter en la cárcel a '
#                               'estos delincuentes que solo buscan su propio '
#                               'porvenir y no el de su pueblo.\n'
#                               'Así que esté 4 de Junio no desperdicies el '
#                               'voto, saca la Garra y vota PT!!',
#                          'i': 0,
#                          'l': 'https://www.facebook.com/groups/221905005059947/permalink/1322724144978022',
#                          'n': 'Todos somos amlo',
#                          't': '2023-05-27T22:51:55'},
#                         {'d': 'En Coahuila ! Apoyamos a Amlo 18 años ! Para '
#                               'llegar a la Presidencia de Mexico Nos prometió '
#                               'meter a la cárcel a los Moreira ! \n'
#                               '\n'
#                               'Lo seguimos apoyando y estamos esperando que '
#                               'los meta a la cárcel ! \n'
#                               '\n'
#                               'Ricardo Mejia Berdeja ha sido leal y fiel a su '
#                               'Gobierno ! \n'
#                               '\n'
# ...
# parsing row 49
# parsing row 50
# parsing row 51
# parsing row 52
# parsing row 53
# parsing row 54
# parsing row 55
# parsing row 56
# parsing row 57
# parsing row 58
# parsing row 59
# parsing row 60
# parsing row 61
# parsing row 62
# parsing row 63
# parsing row 64
# parsing row 65
# parsing row 66
# parsing row 67
# parsing row 68
# parsing row 69
# parsing row 70
# parsing row 71
# parsing row 72
# parsing row 73
# parsing row 74
# parsing row 75
# parsing row 76
# parsing row 77
# parsing row 78
# parsing row 79
# parsing row 80
# parsing row 81
# parsing row 82
# parsing row 83
# parsing row 84
# parsing row 85
# parsing row 86
# parsing row 87
# parsing row 88
# parsing row 89
# parsing row 90
# parsing row 91
# parsing row 92
# parsing row 93
# parsing row 94
# parsing row 95
# parsing row 96
# parsing row 97
# parsing row 98
# parsing row 99
# parsing row 100
# parsing row 101
# parsing row 102
# parsing row 103
# parsing row 104
# parsing row 105
# parsing row 106
# parsing row 107
# parsing row 108
# parsing row 109
# parsing row 110
# parsing row 111
# parsing row 112
# parsing row 113
# parsing row 114
# parsing row 115
# parsing row 116
# parsing row 117
# parsing row 118
# parsing row 119
# parsing row 120
# parsing row 121
# parsing row 122
# parsing row 123
# parsing row 124
# parsing row 125
# parsing row 126
# parsing row 127
# parsing row 128
# parsing row 129
# parsing row 130
# parsing row 131
# parsing row 132
# parsing row 133
# parsing row 134
# parsing row 135
# parsing row 136
# parsing row 137
# parsing row 138
# parsing row 139
# parsing row 140
# parsing row 141
# parsing row 142
# parsing row 143
# parsing row 144
# parsing row 145
# parsing row 146
# parsing row 147
# parsing row 148
# parsing row 149
# parsing row 150
# parsing row 151
# parsing row 152
# parsing row 153
# parsing row 154
# parsing row 155
# parsing row 156
# parsing row 157
# parsing row 158
# parsing row 159
# parsing row 160
# parsing row 161
# parsing row 162
# parsing row 163
# parsing row 164
# parsing row 165
# parsing row 166
# parsing row 167
# parsing row 168
# parsing row 169
# parsing row 170
# parsing row 171
# parsing row 172
# parsing row 173
# parsing row 174
# parsing row 175
# parsing row 176
# parsing row 177
# parsing row 178
# parsing row 179
# parsing row 180
# parsing row 181
# parsing row 182
# parsing row 183
# parsing row 184
# parsing row 185
# parsing row 186
# parsing row 187
# parsing row 188
# parsing row 189
# parsing row 190
# parsing row 191
# parsing row 192
# parsing row 193
# parsing row 194
# parsing row 195
# parsing row 196
# parsing row 197
# parsing row 198
# parsing row 199
# parsing row 200
# parsing row 201
# parsing row 202
# parsing row 203
# parsing row 204
# parsing row 205
# parsing row 206
# parsing row 207
# parsing row 208
# parsing row 209
# parsing row 210
# parsing row 211
# parsing row 212
# parsing row 213
# parsing row 214
# parsing row 215
# parsing row 216
# parsing row 217
# parsing row 218
# parsing row 219
# parsing row 220
# parsing row 221
# parsing row 222
# parsing row 223
# parsing row 224
# parsing row 225
# parsing row 226
# parsing row 227
# parsing row 228
# parsing row 229
# parsing row 230
# parsing row 231
# parsing row 232
# parsing row 233
# parsing row 234
# parsing row 235
# parsing row 236
# parsing row 237
# parsing row 238
# parsing row 239
# parsing row 240
# parsing row 241
# parsing row 242
# parsing row 243
# parsing row 244
# parsing row 245
# parsing row 246
# parsing row 247
# parsing row 248
# parsing row 249
# parsing row 250
# parsing row 251
# parsing row 252
# parsing row 253
# parsing row 254
# parsing row 255
# parsing row 256
# parsing row 257
# parsing row 258
# parsing row 259
# parsing row 260
# parsing row 261
# parsing row 262
# parsing row 263
# parsing row 264
# parsing row 265
# parsing row 266
# parsing row 267
# parsing row 268
# parsing row 269
# parsing row 270
# parsing row 271
# parsing row 272
# parsing row 273
# parsing row 274
# parsing row 275
# parsing row 276
# parsing row 277
# parsing row 278
# parsing row 279
# parsing row 280
# parsing row 281
# parsing row 282
# parsing row 283
# parsing row 284
# parsing row 285
# parsing row 286
# parsing row 287
# parsing row 288
# parsing row 289
# parsing row 290
# parsing row 291
# parsing row 292
# parsing row 293
# parsing row 294
# parsing row 295
# parsing row 296
# parsing row 297
# parsing row 298
# parsing row 299
# parsing row 300
# parsing row 301
# parsing row 302
# parsing row 303
# parsing row 304
# parsing row 305
# parsing row 306
# parsing row 307
# parsing row 308
# parsing row 309
# parsing row 310
# parsing row 311
# parsing row 312
# parsing row 313
# parsing row 314
# parsing row 315
# parsing row 316
# parsing row 317
# parsing row 318
# parsing row 319
# parsing row 320
# parsing row 321
# parsing row 322
# parsing row 323
# parsing row 324
# parsing row 325
# parsing row 326
# parsing row 327
# parsing row 328
# parsing row 329
# parsing row 330
# parsing row 331
# parsing row 332
# parsing row 333
# parsing row 334
# parsing row 335
# parsing row 336
# parsing row 337
# parsing row 338
# parsing row 339
# parsing row 340
# parsing row 341
# parsing row 342
# parsing row 343
# parsing row 344
# parsing row 345
# parsing row 346
# parsing row 347
# parsing row 348
# parsing row 349
# parsing row 350
# parsing row 351
# parsing row 352
# parsing row 353
# parsing row 354
# parsing row 355
# parsing row 356
# parsing row 357
# parsing row 358
# parsing row 359
# parsing row 360
# parsing row 361
# parsing row 362
# parsing row 363
# parsing row 364
# parsing row 365
# parsing row 366
# parsing row 367
# parsing row 368
# parsing row 369
# parsing row 370
# parsing row 371
# parsing row 372
# parsing row 373
# parsing row 374
# parsing row 375
# parsing row 376
# parsing row 377
# parsing row 378
# parsing row 379
# parsing row 380
# parsing row 381
# parsing row 382
# parsing row 383
# parsing row 384
# parsing row 385
# parsing row 386
# parsing row 387
# parsing row 388
# parsing row 389
# parsing row 390
# parsing row 391
# parsing row 392
# parsing row 393
# parsing row 394
# parsing row 395
# parsing row 396
# parsing row 397
# parsing row 398
# parsing row 399
# parsing row 400
# parsing row 401
# parsing row 402
# parsing row 403
# parsing row 404
# parsing row 405
# parsing row 406
# parsing row 407
# parsing row 408
# parsing row 409
# parsing row 410
# parsing row 411
# parsing row 412
# parsing row 413
# parsing row 414
# parsing row 415
# parsing row 416
# parsing row 417
# parsing row 418
# parsing row 419
# parsing row 420
# parsing row 421
# parsing row 422
# parsing row 423
# parsing row 424
# parsing row 425
# parsing row 426
# parsing row 427
# parsing row 428
# parsing row 429
# parsing row 430
# parsing row 431
# parsing row 432
# parsing row 433
# parsing row 434
# parsing row 435
# parsing row 436
# parsing row 437
# parsing row 438
# parsing row 439
# parsing row 440
# parsing row 441
# parsing row 442
# parsing row 443
# parsing row 444
# parsing row 445
# parsing row 446
# parsing row 447
# parsing row 448
# parsing row 449
# parsing row 450
# parsing row 451
# parsing row 452
# parsing row 453
# parsing row 454
# parsing row 455
# parsing row 456
# parsing row 457
# parsing row 458
# parsing row 459
# parsing row 460
# parsing row 461
# parsing row 462
# parsing row 463
# parsing row 464
# parsing row 465
# parsing row 466
# parsing row 467
# parsing row 468
# parsing row 469
# parsing row 470
# parsing row 471
# parsing row 472
# parsing row 473
# parsing row 474
# parsing row 475
# parsing row 476
# parsing row 477
# parsing row 478
# parsing row 479
# parsing row 480
# parsing row 481
# parsing row 482
# parsing row 483
# parsing row 484
# parsing row 485
# parsing row 486
# parsing row 487
# parsing row 488
# parsing row 489
# parsing row 490
# parsing row 491
# parsing row 492
# parsing row 493
# parsing row 494
# parsing row 495
# parsing row 496
# parsing row 497
# parsing row 498
# parsing row 499
# parsing row 500
# parsing row 501
# parsing row 502
# parsing row 503
# parsing row 504
# parsing row 505
# parsing row 506
# parsing row 507
# parsing row 508
# parsing row 509
# parsing row 510
# parsing row 511
# parsing row 512
# parsing row 513
# parsing row 514
# parsing row 515
# parsing row 516
# parsing row 517
# parsing row 518
# parsing row 519
# parsing row 520
# parsing row 521
# parsing row 522
# parsing row 523
# parsing row 524
# parsing row 525
# parsing row 526
# parsing row 527
# parsing row 528
# parsing row 529
# parsing row 530
# parsing row 531
# parsing row 532
# parsing row 533
# parsing row 534
# parsing row 535
# parsing row 536
# parsing row 537
# parsing row 538
# parsing row 539
# parsing row 540
# parsing row 541
# parsing row 542
# parsing row 543
# parsing row 544
# parsing row 545
# parsing row 546
# parsing row 547
# parsing row 548
# parsing row 549
# parsing row 550
# parsing row 551
# parsing row 552
# parsing row 553
# parsing row 554
# parsing row 555
# parsing row 556
# parsing row 557
# parsing row 558
# parsing row 559
# parsing row 560
# parsing row 561
# parsing row 562
# parsing row 563
# parsing row 564
# parsing row 565
# parsing row 566
# parsing row 567
# parsing row 568
# parsing row 569
# parsing row 570
# parsing row 571
# parsing row 572
# parsing row 573
# parsing row 574
# parsing row 575
# parsing row 576
# parsing row 577
# parsing row 578
# parsing row 579
# parsing row 580
# parsing row 581
# parsing row 582
# parsing row 583
# parsing row 584
# parsing row 585
# parsing row 586
# parsing row 587
# parsing row 588
# parsing row 589
# parsing row 590
# parsing row 591
# parsing row 592
# parsing row 593
# parsing row 594
# parsing row 595
# parsing row 596
# parsing row 597
# parsing row 598
# parsing row 599
# parsing row 600
# parsing row 601
# parsing row 602
# parsing row 603
# parsing row 604
# parsing row 605
# parsing row 606
# parsing row 607
# parsing row 608
# parsing row 609
# parsing row 610
# parsing row 611
# parsing row 612
# parsing row 613
# parsing row 614
# parsing row 615
# parsing row 616
# parsing row 617
# parsing row 618
# parsing row 619
# parsing row 620
# parsing row 621
# parsing row 622
# parsing row 623
# parsing row 624
# parsing row 625
# parsing row 626
# parsing row 627
# parsing row 628
# parsing row 629
# parsing row 630
# parsing row 631
# parsing row 632
# parsing row 633
# parsing row 634
# parsing row 635
# parsing row 636
# parsing row 637
# parsing row 638
# parsing row 639
# parsing row 640
# parsing row 641
# parsing row 642
# parsing row 643
# parsing row 644
# parsing row 645
# parsing row 646
# parsing row 647
# parsing row 648
# parsing row 649
# parsing row 650
# parsing row 651
# parsing row 652
# parsing row 653
# parsing row 654
# parsing row 655
# parsing row 656
# parsing row 657
# parsing row 658
# parsing row 659
# parsing row 660
# parsing row 661
# parsing row 662
# parsing row 663
# parsing row 664
# parsing row 665
# parsing row 666
# parsing row 667
# parsing row 668
# parsing row 669
# parsing row 670
# parsing row 671
# parsing row 672
# parsing row 673
# parsing row 674
# parsing row 675
# parsing row 676
# parsing row 677
# parsing row 678
# parsing row 679
# parsing row 680
# parsing row 681
# parsing row 682
# parsing row 683
# parsing row 684
# parsing row 685
# parsing row 686
# parsing row 687
# parsing row 688
# parsing row 689
# parsing row 690
# parsing row 691
# parsing row 692
# parsing row 693
# parsing row 694
# parsing row 695
# parsing row 696
# parsing row 697
# parsing row 698
# parsing row 699
# parsing row 700
# parsing row 701
# parsing row 702
# parsing row 703
# parsing row 704
# parsing row 705
# parsing row 706
# parsing row 707
# parsing row 708
# parsing row 709
# parsing row 710
# parsing row 711
# parsing row 712
# parsing row 713
# parsing row 714
# parsing row 715
# parsing row 716
# parsing row 717
# parsing row 718
# parsing row 719
# parsing row 720
# parsing row 721
# parsing row 722
# parsing row 723
# parsing row 724
# parsing row 725
# parsing row 726
# parsing row 727
# parsing row 728
# parsing row 729
# parsing row 730
# parsing row 731
# parsing row 732
# parsing row 733
# parsing row 734
# parsing row 735
# parsing row 736
# parsing row 737
# parsing row 738
# parsing row 739
# parsing row 740
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-bcb5387c89d6> in <cell line: 2>()
#       1 # # infotracer and sentiment: add historical data
# ----> 2 generate_infotracer_and_sentiment_table(start_date="2023-05-27",end_date="2023-05-27",ytb_end_date="2023-05-27",update_db=True)
#       3
#       4 # # network: add historical data
#       5 # print('network table starts')
#
# <ipython-input-24-452262a4b825> in generate_infotracer_and_sentiment_table(start_date, end_date, ytb_end_date, update_db)
#      38   # sentiment calculation
#      39
# ---> 40   full_sentiment=sent_analyze(sentiment)
#      41   if update_db==True:
#      42     # commit full sentiment to sentiment table in db
#
# <ipython-input-23-1565237d0637> in sent_analyze(df)
#       2 def sent_analyze(df):
#       3   batch=512
# ----> 4   analyzer = create_analyzer(task="sentiment", lang="es", batch_size=batch)
#       5
#       6   text=df['processed_text'].tolist() #list of texts
#
# /usr/local/lib/python3.10/dist-packages/pysentimiento/analyzer.py in create_analyzer(task, lang, model_name, preprocessing_args, **kwargs)
#     605
#     606     preprocessing_args["lang"] = lang
# --> 607     return analyzer_class.from_model_name(
#     608         model_name=model_name,
#     609         task=task,
#
# /usr/local/lib/python3.10/dist-packages/pysentimiento/analyzer.py in from_model_name(cls, model_name, task, preprocessing_args, batch_size, **kwargs)
#     249         model = AutoModelForSequenceClassification.from_pretrained(model_name)
#     250         tokenizer = AutoTokenizer.from_pretrained(model_name)
# --> 251         return cls(model, tokenizer, task, preprocessing_args, batch_size, **kwargs)
#     252
#     253     def _get_output(self, sentence, logits, context=None):
#
# /usr/local/lib/python3.10/dist-packages/pysentimiento/analyzer.py in __init__(self, model, tokenizer, task, preprocessing_args, batch_size, compile, **kwargs)
#     200         self.eval_trainer = Trainer(
#     201             model=self.model,
# --> 202             args=TrainingArguments(
#     203                 output_dir=".",
#     204                 per_device_eval_batch_size=batch_size,
#
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, evaluation_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, no_cuda, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, sharded_ddp, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, dataloader_pin_memory, skip_memory_met...
#
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py in __post_init__(self)
#    1331             self.framework == "pt"
#    1332             and is_torch_available()
# -> 1333             and (self.device.type != "cuda")
#    1334             and (get_xla_device_type(self.device) != "GPU")
#    1335             and (self.fp16 or self.fp16_full_eval)
#
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py in device(self)
#    1695         """
#    1696         requires_backends(self, ["torch"])
# -> 1697         return self._setup_devices
#    1698
#    1699     @property
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py in __get__(self, obj, objtype)
#      52         cached = getattr(obj, attr, None)
#      53         if cached is None:
# ---> 54             cached = self.fget(obj)
#      55             setattr(obj, attr, cached)
#      56         return cached
#
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py in _setup_devices(self)
#    1629             self._n_gpu = 1
#    1630         else:
# -> 1631             self.distributed_state = PartialState(backend=self.ddp_backend)
#    1632             self._n_gpu = 1
#    1633         if not is_sagemaker_mp_enabled():
#
# NameError: name 'PartialState' is not defined

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.19.0-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.19.0

# %%
# # infotracer and sentiment: add historical data
generate_infotracer_and_sentiment_table(start_date="2023-04-25",end_date="2023-04-25",ytb_end_date="2023-04-25",update_db=True)

# %% [markdown]
# # Daily update

# %%
query_dict={'Manolo Jiménez Salinas':'"Manolo Jimenez Salinas" OR "Manolo Jiménez Salinas" OR manolojim OR manolojimenezs OR Manolo.Jimenez.Salinas',
      'Armando Guadiana Tijerina':'"Armando Guadiana Tijerina" OR aguadiana OR armandoguadianatijerina OR ArmandoGuadianaTijerina',
'Ricardo Mejía Berdeja':'"Ricardo Mejía Berdeja" OR "Ricardo Mejia Berdeja" OR RicardoMeb OR ricardomeb OR RicardoMejiaMx',
    'Lenin Pérez Rivera':'"Lenin Pérez Rivera" OR "Lenin Perez Rivera" OR leninperezr OR leninperezr OR leninperezr'
}

# %%
print('##############################')
print('Update starts')

# helper: daily update
# print('helper table starts')
# today = datetime.now(pytz.timezone('America/Mexico_City')).date()
# tomorrow=datetime.now(pytz.timezone('America/Mexico_City')).date() + timedelta(days=1)
# generate_helper_table(start_date=tomorrow, end_date=tomorrow, update_db=True)
# print('helper table done')


# infotracer and sentiment: daily update
print('infotracer and sentiment table start')
# today = datetime.now(pytz.timezone('America/Mexico_City')).date().strftime('%Y-%m-%d')
# tomorrow=(datetime.now(pytz.timezone('America/Mexico_City')).date() + timedelta(days=1)).strftime('%Y-%m-%d')
today='2023-04-16'
tomorrow='2023-04-17'
generate_infotracer_and_sentiment_table(start_date=today, end_date=tomorrow, ytb_end_date=tomorrow,update_db=True)
print('infotracer and sentiment table done')

# wordcloud: daily update
print('wordcloud table starts')
generate_wordcloud_table()
print('wordcloud table done')

# network: daily update
print('network table starts')
generate_network_table(start_date=today, end_date=tomorrow,update_db=True)
print('network table done')

print('Update ends')
print('##############################')

# %%
####################################
##  refresh old data
####################################
'''
This code removes data from 48 hours ago and recollects it because the data 
becomes more stable after that time period. This ensures that we are working 
with the most reliable data possible.
''' 

print('##############################')
print('start refresh')
two_days_ago=(datetime.now(pytz.timezone('America/Mexico_City')).date() - timedelta(days=2)).strftime('%Y-%m-%d')
three_days_ago=(datetime.now(pytz.timezone('America/Mexico_City')).date() - timedelta(days=3)).strftime('%Y-%m-%d')

# delete
# data in db is mexico timezone
infotracer_query="DELETE FROM infotracer WHERE datetime >= '"+three_days_ago+" 18:00:00' AND datetime <= '"+two_days_ago+" 18:00:00'"
sentiment_query="DELETE FROM sentiment WHERE datetime >= '"+three_days_ago+" 18:00:00' AND datetime <= '"+two_days_ago+" 18:00:00'"

mycursor.execute(infotracer_query)
mycursor.execute(sentiment_query)

mydb.commit()
print('old data deleted')

# recollect
print('start recollect')
generate_infotracer_and_sentiment_table(start_date=two_days_ago, end_date=two_days_ago, ytb_end_date=two_days_ago,update_db=True)
print('recollect end')

print('refresh ends')
print('##############################')
